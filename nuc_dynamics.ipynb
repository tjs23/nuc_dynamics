# %%
# %load_ext cythonmagic

# %%
# %%cython
# from libc.math cimport exp, abs, sqrt, ceil
# from numpy cimport ndarray, double_t, int_t
# import numpy, cython, time, gc, random
#
# BOLTZMANN_K = 0.0019872041
#
# #ctypedef int_t   int
# #ctypedef double_t double
#
# class NucCythonError(Exception):
#
#   def __init__(self, err):
#
#     Exception.__init__(self, err)
#
#
# cdef int getRepulsionList(ndarray[int,   ndim=2] repList,
#                           ndarray[double, ndim=2] coords,
#                           int nCoords, int nRepMax,
#                           double repDist,
#                           ndarray[double, ndim=1] radii):
#
#   cdef int i, j
#   cdef int n = 0
#   cdef double dx, dy, dz, d2
#   cdef double distLim
#   cdef double distLim2
#
#   for i in range(nCoords-2):
#     for j in range(i+2, nCoords):
#       distLim = repDist + radii[i] + radii[j]
#       distLim2 = distLim * distLim
#
#       dx = coords[i,0] - coords[j,0]
#       if abs(dx) > distLim:
#         continue
#
#       dy = coords[i,1] - coords[j,1]
#       if abs(dy) > distLim:
#         continue
#
#       dz = coords[i,2] - coords[j,2]
#       if abs(dz) > distLim:
#         continue
#
#       d2 = dx*dx + dy*dy + dz*dz
#
#       if d2 > distLim2:
#         continue
#
#       repList[n,0] = i
#       repList[n,1] = j
#
#       n += 1
#
#       #return if we reached max, something is seriously wrong anyway
#       if n == nRepMax:
#         return n
#
#   return n
#
#
# cdef double getTemp(ndarray[double] masses,
#                     ndarray[double, ndim=2] veloc,
#                     int nCoords):
#   cdef int i
#   cdef double kin = 0.0
#
#   for i in range(nCoords):
#     kin += masses[i] * (veloc[i,0]*veloc[i,0] + veloc[i,1]*veloc[i,1] + veloc[i,2]*veloc[i,2])
#
#   return kin / (3 * nCoords * BOLTZMANN_K)
#
#
# def getStats(ndarray[int,   ndim=2] restIndices,
#              ndarray[double, ndim=2] restLimits,
#              ndarray[double, ndim=2] coords,
#              int nRest):
#
#   cdef int i, nViol = 0
#   cdef int j, k
#   cdef double viol, dmin, dmax, dx, dy, dz, r, s = 0
#
#   for i in range(nRest):
#     j = restIndices[i,0]
#     k = restIndices[i,1]
#
#     if j == k:
#       continue
#
#     dmin = restLimits[i,0]
#     dmax = restLimits[i,1]
#
#     dx = coords[j,0] - coords[k,0]
#     dy = coords[j,1] - coords[k,1]
#     dz = coords[j,2] - coords[k,2]
#     r = sqrt(dx*dx + dy*dy + dz*dz)
#
#     if r < dmin:
#       viol = dmin - r
#       nViol += 1
#
#     elif r > dmax:
#       viol = r - dmax
#       nViol += 1
#
#     else:
#       viol = 0
#
#     s += viol * viol
#
#   return nViol, sqrt(s/nRest)
#
#
# cdef void updateMotion(ndarray[double] masses,
#                        ndarray[double, ndim=2] forces,
#                        ndarray[double, ndim=2] accel,
#                        ndarray[double, ndim=2] veloc,
#                        ndarray[double, ndim=2] coords,
#                        int nCoords, double tRef,
#                        double tStep, double beta):
#
#   cdef int i
#   cdef double r, rtStep, temp
#
#   rtStep = 0.5 * tStep * tStep
#   temp = getTemp(masses, veloc, nCoords)
#   temp = max(temp, 0.001)
#   r = beta * (tRef/temp-1.0)
#
#   for i in range(nCoords):
#
#     accel[i,0] = forces[i,0] / masses[i] + r * veloc[i,0]
#     accel[i,1] = forces[i,1] / masses[i] + r * veloc[i,1]
#     accel[i,2] = forces[i,2] / masses[i] + r * veloc[i,2]
#
#     coords[i,0] += tStep * veloc[i,0] + rtStep * accel[i,0]
#     coords[i,1] += tStep * veloc[i,1] + rtStep * accel[i,1]
#     coords[i,2] += tStep * veloc[i,2] + rtStep * accel[i,2]
#
#     veloc[i,0] += tStep * accel[i,0]
#     veloc[i,1] += tStep * accel[i,1]
#     veloc[i,2] += tStep * accel[i,2]
#
#
# cdef void updateVelocity(ndarray[double] masses,
#                          ndarray[double, ndim=2] forces,
#                          ndarray[double, ndim=2] accel,
#                          ndarray[double, ndim=2] veloc,
#                          int nCoords, double tRef,
#                          double tStep, double beta):
#
#   cdef int i
#   cdef double r, temp
#
#   temp = getTemp(masses, veloc, nCoords)
#   #avoid division by 0 temperature
#   temp = max(temp, 0.001)
#   r = beta * (tRef/temp-1.0)
#
#   for i in range(nCoords):
#     veloc[i,0] += 0.5 * tStep * (forces[i,0] / masses[i] + r * veloc[i,0] - accel[i,0])
#     veloc[i,1] += 0.5 * tStep * (forces[i,1] / masses[i] + r * veloc[i,1] - accel[i,1])
#     veloc[i,2] += 0.5 * tStep * (forces[i,2] / masses[i] + r * veloc[i,2] - accel[i,2])
#
#
# cdef double getRepulsiveForce(ndarray[int,   ndim=2] repList,
#                               ndarray[double, ndim=2] forces,
#                               ndarray[double, ndim=2] coords,
#                               int nRep, double fConst,
#                               ndarray[double, ndim=1] radii):
#
#   cdef int i, j, k
#   cdef double dx, dy, dz, d2, dr, rjk
#   cdef double force = 0
#   cdef double repDist2
#
#   if fConst == 0:
#     return force
#
#   for i from 0 <= i < nRep:
#     j = repList[i,0]
#     k = repList[i,1]
#     repDist = radii[j] + radii[k]
#     repDist2 = repDist * repDist
#
#
#     dx = coords[k,0] - coords[j,0]
#     if abs(dx) > repDist:
#       continue
#
#     dy = coords[k,1] - coords[j,1]
#     if abs(dy) > repDist:
#       continue
#
#     dz = coords[k,2] - coords[j,2]
#     if abs(dz) > repDist:
#       continue
#
#     d2 = dx*dx + dy*dy + dz*dz
#     if d2 > repDist2:
#       continue
#
#     dr = repDist2 - d2
#     #energy contribution
#     force += fConst * dr * dr
#     rjk = 4 * fConst * dr
#
#     dx *= rjk
#     dy *= rjk
#     dz *= rjk
#
#     #force contributions
#     forces[j,0] -= dx
#     forces[k,0] += dx
#
#     forces[j,1] -= dy
#     forces[k,1] += dy
#
#     forces[j,2] -= dz
#     forces[k,2] += dz
#
#   return force
#
#
# cdef double getRestraintForce(ndarray[double, ndim=2] forces,
#                               ndarray[double, ndim=2] coords,
#                               ndarray[int,   ndim=2] restIndices,
#                               ndarray[double, ndim=2] restLimits,
#                               ndarray[int, ndim=1] restAmbig,
#                               int nRest, double fConst, double exponent=2.0,
#                               double distSwitch=0.5, double asymptote=1.0):
#
#   cdef int i, j, k, n, nAmbig
#   cdef double a, b, da, d, dmin, dmax, dx, dy, dz
#   cdef double r, r2, s2, rjk, ujk, force = 0, t
#
#   b = asymptote*distSwitch*distSwitch - exponent*distSwitch*distSwitch*distSwitch
#   a = distSwitch*distSwitch - asymptote*distSwitch - b/ distSwitch
#
#   i = 0
#
#   while i < nRest:
#
#
#     nAmbig = restAmbig[i]
#     r2 = 0.0
#
#     if nAmbig == 1:
#       j = restIndices[i,0]
#       k = restIndices[i,1]
#
#       if j != k:
#         dx = coords[j,0] - coords[k,0]
#         dy = coords[j,1] - coords[k,1]
#         dz = coords[j,2] - coords[k,2]
#         r2 = dx*dx + dy*dy + dz*dz
#
#     else:
#       for n in range(nAmbig):
#         j = restIndices[i+n,0]
#         k = restIndices[i+n,1]
#
#         if j != k:
#           dx = coords[j,0] - coords[k,0]
#           dy = coords[j,1] - coords[k,1]
#           dz = coords[j,2] - coords[k,2]
#           r = dx*dx + dy*dy + dz*dz
#           r2 += 1.0 / (r * r)
#
#       if r2 > 0:
#         r2 = 1.0 / sqrt(r2)
#
#     if r2 <= 0:
#       i += nAmbig
#       continue
#
#     dmin = restLimits[i,0]
#     dmax = restLimits[i,1]
#
#     da = dmax + distSwitch
#
#     if r2 < dmin*dmin:
#       r2 = max(r2, 1e-8)
#       r = sqrt(r2)
#       d = dmin - r
#       ujk = fConst * d * d
#       rjk = fConst * 2 * d
#
#     elif r2 > dmax*dmax:
#       r = sqrt(r2)
#       d = r - dmax
#
#       if r <= da:
#         ujk = fConst * d * d
#         rjk = - fConst * 2 * d
#
#       else:
#         ujk = fConst * (a + asymptote*d + b/d)
#         rjk = - fConst * (asymptote - b/(d*d))
#
#     else:
#       ujk = rjk = 0
#       r = 1.0
#
#     force += ujk
#
#     if nAmbig == 1:
#       j = restIndices[i,0]
#       k = restIndices[i,1]
#
#       if j == k:
#         i += nAmbig
#         continue
#
#       t = rjk / r
#       dx = coords[j,0] - coords[k,0]
#       dy = coords[j,1] - coords[k,1]
#       dz = coords[j,2] - coords[k,2]
#
#       dx *= t
#       dy *= t
#       dz *= t
#
#       forces[j,0] += dx
#       forces[j,1] += dy
#       forces[j,2] += dz
#
#       forces[k,0] -= dx
#       forces[k,1] -= dy
#       forces[k,2] -= dz
#
#     else:
#
#       for n in range(nAmbig):
#         j = restIndices[i+n,0]
#         k = restIndices[i+n,1]
#
#         if j == k:
#           continue
#
#         dx = coords[j,0] - coords[k,0]
#         dy = coords[j,1] - coords[k,1]
#         dz = coords[j,2] - coords[k,2]
#
#         s2 = dx*dx + dy*dy + dz*dz
#         t = rjk * r2 * r2 * r / (s2 * s2 * s2)
#
#         dx *= t
#         dy *= t
#         dz *= t
#
#         forces[j,0] += dx
#         forces[k,0] -= dx
#         forces[j,1] += dy
#         forces[k,1] -= dy
#         forces[j,2] += dz
#         forces[k,2] -= dz
#
#     i += nAmbig
#
#   return force
#
#
# def getSupportedPairs(ndarray[int, ndim=2] positions,
#                      int threshold=2000000, int posErr=100):
#
#   cdef int i, j, n = len(positions)
#   cdef int pA, pB, pC, pD
#   cdef ndarray[int, ndim=1] supported = numpy.zeros(n, numpy.int32)
#
#   for i in range(n):
#     pA = positions[i,0]
#     pB = positions[i,1]
#
#     for j in range(n):
#       if j == i:
#         continue
#
#       pC = positions[j,0]
#       pD = positions[j,1]
#
#       if (posErr < abs(pC-pA) < threshold) and (posErr < abs(pD-pB) < threshold):
#         supported[i] = 1
#         break
#
#       elif (posErr < abs(pD-pA) < threshold) and (posErr < abs(pC-pB) < threshold):
#         supported[i] = 1
#         break
#
#   indices = supported.nonzero()[0]
#
#   return indices
#
#
# def getInterpolatedCoords(chromosomes, posDict, prevPosDict, ndarray[double, ndim=2] coords):
#   """
#   Interpolate x,y,z particle positions for an array of seq positions to a new
#   seq positions e.g. for a change in binned resolution.
#   """
#
#   cdef int i, j, i0, j0, p1, p2, n, m, d, dMin
#   cdef double f, g
#   cdef ndarray[int, ndim=1] positions
#   cdef ndarray[int, ndim=1] prevPositions
#
#   cdef int a, b
#
#   # Get index offsets for each chromo
#   i = 0
#   offsets = {}
#   for chrA in chromosomes:
#     offsets[chrA] = i
#     i += len(posDict[chrA])
#
#   a = i
#   cdef ndarray[double, ndim=2] newCoords = numpy.empty((i, 3), float)
#
#   i = 0
#   prevOffsets = {}
#   for chrA in chromosomes:
#     prevOffsets[chrA] = i
#     i += len(prevPosDict[chrA])
#
#   b = i
#
#   for chrA in posDict:
#     i0 = offsets[chrA]
#     j0 = prevOffsets[chrA]
#     positions = posDict[chrA]
#     prevPositions = prevPosDict[chrA]
#     n = len(positions)
#     m = len(prevPositions)
#
#     for i in range(n):
#
#       #find closest old positions for coordinate interpolation
#       p1 = 0
#       dMin = positions[i]-prevPositions[0]
#
#       for j in range(1,m):
#         d = positions[i]-prevPositions[j]
#
#         if abs(d) < abs(dMin):
#           p1 = j
#           dMin = d #closest pos
#
#         elif abs(d) > abs(dMin): # Seq positions were in order
#           break
#
#       if dMin == 0: #new position coincides with an old position
#         p2 = p1
#
#       elif dMin > 0: #new pos is above p1
#         p2 = min(p1+1, m-1)
#
#       else: #new pos is below p1
#         p2 = p1
#         p1 = max(0, p1-1)
#         dMin = positions[i] - prevPositions[p1]
#
#       #calculate coordinates
#       if prevPositions[p2] == prevPositions[p1]:
#         newCoords[i0+i, 0] = coords[j0+p1, 0]
#         newCoords[i0+i, 1] = coords[j0+p1, 1]
#         newCoords[i0+i, 2] = coords[j0+p1, 2]
#
#       else: #interpolate
#         f = <float>dMin/<float>(prevPositions[p2]-prevPositions[p1])
#         g = 1.0 - f
#
#         newCoords[i0+i, 0] = g * coords[j0+p1, 0] + f * coords[j0+p2, 0]
#         newCoords[i0+i, 1] = g * coords[j0+p1, 1] + f * coords[j0+p2, 1]
#         newCoords[i0+i, 2] = g * coords[j0+p1, 2] + f * coords[j0+p2, 2]
#
#   return newCoords
#
#
#
# def runDynamics(ndarray[double, ndim=2] coords,
#                 ndarray[double, ndim=1] masses,
#                 ndarray[double, ndim=1] radii,
#                 ndarray[int, ndim=2] restIndices,
#                 ndarray[double, ndim=2] restLimits,
#                 ndarray[int, ndim=1] restAmbig,
#                 double tRef=1000.0, double tStep=0.001, int nSteps=1000,
#                 double fConstR=1.0, double fConstD=25.0, double beta=10.0,
#                 double repDist=1.5, # A heuristic to limit the repulsion list
#                 double tTaken=0.0, int printInterval=10000,
#                 double tot0=20.458, int nRepMax=0):
#
#   cdef int nRest = len(restIndices)
#   cdef int nCoords = len(coords)
#
#   if nCoords < 2:
#     raise NucCythonError('Too few coodinates')
#
#   indices = set(restIndices.ravel())
#   if min(indices) < 0:
#     raise NucCythonError('Restraint index negative')
#
#   if max(indices) >= nCoords:
#     data = (max(indices), nCoords)
#     raise NucCythonError('Restraint index "%d" out of bounds (> %d)' % data)
#
#   if nCoords != len(masses):
#     raise NucCythonError('Masses list size does not match coordinates')
#
#   if nRest != len(restLimits):
#     raise NucCythonError('Number of restraint index pairs does not match number of restraint limits')
#
#   if len(restAmbig) != nRest:
#     raise NucCythonError('Size of ambiguity list does not match number of restraints')
#
#   cdef int i, j, n, step, nViol, nRep = 0
#
#   if not nRepMax:
#     nRepMax = nCoords*800
#
#   cdef double d2, maxDelta, dx, dy, dz, ek, rmsd, tStep0, temp, fDist, fRep
#   cdef double deltaLim = 0.25 * repDist * repDist
#   cdef double Langevin_gamma
#
#   tStep0 = tStep * tot0
#   beta /= tot0
#
#   veloc = numpy.random.normal(0.0, 1.0, (nCoords, 3))
#   veloc *= sqrt(tRef / getTemp(masses, veloc, nCoords))
#
#   zeroArray = numpy.zeros((nCoords, 3))
#   repList = numpy.zeros((nRepMax, 2), numpy.int32)
#
#   cdef ndarray[double, ndim=2] coordsPrev = numpy.array(coords)
#   cdef ndarray[double, ndim=2] accel = numpy.array(zeroArray)
#   cdef ndarray[double, ndim=2] forces
#
#   t0 = time.time()
#
#   for step in range(nSteps):
#
#     if step == 0:
#       nRep = getRepulsionList(repList, coords, nCoords, nRepMax, repDist, radii) # Handle errors
#
#       for i in range(nCoords):
#         coordsPrev[i,0] = coords[i,0]
#         coordsPrev[i,1] = coords[i,1]
#         coordsPrev[i,2] = coords[i,2]
#
#       forces = numpy.array(zeroArray)
#       fRep = getRepulsiveForce(repList, forces, coords, nRep,  fConstR, radii)
#       fDist = getRestraintForce(forces, coords, restIndices, restLimits, restAmbig, nRest, fConstD)
#
#       for i in range(nCoords):
#         accel[i,0] = forces[i,0] / masses[i]
#         accel[i,1] = forces[i,1] / masses[i]
#         accel[i,2] = forces[i,2] / masses[i]
#
#     else:
#       maxDelta = 0.0
#       for i in range(nCoords):
#         dx = coords[i,0] - coordsPrev[i,0]
#         dy = coords[i,1] - coordsPrev[i,1]
#         dz = coords[i,2] - coordsPrev[i,2]
#         d2 = dx*dx + dy*dy + dz*dz
#
#         if d2 > maxDelta:
#           maxDelta = d2
#
#           if maxDelta > deltaLim:
#             break
#
#       if maxDelta > deltaLim:
#         nRep = getRepulsionList(repList, coords, nCoords, nRepMax, repDist, radii) # Handle errors
#
#         for i in range(nCoords):
#           coordsPrev[i,0] = coords[i,0]
#           coordsPrev[i,1] = coords[i,1]
#           coordsPrev[i,2] = coords[i,2]
#
#     updateMotion(masses, forces, accel, veloc, coords, nCoords, tRef, tStep0, beta)
#
#     for i in range(nCoords):
#       forces[i,0] = 0.0
#       forces[i,1] = 0.0
#       forces[i,2] = 0.0
#
#     fRep  = getRepulsiveForce(repList, forces, coords, nRep, fConstR, radii)
#     fDist = getRestraintForce(forces, coords, restIndices, restLimits, restAmbig, nRest, fConstD)
#
#     updateVelocity(masses, forces, accel, veloc, nCoords, tRef, tStep0,  beta)
#
#     if (printInterval > 0) and step % printInterval == 0:
#       temp = getTemp(masses, veloc, nCoords)
#       nViol, rmsd = getStats(restIndices, restLimits, coords, nRest)
#
#       data = (temp, fRep, fDist, rmsd, nViol, nRep)
#       print('temp:%7.2lf  fRep:%7.2lf  fDist:%7.2lf  rmsd:%7.2lf  nViol:%5d  nRep:%5d' % data)
#
#     tTaken += tStep
#
#   return tTaken, nRep

# %%
# %%cython
# from libc.math cimport exp, abs, sqrt, ceil
# from numpy cimport ndarray, double_t, int_t
# import numpy
#
# def calc_restraints(chromosomes, contact_dict, int particle_size=10000,
#                     float scale=1.0, float exponent=-0.33,
#                     float lower=0.8, float upper=1.2,
#                     int min_count=1):
#   """
#   Function to convert single-cell contact data into distance restraints
#   for structure calculations.
#   """
#
#   cdef int i, j, k, a, b, nc, n, na, nb
#   cdef double dist
#   cdef ndarray[long, ndim=2] contacts      # Contact matrix (3:(posA, posB, nObs), nContacts)
#   cdef ndarray[double, ndim=2] restraints  # Distance restraints (6:(), nRestraints)
#   cdef ndarray[int, ndim=2] bin_matrix     # Temp array for binned contacts
#   cdef ndarray[int, ndim=1] seq_pos_a
#   cdef ndarray[int, ndim=1] seq_pos_b
#   cdef ndarray[int, ndim=2] limits         # shape: (chromoId, 2:[start, end])
#
#   num_contacts_dict = {} # Total num contacts for each chromosomes
#   pos_dict = {}          # Start sequence position for each particle in each chromosome
#   restraint_dict = {}    # Final restraints for each pair of chromosomes
#
#   chromos = set(chromosomes)
#   nc = len(chromosomes)
#
#   # Num contacts per chromo for mem allocations
#   for chrA in contact_dict:
#     if chrA not in chromos:
#       continue
#
#     for chrB in contact_dict[chrA]:
#       if chrB not in chromos:
#         continue
#
#       contacts = contact_dict[chrA][chrB]
#       n = len(contacts[0])
#
#       if chrA in num_contacts_dict:
#         num_contacts_dict[chrA] += n
#       else:
#         num_contacts_dict[chrA] = n
#
#       if chrB in num_contacts_dict:
#         num_contacts_dict[chrB] += n
#       else:
#         num_contacts_dict[chrB] = n
#
#   chromo_idx = {chromo:i for i, chromo in enumerate(chromosomes)}
#   limits = numpy.zeros((nc,2), numpy.int32)
#
#   # Get chromosome ranges
#   for chrA in contact_dict:
#     if chrA not in chromos:
#       continue
#
#     a = chromo_idx[chrA]
#
#     for chrB in contact_dict[chrA]:
#       if chrB not in chromos:
#         continue
#
#       b = chromo_idx[chrB]
#       contacts = contact_dict[chrA][chrB]
#       n = len(contacts[0])
#
#       for i in range(n):
#
#         if limits[a,0] == 0: # zero is not a valid seq pos anyhow
#           limits[a,0] = contacts[0,i]
#         elif contacts[0,i] < limits[a,0]:
#           limits[a,0] = contacts[0,i]
#
#         if limits[b,0] == 0:
#           limits[b,0] = contacts[1,i]
#         elif contacts[1,i] < limits[b,0]:
#           limits[b,0] = contacts[1,i]
#
#         if contacts[0,i] > limits[a,1]:
#           limits[a,1] = contacts[0,i]
#
#         if contacts[1,i] > limits[b,1]:
#           limits[b,1] = contacts[1,i]
#
#
#   # Shift extremities of chromosome ranges to lie exactly on particle region edges
#   for a in range(nc):
#     limits[a,0] = particle_size * (limits[a,0]/particle_size)
#     limits[a,1] = particle_size * <int>(ceil(<float>limits[a,1]/particle_size))
#
#   # Get particle region start positions for each chromosome
#   for chromo in chromosomes:
#     a = chromo_idx[chromo]
#     pos_dict[chromo] = numpy.arange(limits[a,0], limits[a,1] + particle_size, particle_size, numpy.int32)
#
#   # Get restraint indices, do binning of contact observations
#   for chrA in contact_dict:
#     if chrA not in chromos:
#       continue
#
#     a = chromo_idx[chrA]
#     na = len(pos_dict[chrA])
#     seq_pos_a = pos_dict[chrA]
#     restraint_dict[chrA] = {}
#
#     for chrB in contact_dict[chrA]:
#       if chrB not in chromos:
#         continue
#
#       b = chromo_idx[chrB]
#       nb = len(pos_dict[chrB])
#       seq_pos_b = pos_dict[chrB]
#
#       contacts = contact_dict[chrA][chrB]
#       n = len(contacts[0])
#
#       restraints = numpy.empty((6, n), float)
#       bin_matrix = numpy.zeros((na, nb), numpy.int32)
#
#       for i in range(n):
#
#         # Find bin index for chromo A
#         for j in range(na):
#           if seq_pos_a[j] >= contacts[0,i]:
#             break
#
#         else:
#           continue
#
#         # Find bin index for chromo B
#         for k in range(nb):
#           if seq_pos_b[k] >= contacts[1,i]:
#             break
#
#         else:
#           continue
#
#         bin_matrix[j,k] += contacts[2,i]
#
#       #loop over all binned contacts, and calculate the constraint target distance
#       #using a powerlaw function and the number of observations
#       k = 0
#       for i in range(na):
#         for j in range(nb):
#           if bin_matrix[i,j] > 0:
#             if bin_matrix[i,j] < min_count:
#               continue
#
#             dist = scale * bin_matrix[i,j] ** exponent
#
#             restraints[0,k] = <double>i #binA
#             restraints[1,k] = <double>j #binB
#             restraints[2,k] = 1.0 # Weighting not currently used
#             restraints[3,k] = dist # target value
#             restraints[4,k] = dist * lower # constraint lower bound
#             restraints[5,k] = dist * upper # constraint upper bound
#
#             k += 1
#
#       restraint_dict[chrA][chrB] = restraints[:,:k]
#
#   return restraint_dict, pos_dict
#
#
# def concatenate_restraints(restraint_dict, pos_dict, particle_size,
#                            backbone_lower=0.1, backbone_upper=1.1):
#   """
#   Joins restraints stored in a dict by chromo pairs into long concatenated arrays.
#   Indices of restraints relate to concatenated chromo seq pos.
#   Add-in all the backbone restraints for sequential particles.
#   """
#
#   cdef int i, n, num_restraints, m
#   cdef int start_a, start_b
#   cdef float bbl = numpy.float32(backbone_lower)
#   cdef float bbu = numpy.float32(backbone_upper)
#   cdef double dist, size = particle_size
#
#   # Get total max number restraints and final restraint index offset for all chromos
#   i = 0
#   num_restraints = 0
#   chromo_idx_offset = {}
#
#   for chr_a in sorted(pos_dict):
#     n = len(pos_dict[chr_a])
#     chromo_idx_offset[chr_a] = i
#     num_restraints += n-1 # One fewer because no link at end of chain
#     i += n
#
#   for chr_a in restraint_dict:
#     for chr_b in restraint_dict[chr_a]:
#       num_restraints += restraint_dict[chr_a][chr_b].shape[1]
#
#   # Loop allocated arrays
#   cdef ndarray[int, ndim=1] positions
#   cdef ndarray[double, ndim=2] restraints
#
#   # Final arrays which will hold identities of restrained particle pairs
#   # and the restraint distances for each
#   cdef ndarray[int, ndim=2] particle_indices = numpy.empty((num_restraints, 2), numpy.int32)
#   cdef ndarray[double, ndim=2] distances = numpy.empty((num_restraints, 2), float)
#
#   # Add backbone path restraints
#   m = 0
#   for chr_a in pos_dict:
#
#     positions = pos_dict[chr_a]
#     n = len(positions)
#     start_a = chromo_idx_offset[chr_a]
#
#     for i in range(n-1):
#
#       # Normally this is 1.0 for regular sized particles
#       dist = (positions[i+1]-positions[i])/size
#
#       particle_indices[m,0] = i + start_a
#       particle_indices[m,1] = i + start_a + 1
#
#       distances[m,0] = dist * bbl # lower
#       distances[m,1] = dist * bbu # upper
#
#       m += 1
#
#   # Add regular restraints for chromo pairs
#   for chr_a in restraint_dict:
#     start_a = chromo_idx_offset[chr_a] # Offset for chromo A particles
#
#     for chr_b in restraint_dict[chr_a]:
#       start_b = chromo_idx_offset[chr_b] # Offset for chromo B particles
#
#       restraints = restraint_dict[chr_a][chr_b]
#       n = restraints.shape[1]
#
#       for i in range(n):
#         particle_indices[m,0] = <int>restraints[0,i] + start_a
#         particle_indices[m,1] = <int>restraints[1,i] + start_b
#
#         distances[m,0] = restraints[4,i] # lower
#         distances[m,1] = restraints[5,i] # upper
#
#         m += 1
#
#   return particle_indices, distances

# %% [markdown]
# ### Simple annealing protocol

# %%
def anneal_structure(coords, restraintIndices, restraintLimits,
                    tempMax=5000.0, tempMin=10.0, tempSteps=500,
                    dynSteps=100, timeStep=0.001, randSeed=None):
  """
  A simple single-stage annealing protocol with exponential
  temperature decay and sigmoidal repulsion scheme.
  """
    
  from random import seed
  from math import atan, log, exp, pi
  from numpy import array, random, ones, int32
    
  # Consider masses and fixed particles
      
  if randSeed is None:
    seed()
  else:
    seed(randSeed)
  
  # Ensure inputs are numpy.ndarray  
  coords = array(coords)
  restraintIndices = array(restraintIndices, dtype=int32)
  restraintLimits = array(restraintLimits)
    
  nPoints = len(coords)
  
  # Masses and radii not used, just set to 1.0
  masses = radii = ones(nPoints, float)
    
  # Ambiguiuty not used, but represents the stride of sequential, grouped restraints
  ambiguity = ones(len(restraintIndices), int32)

  adj = 1.0 / atan(10.0)
  decay = log(tempMax/tempMin)    

  for step in range(tempSteps):
    frac = step/float(tempSteps)
    
    # exponential temp decay
    temp = tempMax * exp(-decay*frac)
    
    # sigmoidal repusion scheme
    repulse = 0.5 + adj * atan(frac*20.0-10) / pi 
    
    # update coordinates
    runDynamics(coords, masses, radii, restraintIndices, restraintLimits,
                ambiguity, temp, timeStep, dynSteps, repulse,
                repDist=1.5, printInterval=int32(100))
  
    # Center
    coords -= coords.mean(axis=0)
  
  return coords

# %% [markdown]
# ### Test annealing

# %%
from numpy import random

# Random particle coordinates - 20 test points of (x,y,z) 
nCoords = 20
coords = random.uniform(-1.0, 1.0, (nCoords,3)) 
  
# Each pair represents a connection between a pair of particles
# Restraint indices refer to indices in coordinate array
rIndices = [(0, 1), (0, 5), (0, 18), (1, 0), (1, 2),
            (1, 9), (2, 1), (2, 3), (2, 10), (3, 2),
            (3, 4), (3, 17), (4, 3), (4, 5), (4, 11),
            (5, 0), (5, 4), (5, 12), (6, 7), (6, 17),
            (6, 19), (7, 6), (7, 14), (7, 15), (7, 16),
            (8, 18), (9, 1), (10, 2), (11, 4), (12, 5),
            (13, 17), (14, 7), (15, 7), (16, 7), (17, 3),
            (17, 6), (17, 13), (18, 0), (18, 8), (19, 6)]
  
# Distances - upper and lower bounds for each particle
# Unform upper and lower bounds for test restraints
lower = 0.8
upper = 1.2
rDists = [(0.8, 1.2)] * len(rIndices)

# Run calculation
coords = anneal_structure(coords, rIndices, rDists)
  
# Show results
for i, c in enumerate(coords):
  print '%3d' % i, c
# Out:
# temp:5592.10  fRep: 157.87  fDist: 153.98  rmsd:   0.41  nViol:   30  nRep:  171
# temp:4848.06  fRep:  22.35  fDist: 167.29  rmsd:   0.43  nViol:   38  nRep:   97
# temp:4780.54  fRep:  53.91  fDist:  72.05  rmsd:   0.27  nViol:   30  nRep:  150
# temp:4755.10  fRep:  24.49  fDist: 115.46  rmsd:   0.38  nViol:   22  nRep:  112
# temp:4782.63  fRep:  49.44  fDist: 141.80  rmsd:   0.40  nViol:   34  nRep:  135
# temp:4957.35  fRep:  43.37  fDist: 160.88  rmsd:   0.43  nViol:   32  nRep:  111
# temp:4627.30  fRep:  39.85  fDist:  59.84  rmsd:   0.25  nViol:   22  nRep:  117
# temp:4678.66  fRep:  59.98  fDist: 152.55  rmsd:   0.40  nViol:   36  nRep:  152
# temp:4529.00  fRep:  59.79  fDist:  61.71  rmsd:   0.25  nViol:   20  nRep:  112
# temp:4555.94  fRep:  40.22  fDist: 118.17  rmsd:   0.39  nViol:   30  nRep:  150
# temp:4338.46  fRep:  38.78  fDist: 181.41  rmsd:   0.47  nViol:   36  nRep:  103
# temp:4303.05  fRep:  59.23  fDist:  63.32  rmsd:   0.25  nViol:   30  nRep:  152
# temp:4230.39  fRep:  37.96  fDist:  64.36  rmsd:   0.26  nViol:   32  nRep:  126
# temp:4175.05  fRep:  39.53  fDist:  89.64  rmsd:   0.30  nViol:   32  nRep:  118
# temp:3917.83  fRep:  38.88  fDist:  67.21  rmsd:   0.26  nViol:   38  nRep:  130
# temp:4078.84  fRep:  49.06  fDist:  86.67  rmsd:   0.31  nViol:   32  nRep:  130
# temp:3999.47  fRep:  33.81  fDist: 119.60  rmsd:   0.36  nViol:   24  nRep:  113
# temp:3994.51  fRep:  28.44  fDist:  79.14  rmsd:   0.29  nViol:   28  nRep:   92
# temp:4140.15  fRep:  80.05  fDist:  70.75  rmsd:   0.28  nViol:   34  nRep:  148
# temp:3895.24  fRep:  33.20  fDist:  77.25  rmsd:   0.30  nViol:   24  nRep:  128
# temp:4027.72  fRep:  47.12  fDist:  47.35  rmsd:   0.22  nViol:   30  nRep:  145
# temp:3969.87  fRep:  62.04  fDist:  64.68  rmsd:   0.25  nViol:   26  nRep:  144
# temp:3885.27  fRep:  38.89  fDist:  72.06  rmsd:   0.27  nViol:   26  nRep:  106
# temp:3684.40  fRep:  35.37  fDist:  95.10  rmsd:   0.32  nViol:   38  nRep:   92
# temp:3571.60  fRep:  57.59  fDist:  77.43  rmsd:   0.28  nViol:   28  nRep:  150
# temp:3581.58  fRep:  47.61  fDist:  55.83  rmsd:   0.24  nViol:   26  nRep:  143
# temp:3693.35  fRep:  42.77  fDist:  57.58  rmsd:   0.24  nViol:   32  nRep:  100
# temp:3543.76  fRep:  30.96  fDist:  55.45  rmsd:   0.24  nViol:   28  nRep:  111
# temp:3573.84  fRep:  33.59  fDist:  39.96  rmsd:   0.20  nViol:   30  nRep:  111
# temp:3452.26  fRep:  43.85  fDist:  36.42  rmsd:   0.19  nViol:   30  nRep:  146
# temp:3559.80  fRep:  32.22  fDist:  68.32  rmsd:   0.26  nViol:   28  nRep:  102
# temp:3376.99  fRep:  50.72  fDist:  75.61  rmsd:   0.27  nViol:   30  nRep:  131
# temp:3472.38  fRep:  37.78  fDist:  91.53  rmsd:   0.32  nViol:   36  nRep:  123
# temp:3242.41  fRep:  34.05  fDist:  96.22  rmsd:   0.33  nViol:   30  nRep:   88
# temp:3342.43  fRep:  61.79  fDist:  44.06  rmsd:   0.21  nViol:   28  nRep:  143
# temp:3187.93  fRep:  29.51  fDist:  35.48  rmsd:   0.19  nViol:   28  nRep:   92
# temp:3254.14  fRep:  61.89  fDist:  82.22  rmsd:   0.29  nViol:   28  nRep:  158
# temp:3174.22  fRep:  37.78  fDist:  65.80  rmsd:   0.26  nViol:   24  nRep:  134
# temp:3087.84  fRep:  39.95  fDist:  50.15  rmsd:   0.22  nViol:   28  nRep:  139
# temp:3104.52  fRep:  39.43  fDist:  35.01  rmsd:   0.19  nViol:   18  nRep:  117
# temp:3130.66  fRep:  43.88  fDist:  41.07  rmsd:   0.20  nViol:   22  nRep:  130
# temp:2849.22  fRep:  38.59  fDist:  79.86  rmsd:   0.28  nViol:   30  nRep:  125
# temp:2912.78  fRep:  44.63  fDist:  70.70  rmsd:   0.27  nViol:   28  nRep:  137
# temp:3009.77  fRep:  36.96  fDist:  59.26  rmsd:   0.24  nViol:   20  nRep:  116
# temp:2882.35  fRep:  41.08  fDist:  44.00  rmsd:   0.21  nViol:   28  nRep:  132
# temp:2799.88  fRep:  41.95  fDist:  61.28  rmsd:   0.25  nViol:   28  nRep:  124
# temp:2819.65  fRep:  39.16  fDist:  33.52  rmsd:   0.18  nViol:   24  nRep:  133
# temp:2590.02  fRep:  41.45  fDist:  99.25  rmsd:   0.32  nViol:   28  nRep:  123
# temp:2618.74  fRep:  30.55  fDist:  65.13  rmsd:   0.26  nViol:   26  nRep:  128
# temp:2695.82  fRep:  21.80  fDist:  63.25  rmsd:   0.25  nViol:   28  nRep:  117
# temp:2790.09  fRep:  63.28  fDist:  23.96  rmsd:   0.15  nViol:   20  nRep:  153
# temp:2493.13  fRep:  39.82  fDist:  48.79  rmsd:   0.22  nViol:   18  nRep:  120
# temp:2538.38  fRep:  46.05  fDist:  57.32  rmsd:   0.24  nViol:   32  nRep:  137
# temp:2697.48  fRep:  35.32  fDist:  29.55  rmsd:   0.17  nViol:   24  nRep:  127
# temp:2421.42  fRep:  33.21  fDist:  83.79  rmsd:   0.30  nViol:   32  nRep:  105
# temp:2573.32  fRep:  44.91  fDist:  70.38  rmsd:   0.27  nViol:   30  nRep:  124
# temp:2544.97  fRep:  47.24  fDist:  71.83  rmsd:   0.28  nViol:   30  nRep:  121
# temp:2536.03  fRep:  36.76  fDist:  50.94  rmsd:   0.23  nViol:   20  nRep:  126
# temp:2516.78  fRep:  35.70  fDist:  42.35  rmsd:   0.21  nViol:   30  nRep:  110
# temp:2364.44  fRep:  30.16  fDist:  52.48  rmsd:   0.23  nViol:   26  nRep:  108
# temp:2308.27  fRep:  40.06  fDist:  30.22  rmsd:   0.17  nViol:   26  nRep:  131
# temp:2259.73  fRep:  30.26  fDist:  34.52  rmsd:   0.19  nViol:   28  nRep:  110
# temp:2320.94  fRep:  54.20  fDist:  34.12  rmsd:   0.19  nViol:   20  nRep:  142
# temp:2280.06  fRep:  36.82  fDist:  32.78  rmsd:   0.18  nViol:   24  nRep:  104
# temp:2239.04  fRep:  40.06  fDist:  55.83  rmsd:   0.24  nViol:   28  nRep:  110
# temp:2109.11  fRep:  49.50  fDist:  34.21  rmsd:   0.18  nViol:   18  nRep:  145
# temp:2323.55  fRep:  41.10  fDist:  26.70  rmsd:   0.16  nViol:   30  nRep:  112
# temp:2177.37  fRep:  35.68  fDist:  70.85  rmsd:   0.28  nViol:   28  nRep:  129
# temp:2321.63  fRep:  24.42  fDist:  60.32  rmsd:   0.25  nViol:   26  nRep:   94
# temp:2078.29  fRep:  38.00  fDist:  49.53  rmsd:   0.22  nViol:   26  nRep:  140
# temp:2044.08  fRep:  23.07  fDist:  61.45  rmsd:   0.25  nViol:   24  nRep:   86
# temp:2092.03  fRep:  53.39  fDist:  29.42  rmsd:   0.17  nViol:   20  nRep:  146
# temp:2147.40  fRep:  34.40  fDist:  28.34  rmsd:   0.17  nViol:   30  nRep:   98
# temp:2021.90  fRep:  49.13  fDist:  43.78  rmsd:   0.21  nViol:   24  nRep:  140
# temp:1994.71  fRep:  36.80  fDist:  33.59  rmsd:   0.18  nViol:   26  nRep:  111
# temp:1929.93  fRep:  49.31  fDist:  26.12  rmsd:   0.16  nViol:   26  nRep:  133
# temp:1967.08  fRep:  40.97  fDist:  47.05  rmsd:   0.22  nViol:   26  nRep:  125
# temp:1895.11  fRep:  40.42  fDist:  26.26  rmsd:   0.16  nViol:   26  nRep:  133
# temp:1906.46  fRep:  61.66  fDist:  23.53  rmsd:   0.15  nViol:   22  nRep:  121
# temp:1933.60  fRep:  48.60  fDist:  35.87  rmsd:   0.19  nViol:   26  nRep:  135
# temp:1914.87  fRep:  37.17  fDist:  15.44  rmsd:   0.12  nViol:   22  nRep:  138
# temp:1856.88  fRep:  40.73  fDist:  39.05  rmsd:   0.20  nViol:   28  nRep:  111
# temp:1797.87  fRep:  44.51  fDist:  42.59  rmsd:   0.21  nViol:   24  nRep:  118
# temp:1909.18  fRep:  35.62  fDist:  28.22  rmsd:   0.17  nViol:   26  nRep:  143
# temp:1644.93  fRep:  46.08  fDist:  57.64  rmsd:   0.24  nViol:   24  nRep:  116
# temp:1669.22  fRep:  34.96  fDist:  51.95  rmsd:   0.23  nViol:   30  nRep:  114
# temp:1730.46  fRep:  32.46  fDist:  37.65  rmsd:   0.20  nViol:   28  nRep:  124
# temp:1698.84  fRep:  42.00  fDist:  18.40  rmsd:   0.14  nViol:   20  nRep:  114
# temp:1672.53  fRep:  36.27  fDist:  17.62  rmsd:   0.13  nViol:   24  nRep:  122
# temp:1589.92  fRep:  48.16  fDist:  20.34  rmsd:   0.14  nViol:   16  nRep:  137
# temp:1640.76  fRep:  35.99  fDist:  50.65  rmsd:   0.23  nViol:   28  nRep:  124
# temp:1525.59  fRep:  51.40  fDist:  14.62  rmsd:   0.12  nViol:   24  nRep:  133
# temp:1648.05  fRep:  38.08  fDist:  25.53  rmsd:   0.16  nViol:   26  nRep:  130
# temp:1557.75  fRep:  50.49  fDist:  31.02  rmsd:   0.18  nViol:   26  nRep:  121
# temp:1491.20  fRep:  44.08  fDist:  29.90  rmsd:   0.17  nViol:   24  nRep:  129
# temp:1599.20  fRep:  35.84  fDist:  24.53  rmsd:   0.16  nViol:   26  nRep:  107
# temp:1488.36  fRep:  42.98  fDist:  32.09  rmsd:   0.18  nViol:   24  nRep:  114
# temp:1542.20  fRep:  37.00  fDist:  13.28  rmsd:   0.12  nViol:   20  nRep:  116
# temp:1389.76  fRep:  34.04  fDist:  26.31  rmsd:   0.16  nViol:   26  nRep:  103
# temp:1421.64  fRep:  33.02  fDist:  26.10  rmsd:   0.16  nViol:   30  nRep:  128
# temp:1459.77  fRep:  35.97  fDist:  18.20  rmsd:   0.13  nViol:   22  nRep:  117
# temp:1430.06  fRep:  31.72  fDist:  17.18  rmsd:   0.13  nViol:   36  nRep:  128
# temp:1392.59  fRep:  33.04  fDist:  13.72  rmsd:   0.12  nViol:   26  nRep:  132
# temp:1354.21  fRep:  43.17  fDist:  28.37  rmsd:   0.17  nViol:   26  nRep:  126
# temp:1378.16  fRep:  32.58  fDist:  28.36  rmsd:   0.17  nViol:   32  nRep:  118
# temp:1318.31  fRep:  44.97  fDist:  10.08  rmsd:   0.10  nViol:   22  nRep:  112
# temp:1317.00  fRep:  33.88  fDist:  40.04  rmsd:   0.20  nViol:   34  nRep:  119
# temp:1286.46  fRep:  27.70  fDist:  49.30  rmsd:   0.22  nViol:   30  nRep:   95
# temp:1299.72  fRep:  43.02  fDist:  13.61  rmsd:   0.12  nViol:   22  nRep:  136
# temp:1269.13  fRep:  31.36  fDist:  25.90  rmsd:   0.16  nViol:   24  nRep:  110
# temp:1249.03  fRep:  34.80  fDist:  17.05  rmsd:   0.13  nViol:   24  nRep:  125
# temp:1154.01  fRep:  36.17  fDist:  26.75  rmsd:   0.16  nViol:   24  nRep:  119
# temp:1274.48  fRep:  25.37  fDist:  17.55  rmsd:   0.13  nViol:   24  nRep:  104
# temp:1245.07  fRep:  36.02  fDist:   9.25  rmsd:   0.10  nViol:   26  nRep:  115
# temp:1199.72  fRep:  41.69  fDist:  13.13  rmsd:   0.11  nViol:   20  nRep:  100
# temp:1135.04  fRep:  31.89  fDist:  23.79  rmsd:   0.15  nViol:   24  nRep:  116
# temp:1177.64  fRep:  30.16  fDist:  21.69  rmsd:   0.15  nViol:   26  nRep:  103
# temp:1203.18  fRep:  32.57  fDist:  23.18  rmsd:   0.15  nViol:   22  nRep:  118
# temp:1119.90  fRep:  39.92  fDist:   7.64  rmsd:   0.09  nViol:   22  nRep:  112
# temp:1147.38  fRep:  33.72  fDist:  14.03  rmsd:   0.12  nViol:   20  nRep:  121
# temp:1133.52  fRep:  32.34  fDist:  21.68  rmsd:   0.15  nViol:   22  nRep:  130
# temp:1128.66  fRep:  36.78  fDist:  36.74  rmsd:   0.19  nViol:   16  nRep:  104
# temp:1121.07  fRep:  31.14  fDist:  18.73  rmsd:   0.14  nViol:   24  nRep:  105
# temp:1139.22  fRep:  32.79  fDist:  23.62  rmsd:   0.15  nViol:   22  nRep:  127
# temp:1035.35  fRep:  31.10  fDist:  32.68  rmsd:   0.18  nViol:   26  nRep:  114
# temp:1094.87  fRep:  31.56  fDist:  12.84  rmsd:   0.11  nViol:   20  nRep:  125
# temp:1077.57  fRep:  36.57  fDist:  16.14  rmsd:   0.13  nViol:   24  nRep:  115
# temp: 984.39  fRep:  40.04  fDist:  17.42  rmsd:   0.13  nViol:   24  nRep:  110
# temp:1012.50  fRep:  30.24  fDist:  19.99  rmsd:   0.14  nViol:   20  nRep:   95
# temp: 970.53  fRep:  35.64  fDist:  10.99  rmsd:   0.10  nViol:   20  nRep:  122
# temp:1055.12  fRep:  28.98  fDist:  16.24  rmsd:   0.13  nViol:   24  nRep:   98
# temp:1005.11  fRep:  43.15  fDist:  10.47  rmsd:   0.10  nViol:   24  nRep:  129
# temp:1004.84  fRep:  36.88  fDist:  20.61  rmsd:   0.14  nViol:   28  nRep:  112
# temp: 911.06  fRep:  33.15  fDist:  27.23  rmsd:   0.17  nViol:   26  nRep:  116
# temp: 955.45  fRep:  31.30  fDist:  23.36  rmsd:   0.15  nViol:   24  nRep:  109
# temp: 919.02  fRep:  38.41  fDist:  21.33  rmsd:   0.15  nViol:   28  nRep:  108
# temp: 926.66  fRep:  35.69  fDist:  10.27  rmsd:   0.10  nViol:   22  nRep:  142
# temp: 900.69  fRep:  34.08  fDist:  20.43  rmsd:   0.14  nViol:   26  nRep:  100
# temp: 952.56  fRep:  32.43  fDist:  22.07  rmsd:   0.15  nViol:   30  nRep:  116
# temp: 901.27  fRep:  26.81  fDist:  24.78  rmsd:   0.16  nViol:   28  nRep:  116
# temp: 884.25  fRep:  28.89  fDist:   9.46  rmsd:   0.10  nViol:   22  nRep:  117
# temp: 815.49  fRep:  26.47  fDist:  28.97  rmsd:   0.17  nViol:   26  nRep:  101
# temp: 862.94  fRep:  29.07  fDist:  13.42  rmsd:   0.12  nViol:   26  nRep:  107
# temp: 860.86  fRep:  30.64  fDist:   6.91  rmsd:   0.08  nViol:   22  nRep:  107
# temp: 877.55  fRep:  31.71  fDist:  14.50  rmsd:   0.12  nViol:   28  nRep:  113
# temp: 820.09  fRep:  37.56  fDist:  11.36  rmsd:   0.11  nViol:   20  nRep:  134
# temp: 783.57  fRep:  27.88  fDist:  13.41  rmsd:   0.12  nViol:   24  nRep:  117
# temp: 845.89  fRep:  28.99  fDist:   9.02  rmsd:   0.09  nViol:   22  nRep:  121
# temp: 783.58  fRep:  29.66  fDist:  16.26  rmsd:   0.13  nViol:   26  nRep:  119
# temp: 781.84  fRep:  28.07  fDist:  21.21  rmsd:   0.15  nViol:   26  nRep:   96
# temp: 819.42  fRep:  35.39  fDist:   9.73  rmsd:   0.10  nViol:   26  nRep:  118
# temp: 761.93  fRep:  33.35  fDist:  12.70  rmsd:   0.11  nViol:   16  nRep:  107
# temp: 743.86  fRep:  34.93  fDist:   6.65  rmsd:   0.08  nViol:   22  nRep:  112
# temp: 717.03  fRep:  24.16  fDist:  20.16  rmsd:   0.14  nViol:   28  nRep:  114
# temp: 772.34  fRep:  36.89  fDist:  13.12  rmsd:   0.11  nViol:   24  nRep:  103
# temp: 710.66  fRep:  32.16  fDist:  12.62  rmsd:   0.11  nViol:   24  nRep:  122
# temp: 751.30  fRep:  26.89  fDist:  20.70  rmsd:   0.14  nViol:   32  nRep:  112
# temp: 719.60  fRep:  29.56  fDist:  15.98  rmsd:   0.13  nViol:   20  nRep:  130
# temp: 675.27  fRep:  30.93  fDist:   9.62  rmsd:   0.10  nViol:   20  nRep:  105
# temp: 670.89  fRep:  36.42  fDist:   6.98  rmsd:   0.08  nViol:   28  nRep:  112
# temp: 636.78  fRep:  36.71  fDist:  12.04  rmsd:   0.11  nViol:   28  nRep:   91
# temp: 674.53  fRep:  25.92  fDist:   8.37  rmsd:   0.09  nViol:   30  nRep:  116
# temp: 671.58  fRep:  25.61  fDist:  13.15  rmsd:   0.11  nViol:   30  nRep:   98
# temp: 688.07  fRep:  29.83  fDist:  10.44  rmsd:   0.10  nViol:   24  nRep:  109
# temp: 636.78  fRep:  29.57  fDist:   8.17  rmsd:   0.09  nViol:   22  nRep:  116
# temp: 673.31  fRep:  34.63  fDist:   2.35  rmsd:   0.05  nViol:   20  nRep:  111
# temp: 632.00  fRep:  30.56  fDist:  12.89  rmsd:   0.11  nViol:   28  nRep:  101
# temp: 615.76  fRep:  24.12  fDist:  10.73  rmsd:   0.10  nViol:   26  nRep:   96
# temp: 625.91  fRep:  30.78  fDist:   4.06  rmsd:   0.06  nViol:   20  nRep:  123
# temp: 605.98  fRep:  26.51  fDist:  12.47  rmsd:   0.11  nViol:   18  nRep:  115
# temp: 614.16  fRep:  32.51  fDist:   6.79  rmsd:   0.08  nViol:   26  nRep:  124
# temp: 639.24  fRep:  28.82  fDist:  13.87  rmsd:   0.12  nViol:   28  nRep:  125
# temp: 611.91  fRep:  22.38  fDist:  18.31  rmsd:   0.14  nViol:   26  nRep:   91
# temp: 573.33  fRep:  27.52  fDist:  12.01  rmsd:   0.11  nViol:   20  nRep:  101
# temp: 587.60  fRep:  28.34  fDist:   5.71  rmsd:   0.08  nViol:   22  nRep:  119
# temp: 566.70  fRep:  30.59  fDist:  12.27  rmsd:   0.11  nViol:   24  nRep:  100
# temp: 562.95  fRep:  39.17  fDist:   5.23  rmsd:   0.07  nViol:   24  nRep:  121
# temp: 560.02  fRep:  34.53  fDist:   9.63  rmsd:   0.10  nViol:   22  nRep:   99
# temp: 534.07  fRep:  33.01  fDist:   6.44  rmsd:   0.08  nViol:   18  nRep:  114
# temp: 523.97  fRep:  28.20  fDist:  12.30  rmsd:   0.11  nViol:   26  nRep:  105
# temp: 526.35  fRep:  32.03  fDist:  10.08  rmsd:   0.10  nViol:   22  nRep:   98
# temp: 530.64  fRep:  30.46  fDist:   8.29  rmsd:   0.09  nViol:   24  nRep:  111
# temp: 515.87  fRep:  28.84  fDist:   7.88  rmsd:   0.09  nViol:   26  nRep:  107
# temp: 510.14  fRep:  25.92  fDist:  12.19  rmsd:   0.11  nViol:   30  nRep:  115
# temp: 537.72  fRep:  28.23  fDist:   8.53  rmsd:   0.09  nViol:   24  nRep:  106
# temp: 523.78  fRep:  29.85  fDist:   7.54  rmsd:   0.09  nViol:   26  nRep:   97
# temp: 512.87  fRep:  25.32  fDist:   7.38  rmsd:   0.09  nViol:   24  nRep:   97
# temp: 503.81  fRep:  31.89  fDist:   3.21  rmsd:   0.06  nViol:   24  nRep:  113
# temp: 502.48  fRep:  25.76  fDist:   7.56  rmsd:   0.09  nViol:   20  nRep:   98
# temp: 488.02  fRep:  28.71  fDist:   6.72  rmsd:   0.08  nViol:   22  nRep:  103
# temp: 485.95  fRep:  32.92  fDist:   7.51  rmsd:   0.09  nViol:   20  nRep:  110
# temp: 465.66  fRep:  32.78  fDist:  10.85  rmsd:   0.10  nViol:   28  nRep:  103
# temp: 450.48  fRep:  32.42  fDist:  10.01  rmsd:   0.10  nViol:   24  nRep:  106
# temp: 449.64  fRep:  31.47  fDist:   6.89  rmsd:   0.08  nViol:   20  nRep:  107
# temp: 444.01  fRep:  28.04  fDist:   7.34  rmsd:   0.09  nViol:   26  nRep:  120
# temp: 428.67  fRep:  23.42  fDist:   6.36  rmsd:   0.08  nViol:   30  nRep:   97
# temp: 425.35  fRep:  30.06  fDist:   7.73  rmsd:   0.09  nViol:   22  nRep:  104
# temp: 430.06  fRep:  32.26  fDist:  10.03  rmsd:   0.10  nViol:   24  nRep:   98
# temp: 400.87  fRep:  38.30  fDist:   4.49  rmsd:   0.07  nViol:   16  nRep:  108
# temp: 422.96  fRep:  32.85  fDist:   3.20  rmsd:   0.06  nViol:   22  nRep:   93
# temp: 415.52  fRep:  34.07  fDist:   7.41  rmsd:   0.09  nViol:   24  nRep:  115
# temp: 396.81  fRep:  29.87  fDist:   6.86  rmsd:   0.08  nViol:   20  nRep:  100
# temp: 413.13  fRep:  28.20  fDist:   5.15  rmsd:   0.07  nViol:   22  nRep:  102
# temp: 386.88  fRep:  32.67  fDist:   8.24  rmsd:   0.09  nViol:   22  nRep:  112
# temp: 390.75  fRep:  31.04  fDist:   9.62  rmsd:   0.10  nViol:   30  nRep:  101
# temp: 370.08  fRep:  29.89  fDist:   6.83  rmsd:   0.08  nViol:   22  nRep:   96
# temp: 383.01  fRep:  32.62  fDist:   3.67  rmsd:   0.06  nViol:   22  nRep:  121
# temp: 392.06  fRep:  32.20  fDist:   4.20  rmsd:   0.06  nViol:   24  nRep:  105
# temp: 376.29  fRep:  31.44  fDist:   5.34  rmsd:   0.07  nViol:   28  nRep:  104
# temp: 363.09  fRep:  27.29  fDist:   7.64  rmsd:   0.09  nViol:   26  nRep:  106
# temp: 385.22  fRep:  29.94  fDist:   6.80  rmsd:   0.08  nViol:   30  nRep:  100
# temp: 366.58  fRep:  32.87  fDist:   3.87  rmsd:   0.06  nViol:   16  nRep:  109
# temp: 346.32  fRep:  28.85  fDist:   6.62  rmsd:   0.08  nViol:   18  nRep:   94
# temp: 336.47  fRep:  33.21  fDist:   8.84  rmsd:   0.09  nViol:   30  nRep:  104
# temp: 354.26  fRep:  29.96  fDist:   5.55  rmsd:   0.07  nViol:   22  nRep:   90
# temp: 333.03  fRep:  31.76  fDist:   8.15  rmsd:   0.09  nViol:   28  nRep:  111
# temp: 334.06  fRep:  32.31  fDist:   6.87  rmsd:   0.08  nViol:   22  nRep:   98
# temp: 331.99  fRep:  31.04  fDist:   7.60  rmsd:   0.09  nViol:   24  nRep:   95
# temp: 335.57  fRep:  34.38  fDist:   4.52  rmsd:   0.07  nViol:   18  nRep:  103
# temp: 326.85  fRep:  33.78  fDist:  10.67  rmsd:   0.10  nViol:   20  nRep:   94
# temp: 323.42  fRep:  34.55  fDist:   6.70  rmsd:   0.08  nViol:   24  nRep:  103
# temp: 317.68  fRep:  31.00  fDist:   6.79  rmsd:   0.08  nViol:   26  nRep:   96
# temp: 311.07  fRep:  36.23  fDist:   6.21  rmsd:   0.08  nViol:   26  nRep:  117
# temp: 300.87  fRep:  36.07  fDist:   5.93  rmsd:   0.08  nViol:   28  nRep:  104
# temp: 328.01  fRep:  30.76  fDist:   7.66  rmsd:   0.09  nViol:   26  nRep:   93
# temp: 313.21  fRep:  31.89  fDist:   4.19  rmsd:   0.06  nViol:   24  nRep:   99
# temp: 296.26  fRep:  32.03  fDist:   3.87  rmsd:   0.06  nViol:   24  nRep:  111
# temp: 306.58  fRep:  36.15  fDist:   4.67  rmsd:   0.07  nViol:   18  nRep:   95
# temp: 287.23  fRep:  35.00  fDist:   4.46  rmsd:   0.07  nViol:   22  nRep:  110
# temp: 281.97  fRep:  30.00  fDist:   8.21  rmsd:   0.09  nViol:   26  nRep:  111
# temp: 292.13  fRep:  31.10  fDist:   8.51  rmsd:   0.09  nViol:   26  nRep:  104
# temp: 276.01  fRep:  34.94  fDist:   6.70  rmsd:   0.08  nViol:   26  nRep:  112
# temp: 280.32  fRep:  38.96  fDist:   2.74  rmsd:   0.05  nViol:   24  nRep:  111
# temp: 273.17  fRep:  34.78  fDist:   8.93  rmsd:   0.09  nViol:   22  nRep:  104
# temp: 264.90  fRep:  37.61  fDist:   8.14  rmsd:   0.09  nViol:   28  nRep:  100
# temp: 289.89  fRep:  36.60  fDist:   8.81  rmsd:   0.09  nViol:   30  nRep:  100
# temp: 267.33  fRep:  35.30  fDist:  10.11  rmsd:   0.10  nViol:   30  nRep:  104
# temp: 249.53  fRep:  32.63  fDist:  11.19  rmsd:   0.11  nViol:   32  nRep:   90
# temp: 247.25  fRep:  34.25  fDist:  11.78  rmsd:   0.11  nViol:   30  nRep:   99
# temp: 255.12  fRep:  37.52  fDist:   8.24  rmsd:   0.09  nViol:   28  nRep:  102
# temp: 255.91  fRep:  39.80  fDist:   6.89  rmsd:   0.08  nViol:   28  nRep:  104
# temp: 253.27  fRep:  41.05  fDist:   3.81  rmsd:   0.06  nViol:   26  nRep:   92
# temp: 243.48  fRep:  36.40  fDist:  12.20  rmsd:   0.11  nViol:   40  nRep:  109
# temp: 241.13  fRep:  40.05  fDist:  10.08  rmsd:   0.10  nViol:   32  nRep:  109
# temp: 246.41  fRep:  38.86  fDist:  11.95  rmsd:   0.11  nViol:   24  nRep:  105
# temp: 234.34  fRep:  43.25  fDist:   5.91  rmsd:   0.08  nViol:   24  nRep:  100
# temp: 231.49  fRep:  42.37  fDist:   4.46  rmsd:   0.07  nViol:   28  nRep:  111
# temp: 222.48  fRep:  42.39  fDist:   4.89  rmsd:   0.07  nViol:   24  nRep:   94
# temp: 231.39  fRep:  39.47  fDist:   7.88  rmsd:   0.09  nViol:   32  nRep:   96
# temp: 206.39  fRep:  43.20  fDist:   7.72  rmsd:   0.09  nViol:   32  nRep:  109
# temp: 230.92  fRep:  41.22  fDist:   7.32  rmsd:   0.09  nViol:   32  nRep:  117
# temp: 213.83  fRep:  46.64  fDist:   5.93  rmsd:   0.08  nViol:   24  nRep:  102
# temp: 224.74  fRep:  41.23  fDist:   9.84  rmsd:   0.10  nViol:   32  nRep:   94
# temp: 219.82  fRep:  40.07  fDist:  11.19  rmsd:   0.11  nViol:   38  nRep:   99
# temp: 206.27  fRep:  41.18  fDist:  11.09  rmsd:   0.11  nViol:   34  nRep:   96
# temp: 229.12  fRep:  44.24  fDist:   9.66  rmsd:   0.10  nViol:   34  nRep:   88
# temp: 199.06  fRep:  45.63  fDist:   8.50  rmsd:   0.09  nViol:   34  nRep:  100
# temp: 202.70  fRep:  42.36  fDist:  13.50  rmsd:   0.12  nViol:   38  nRep:   89
# temp: 198.83  fRep:  50.04  fDist:   4.96  rmsd:   0.07  nViol:   28  nRep:  106
# temp: 199.30  fRep:  47.78  fDist:   6.84  rmsd:   0.08  nViol:   30  nRep:   98
# temp: 203.02  fRep:  45.48  fDist:   7.76  rmsd:   0.09  nViol:   36  nRep:  102
# temp: 192.32  fRep:  47.68  fDist:   7.45  rmsd:   0.09  nViol:   34  nRep:   89
# temp: 197.85  fRep:  47.85  fDist:   9.12  rmsd:   0.10  nViol:   32  nRep:  105
# temp: 198.26  fRep:  45.61  fDist:  11.59  rmsd:   0.11  nViol:   34  nRep:  100
# temp: 184.07  fRep:  47.04  fDist:  11.94  rmsd:   0.11  nViol:   28  nRep:   98
# temp: 174.11  fRep:  52.51  fDist:   7.81  rmsd:   0.09  nViol:   32  nRep:   96
# temp: 175.16  fRep:  54.34  fDist:   8.72  rmsd:   0.09  nViol:   26  nRep:  113
# temp: 176.72  fRep:  53.36  fDist:   9.12  rmsd:   0.10  nViol:   26  nRep:   94
# temp: 176.82  fRep:  53.78  fDist:   4.15  rmsd:   0.06  nViol:   30  nRep:   94
# temp: 183.81  fRep:  51.10  fDist:   7.43  rmsd:   0.09  nViol:   34  nRep:   91
# temp: 164.31  fRep:  50.32  fDist:   9.36  rmsd:   0.10  nViol:   32  nRep:   96
# temp: 183.90  fRep:  52.71  fDist:   6.67  rmsd:   0.08  nViol:   38  nRep:   99
# temp: 161.98  fRep:  50.82  fDist:   9.98  rmsd:   0.10  nViol:   36  nRep:   99
# temp: 173.98  fRep:  52.68  fDist:   9.84  rmsd:   0.10  nViol:   32  nRep:  100
# temp: 162.28  fRep:  53.43  fDist:   8.95  rmsd:   0.09  nViol:   32  nRep:   96
# temp: 170.53  fRep:  52.65  fDist:   8.41  rmsd:   0.09  nViol:   28  nRep:   96
# temp: 168.92  fRep:  51.43  fDist:  11.03  rmsd:   0.11  nViol:   36  nRep:  100
# temp: 162.01  fRep:  53.22  fDist:   8.16  rmsd:   0.09  nViol:   36  nRep:  104
# temp: 154.76  fRep:  53.09  fDist:   9.53  rmsd:   0.10  nViol:   40  nRep:   94
# temp: 157.97  fRep:  52.12  fDist:   9.04  rmsd:   0.10  nViol:   36  nRep:   98
# temp: 155.59  fRep:  52.77  fDist:   8.03  rmsd:   0.09  nViol:   32  nRep:  104
# temp: 147.84  fRep:  53.18  fDist:   9.88  rmsd:   0.10  nViol:   30  nRep:  101
# temp: 154.42  fRep:  53.47  fDist:   8.98  rmsd:   0.09  nViol:   34  nRep:  108
# temp: 145.14  fRep:  53.65  fDist:   8.35  rmsd:   0.09  nViol:   34  nRep:   96
# temp: 143.66  fRep:  53.72  fDist:   8.34  rmsd:   0.09  nViol:   32  nRep:   97
# temp: 143.84  fRep:  51.99  fDist:  11.70  rmsd:   0.11  nViol:   36  nRep:   99
# temp: 138.27  fRep:  54.88  fDist:   8.21  rmsd:   0.09  nViol:   32  nRep:   97
# temp: 149.71  fRep:  57.65  fDist:   6.06  rmsd:   0.08  nViol:   36  nRep:   99
# temp: 133.42  fRep:  55.05  fDist:   9.75  rmsd:   0.10  nViol:   28  nRep:  101
# temp: 138.63  fRep:  56.50  fDist:   7.40  rmsd:   0.09  nViol:   36  nRep:  100
# temp: 138.13  fRep:  56.10  fDist:   8.23  rmsd:   0.09  nViol:   36  nRep:   91
# temp: 137.34  fRep:  59.22  fDist:   6.71  rmsd:   0.08  nViol:   34  nRep:  104
# temp: 128.75  fRep:  54.57  fDist:  10.02  rmsd:   0.10  nViol:   36  nRep:   84
# temp: 140.05  fRep:  55.22  fDist:   9.27  rmsd:   0.10  nViol:   32  nRep:   95
# temp: 131.19  fRep:  55.13  fDist:  10.06  rmsd:   0.10  nViol:   36  nRep:   92
# temp: 132.52  fRep:  55.78  fDist:   8.82  rmsd:   0.09  nViol:   34  nRep:  100
# temp: 125.78  fRep:  54.85  fDist:  10.71  rmsd:   0.10  nViol:   34  nRep:   96
# temp: 120.34  fRep:  56.49  fDist:   9.57  rmsd:   0.10  nViol:   34  nRep:  101
# temp: 119.22  fRep:  58.22  fDist:   6.53  rmsd:   0.08  nViol:   32  nRep:   96
# temp: 123.01  fRep:  54.74  fDist:  10.96  rmsd:   0.10  nViol:   36  nRep:   91
# temp: 120.74  fRep:  57.19  fDist:   7.01  rmsd:   0.08  nViol:   34  nRep:   88
# temp: 112.82  fRep:  56.76  fDist:  11.05  rmsd:   0.11  nViol:   34  nRep:   97
# temp: 115.63  fRep:  53.13  fDist:  11.82  rmsd:   0.11  nViol:   38  nRep:   91
# temp: 116.25  fRep:  55.88  fDist:   9.98  rmsd:   0.10  nViol:   30  nRep:   90
# temp: 114.92  fRep:  58.62  fDist:   6.29  rmsd:   0.08  nViol:   32  nRep:   98
# temp: 106.66  fRep:  54.13  fDist:  12.96  rmsd:   0.11  nViol:   32  nRep:   92
# temp: 101.06  fRep:  56.29  fDist:  11.03  rmsd:   0.11  nViol:   32  nRep:   95
# temp: 104.85  fRep:  56.47  fDist:   9.90  rmsd:   0.10  nViol:   28  nRep:   94
# temp: 114.06  fRep:  59.24  fDist:   7.60  rmsd:   0.09  nViol:   34  nRep:   97
# temp: 103.91  fRep:  55.68  fDist:   9.66  rmsd:   0.10  nViol:   32  nRep:   82
# temp:  96.33  fRep:  57.33  fDist:   9.20  rmsd:   0.10  nViol:   38  nRep:   92
# temp: 106.63  fRep:  57.14  fDist:   8.76  rmsd:   0.09  nViol:   34  nRep:   99
# temp: 101.47  fRep:  57.56  fDist:   9.47  rmsd:   0.10  nViol:   34  nRep:   92
# temp: 102.59  fRep:  60.12  fDist:   5.64  rmsd:   0.08  nViol:   34  nRep:  102
# temp: 106.28  fRep:  58.82  fDist:   6.76  rmsd:   0.08  nViol:   36  nRep:   96
# temp: 108.69  fRep:  59.92  fDist:   6.22  rmsd:   0.08  nViol:   36  nRep:   93
# temp:  95.27  fRep:  57.57  fDist:   9.08  rmsd:   0.10  nViol:   36  nRep:   96
# temp:  94.20  fRep:  56.99  fDist:  10.61  rmsd:   0.10  nViol:   34  nRep:   94
# temp: 100.75  fRep:  53.93  fDist:  12.45  rmsd:   0.11  nViol:   34  nRep:   92
# temp:  91.21  fRep:  57.57  fDist:   8.78  rmsd:   0.09  nViol:   36  nRep:   86
# temp:  94.30  fRep:  57.76  fDist:   8.73  rmsd:   0.09  nViol:   38  nRep:   89
# temp:  92.66  fRep:  55.81  fDist:  10.49  rmsd:   0.10  nViol:   34  nRep:   95
# temp:  88.07  fRep:  55.46  fDist:  10.52  rmsd:   0.10  nViol:   32  nRep:   97
# temp:  89.61  fRep:  56.84  fDist:  10.23  rmsd:   0.10  nViol:   32  nRep:   99
# temp:  86.26  fRep:  56.42  fDist:  10.82  rmsd:   0.10  nViol:   30  nRep:   91
# temp:  84.67  fRep:  55.69  fDist:  11.84  rmsd:   0.11  nViol:   34  nRep:   92
# temp:  87.75  fRep:  58.94  fDist:   7.79  rmsd:   0.09  nViol:   30  nRep:   90
# temp:  83.45  fRep:  57.00  fDist:   9.65  rmsd:   0.10  nViol:   36  nRep:   88
# temp:  81.80  fRep:  55.55  fDist:  12.33  rmsd:   0.11  nViol:   28  nRep:   91
# temp:  80.64  fRep:  60.84  fDist:   6.20  rmsd:   0.08  nViol:   32  nRep:   97
# temp:  82.86  fRep:  57.82  fDist:   9.43  rmsd:   0.10  nViol:   32  nRep:   95
# temp:  83.89  fRep:  57.00  fDist:  10.55  rmsd:   0.10  nViol:   36  nRep:   98
# temp:  85.16  fRep:  56.34  fDist:  10.77  rmsd:   0.10  nViol:   34  nRep:   97
# temp:  82.22  fRep:  55.57  fDist:  11.68  rmsd:   0.11  nViol:   38  nRep:   90
# temp:  80.56  fRep:  58.90  fDist:   8.83  rmsd:   0.09  nViol:   30  nRep:  103
# temp:  68.31  fRep:  59.58  fDist:   8.37  rmsd:   0.09  nViol:   36  nRep:  102
# temp:  73.69  fRep:  62.51  fDist:   4.76  rmsd:   0.07  nViol:   30  nRep:   95
# temp:  72.43  fRep:  60.12  fDist:   7.50  rmsd:   0.09  nViol:   34  nRep:  102
# temp:  75.13  fRep:  58.92  fDist:   8.97  rmsd:   0.09  nViol:   38  nRep:  101
# temp:  72.35  fRep:  58.17  fDist:   9.26  rmsd:   0.10  nViol:   30  nRep:  104
# temp:  73.85  fRep:  58.68  fDist:   7.97  rmsd:   0.09  nViol:   30  nRep:   94
# temp:  72.21  fRep:  58.42  fDist:   8.79  rmsd:   0.09  nViol:   38  nRep:  100
# temp:  67.65  fRep:  60.07  fDist:   7.23  rmsd:   0.09  nViol:   38  nRep:  103
# temp:  70.99  fRep:  59.12  fDist:   7.39  rmsd:   0.09  nViol:   36  nRep:   95
# temp:  69.97  fRep:  57.37  fDist:   9.44  rmsd:   0.10  nViol:   32  nRep:   99
# temp:  66.53  fRep:  58.97  fDist:   7.87  rmsd:   0.09  nViol:   28  nRep:   92
# temp:  64.27  fRep:  59.82  fDist:   8.15  rmsd:   0.09  nViol:   36  nRep:   99
# temp:  63.93  fRep:  60.33  fDist:   7.64  rmsd:   0.09  nViol:   32  nRep:   97
# temp:  63.22  fRep:  62.85  fDist:   4.82  rmsd:   0.07  nViol:   34  nRep:   98
# temp:  62.84  fRep:  55.64  fDist:  11.72  rmsd:   0.11  nViol:   36  nRep:   97
# temp:  67.63  fRep:  61.11  fDist:   6.37  rmsd:   0.08  nViol:   30  nRep:  101
# temp:  64.76  fRep:  60.82  fDist:   6.75  rmsd:   0.08  nViol:   34  nRep:  108
# temp:  66.80  fRep:  60.88  fDist:   6.66  rmsd:   0.08  nViol:   34  nRep:  105
# temp:  66.88  fRep:  59.28  fDist:   7.51  rmsd:   0.09  nViol:   32  nRep:  100
# temp:  60.72  fRep:  59.16  fDist:   7.89  rmsd:   0.09  nViol:   28  nRep:   94
# temp:  57.57  fRep:  58.75  fDist:   8.94  rmsd:   0.09  nViol:   32  nRep:  103
# temp:  60.25  fRep:  58.44  fDist:   9.29  rmsd:   0.10  nViol:   34  nRep:   99
# temp:  57.71  fRep:  56.43  fDist:  11.10  rmsd:   0.11  nViol:   34  nRep:  102
# temp:  55.83  fRep:  57.55  fDist:   9.81  rmsd:   0.10  nViol:   32  nRep:   97
# temp:  58.22  fRep:  59.52  fDist:   8.09  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  50.97  fRep:  57.49  fDist:  11.08  rmsd:   0.11  nViol:   34  nRep:   98
# temp:  55.03  fRep:  59.74  fDist:   8.69  rmsd:   0.09  nViol:   32  nRep:   92
# temp:  51.53  fRep:  59.08  fDist:   8.73  rmsd:   0.09  nViol:   32  nRep:   95
# temp:  49.77  fRep:  57.77  fDist:  10.21  rmsd:   0.10  nViol:   28  nRep:   89
# temp:  54.11  fRep:  58.38  fDist:   9.91  rmsd:   0.10  nViol:   32  nRep:   87
# temp:  55.92  fRep:  58.34  fDist:   9.25  rmsd:   0.10  nViol:   36  nRep:   88
# temp:  52.22  fRep:  59.01  fDist:   8.37  rmsd:   0.09  nViol:   32  nRep:   90
# temp:  56.32  fRep:  58.41  fDist:   9.17  rmsd:   0.10  nViol:   40  nRep:   88
# temp:  51.40  fRep:  58.26  fDist:   9.17  rmsd:   0.10  nViol:   34  nRep:   93
# temp:  51.03  fRep:  58.01  fDist:   9.89  rmsd:   0.10  nViol:   34  nRep:   91
# temp:  46.91  fRep:  59.36  fDist:   8.28  rmsd:   0.09  nViol:   36  nRep:   80
# temp:  50.98  fRep:  60.36  fDist:   7.57  rmsd:   0.09  nViol:   36  nRep:   92
# temp:  50.80  fRep:  61.31  fDist:   6.11  rmsd:   0.08  nViol:   34  nRep:   83
# temp:  47.38  fRep:  59.25  fDist:   8.21  rmsd:   0.09  nViol:   38  nRep:   90
# temp:  44.03  fRep:  62.20  fDist:   5.56  rmsd:   0.07  nViol:   36  nRep:   89
# temp:  45.87  fRep:  60.64  fDist:   7.18  rmsd:   0.08  nViol:   34  nRep:   94
# temp:  46.44  fRep:  58.44  fDist:   8.93  rmsd:   0.09  nViol:   32  nRep:   88
# temp:  44.03  fRep:  58.91  fDist:   8.69  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  45.91  fRep:  58.22  fDist:   9.60  rmsd:   0.10  nViol:   34  nRep:   88
# temp:  43.93  fRep:  61.81  fDist:   5.35  rmsd:   0.07  nViol:   34  nRep:   88
# temp:  45.81  fRep:  60.62  fDist:   6.89  rmsd:   0.08  nViol:   30  nRep:   91
# temp:  39.72  fRep:  60.17  fDist:   8.20  rmsd:   0.09  nViol:   28  nRep:   91
# temp:  43.40  fRep:  59.14  fDist:   8.77  rmsd:   0.09  nViol:   34  nRep:   89
# temp:  40.45  fRep:  61.22  fDist:   6.92  rmsd:   0.08  nViol:   32  nRep:   85
# temp:  39.20  fRep:  60.41  fDist:   7.73  rmsd:   0.09  nViol:   34  nRep:   89
# temp:  42.71  fRep:  59.19  fDist:   8.58  rmsd:   0.09  nViol:   36  nRep:   90
# temp:  37.72  fRep:  59.90  fDist:   8.47  rmsd:   0.09  nViol:   32  nRep:   91
# temp:  39.85  fRep:  60.06  fDist:   7.79  rmsd:   0.09  nViol:   32  nRep:   90
# temp:  41.11  fRep:  59.73  fDist:   8.24  rmsd:   0.09  nViol:   36  nRep:   87
# temp:  41.62  fRep:  58.63  fDist:   9.85  rmsd:   0.10  nViol:   36  nRep:   96
# temp:  39.78  fRep:  60.45  fDist:   7.41  rmsd:   0.09  nViol:   32  nRep:  110
# temp:  37.66  fRep:  58.95  fDist:   8.75  rmsd:   0.09  nViol:   30  nRep:   97
# temp:  36.32  fRep:  57.33  fDist:  10.75  rmsd:   0.10  nViol:   38  nRep:  101
# temp:  37.58  fRep:  60.89  fDist:   6.75  rmsd:   0.08  nViol:   32  nRep:   96
# temp:  37.25  fRep:  61.10  fDist:   6.57  rmsd:   0.08  nViol:   32  nRep:  103
# temp:  36.10  fRep:  60.37  fDist:   7.55  rmsd:   0.09  nViol:   32  nRep:  102
# temp:  38.47  fRep:  59.77  fDist:   7.83  rmsd:   0.09  nViol:   34  nRep:  101
# temp:  37.84  fRep:  59.94  fDist:   7.53  rmsd:   0.09  nViol:   34  nRep:  102
# temp:  34.59  fRep:  60.55  fDist:   7.37  rmsd:   0.09  nViol:   34  nRep:  101
# temp:  36.77  fRep:  59.58  fDist:   8.10  rmsd:   0.09  nViol:   36  nRep:   93
# temp:  37.10  fRep:  60.86  fDist:   7.07  rmsd:   0.08  nViol:   30  nRep:   99
# temp:  32.99  fRep:  59.56  fDist:   8.17  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  33.32  fRep:  60.65  fDist:   7.24  rmsd:   0.09  nViol:   30  nRep:  107
# temp:  34.28  fRep:  58.55  fDist:   9.62  rmsd:   0.10  nViol:   30  nRep:  106
# temp:  35.11  fRep:  58.26  fDist:   9.72  rmsd:   0.10  nViol:   32  nRep:  101
# temp:  32.63  fRep:  59.97  fDist:   8.35  rmsd:   0.09  nViol:   34  nRep:  105
# temp:  33.38  fRep:  60.68  fDist:   7.15  rmsd:   0.08  nViol:   32  nRep:  112
# temp:  31.32  fRep:  59.26  fDist:   8.49  rmsd:   0.09  nViol:   36  nRep:  105
# temp:  32.08  fRep:  61.78  fDist:   6.23  rmsd:   0.08  nViol:   34  nRep:   97
# temp:  30.69  fRep:  60.92  fDist:   6.94  rmsd:   0.08  nViol:   32  nRep:   95
# temp:  32.18  fRep:  60.37  fDist:   7.62  rmsd:   0.09  nViol:   36  nRep:   91
# temp:  30.41  fRep:  60.95  fDist:   6.88  rmsd:   0.08  nViol:   36  nRep:   98
# temp:  29.80  fRep:  58.55  fDist:   9.48  rmsd:   0.10  nViol:   30  nRep:  100
# temp:  27.93  fRep:  60.75  fDist:   7.29  rmsd:   0.09  nViol:   36  nRep:  102
# temp:  29.80  fRep:  60.95  fDist:   7.05  rmsd:   0.08  nViol:   34  nRep:  108
# temp:  28.09  fRep:  60.50  fDist:   7.39  rmsd:   0.09  nViol:   34  nRep:  103
# temp:  27.52  fRep:  61.24  fDist:   6.80  rmsd:   0.08  nViol:   36  nRep:   99
# temp:  27.31  fRep:  59.35  fDist:   8.61  rmsd:   0.09  nViol:   34  nRep:   94
# temp:  24.67  fRep:  59.73  fDist:   8.57  rmsd:   0.09  nViol:   34  nRep:   87
# temp:  26.24  fRep:  60.07  fDist:   7.83  rmsd:   0.09  nViol:   32  nRep:  100
# temp:  25.92  fRep:  59.34  fDist:   8.92  rmsd:   0.09  nViol:   30  nRep:   93
# temp:  27.78  fRep:  59.30  fDist:   8.66  rmsd:   0.09  nViol:   36  nRep:   96
# temp:  27.39  fRep:  59.44  fDist:   8.65  rmsd:   0.09  nViol:   30  nRep:  105
# temp:  27.29  fRep:  60.42  fDist:   8.00  rmsd:   0.09  nViol:   34  nRep:  100
# temp:  25.88  fRep:  60.54  fDist:   7.74  rmsd:   0.09  nViol:   34  nRep:  104
# temp:  24.54  fRep:  60.42  fDist:   7.73  rmsd:   0.09  nViol:   36  nRep:   97
# temp:  26.06  fRep:  61.15  fDist:   6.86  rmsd:   0.08  nViol:   36  nRep:   95
# temp:  24.99  fRep:  60.50  fDist:   7.41  rmsd:   0.09  nViol:   34  nRep:   91
# temp:  24.86  fRep:  61.39  fDist:   6.92  rmsd:   0.08  nViol:   38  nRep:   94
# temp:  24.17  fRep:  61.05  fDist:   6.90  rmsd:   0.08  nViol:   34  nRep:   96
# temp:  24.26  fRep:  60.81  fDist:   7.02  rmsd:   0.08  nViol:   32  nRep:   96
# temp:  26.57  fRep:  60.04  fDist:   8.20  rmsd:   0.09  nViol:   32  nRep:   94
# temp:  23.00  fRep:  61.02  fDist:   7.39  rmsd:   0.09  nViol:   34  nRep:   92
# temp:  23.42  fRep:  60.13  fDist:   7.85  rmsd:   0.09  nViol:   36  nRep:   93
# temp:  22.56  fRep:  60.17  fDist:   7.91  rmsd:   0.09  nViol:   32  nRep:   89
# temp:  22.08  fRep:  59.49  fDist:   8.52  rmsd:   0.09  nViol:   36  nRep:   87
# temp:  21.92  fRep:  60.66  fDist:   7.35  rmsd:   0.09  nViol:   36  nRep:   86
# temp:  22.11  fRep:  61.86  fDist:   6.07  rmsd:   0.08  nViol:   34  nRep:   88
# temp:  21.93  fRep:  61.03  fDist:   7.16  rmsd:   0.08  nViol:   34  nRep:   90
# temp:  22.27  fRep:  60.69  fDist:   7.36  rmsd:   0.09  nViol:   34  nRep:   88
# temp:  22.63  fRep:  60.36  fDist:   7.78  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  21.47  fRep:  61.40  fDist:   6.75  rmsd:   0.08  nViol:   32  nRep:   89
# temp:  21.55  fRep:  60.62  fDist:   7.54  rmsd:   0.09  nViol:   34  nRep:   89
# temp:  20.12  fRep:  60.69  fDist:   7.44  rmsd:   0.09  nViol:   36  nRep:   87
# temp:  18.85  fRep:  60.95  fDist:   7.37  rmsd:   0.09  nViol:   34  nRep:   84
# temp:  21.47  fRep:  61.38  fDist:   6.89  rmsd:   0.08  nViol:   34  nRep:   86
# temp:  18.66  fRep:  61.81  fDist:   6.44  rmsd:   0.08  nViol:   34  nRep:   88
# temp:  18.35  fRep:  60.35  fDist:   7.69  rmsd:   0.09  nViol:   34  nRep:   89
# temp:  19.22  fRep:  61.63  fDist:   6.38  rmsd:   0.08  nViol:   30  nRep:   91
# temp:  18.79  fRep:  61.24  fDist:   6.82  rmsd:   0.08  nViol:   32  nRep:   89
# temp:  18.66  fRep:  60.25  fDist:   7.84  rmsd:   0.09  nViol:   30  nRep:   92
# temp:  18.95  fRep:  61.59  fDist:   6.62  rmsd:   0.08  nViol:   28  nRep:   93
# temp:  18.71  fRep:  60.46  fDist:   7.65  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  18.19  fRep:  59.31  fDist:   8.97  rmsd:   0.09  nViol:   36  nRep:   84
# temp:  17.18  fRep:  60.64  fDist:   7.53  rmsd:   0.09  nViol:   30  nRep:   92
# temp:  16.35  fRep:  60.11  fDist:   7.97  rmsd:   0.09  nViol:   32  nRep:   91
# temp:  17.49  fRep:  59.82  fDist:   8.42  rmsd:   0.09  nViol:   30  nRep:   94
# temp:  17.40  fRep:  62.33  fDist:   5.85  rmsd:   0.08  nViol:   30  nRep:   92
# temp:  17.73  fRep:  60.66  fDist:   7.56  rmsd:   0.09  nViol:   32  nRep:   93
# temp:  16.38  fRep:  61.08  fDist:   7.22  rmsd:   0.08  nViol:   32  nRep:   88
# temp:  16.11  fRep:  60.64  fDist:   7.78  rmsd:   0.09  nViol:   34  nRep:   97
# temp:  17.20  fRep:  59.58  fDist:   8.68  rmsd:   0.09  nViol:   32  nRep:   93
# temp:  16.36  fRep:  61.31  fDist:   6.85  rmsd:   0.08  nViol:   30  nRep:   97
# temp:  16.78  fRep:  60.98  fDist:   7.13  rmsd:   0.08  nViol:   30  nRep:   94
# temp:  16.36  fRep:  59.94  fDist:   8.30  rmsd:   0.09  nViol:   30  nRep:   89
# temp:  15.45  fRep:  61.91  fDist:   6.40  rmsd:   0.08  nViol:   30  nRep:   96
# temp:  14.39  fRep:  60.22  fDist:   8.07  rmsd:   0.09  nViol:   32  nRep:   95
# temp:  15.33  fRep:  60.75  fDist:   7.44  rmsd:   0.09  nViol:   30  nRep:   91
# temp:  14.79  fRep:  61.08  fDist:   7.16  rmsd:   0.08  nViol:   34  nRep:   96
# temp:  14.91  fRep:  61.34  fDist:   6.74  rmsd:   0.08  nViol:   30  nRep:   96
# temp:  13.74  fRep:  60.92  fDist:   7.21  rmsd:   0.08  nViol:   34  nRep:   95
# temp:  13.61  fRep:  62.20  fDist:   6.15  rmsd:   0.08  nViol:   34  nRep:   90
# temp:  14.20  fRep:  60.42  fDist:   7.82  rmsd:   0.09  nViol:   32  nRep:   94
# temp:  14.08  fRep:  61.43  fDist:   6.83  rmsd:   0.08  nViol:   34  nRep:   94
# temp:  13.55  fRep:  61.14  fDist:   6.99  rmsd:   0.08  nViol:   30  nRep:   91
# temp:  13.89  fRep:  61.00  fDist:   7.25  rmsd:   0.09  nViol:   34  nRep:   94
# temp:  13.30  fRep:  61.93  fDist:   6.45  rmsd:   0.08  nViol:   30  nRep:   96
# temp:  13.17  fRep:  61.27  fDist:   7.32  rmsd:   0.09  nViol:   34  nRep:   94
# temp:  13.79  fRep:  60.96  fDist:   7.44  rmsd:   0.09  nViol:   34  nRep:   89
# temp:  12.33  fRep:  61.19  fDist:   7.16  rmsd:   0.08  nViol:   34  nRep:   94
# temp:  12.96  fRep:  61.66  fDist:   6.58  rmsd:   0.08  nViol:   34  nRep:   93
# temp:  11.94  fRep:  61.55  fDist:   6.77  rmsd:   0.08  nViol:   32  nRep:   96
# temp:  12.22  fRep:  61.57  fDist:   6.72  rmsd:   0.08  nViol:   30  nRep:  101
# temp:  12.13  fRep:  61.19  fDist:   7.05  rmsd:   0.08  nViol:   30  nRep:  100
# temp:  11.81  fRep:  60.67  fDist:   7.62  rmsd:   0.09  nViol:   32  nRep:  102
# temp:  11.31  fRep:  60.97  fDist:   7.35  rmsd:   0.09  nViol:   32  nRep:   97
# temp:  11.72  fRep:  61.11  fDist:   7.25  rmsd:   0.09  nViol:   34  nRep:   97
# temp:  11.73  fRep:  61.99  fDist:   6.35  rmsd:   0.08  nViol:   28  nRep:  100
# temp:  11.25  fRep:  61.17  fDist:   7.12  rmsd:   0.08  nViol:   30  nRep:  103
# temp:  10.99  fRep:  61.55  fDist:   6.74  rmsd:   0.08  nViol:   34  nRep:  102
# temp:  11.27  fRep:  60.90  fDist:   7.41  rmsd:   0.09  nViol:   32  nRep:  107
# temp:  12.19  fRep:  60.93  fDist:   7.38  rmsd:   0.09  nViol:   32  nRep:  103
# temp:  10.67  fRep:  60.71  fDist:   7.63  rmsd:   0.09  nViol:   30  nRep:  103
# temp:  10.45  fRep:  61.22  fDist:   7.15  rmsd:   0.08  nViol:   30  nRep:  101
# temp:  10.92  fRep:  61.24  fDist:   7.05  rmsd:   0.08  nViol:   32  nRep:  102
# temp:  10.64  fRep:  61.21  fDist:   7.04  rmsd:   0.08  nViol:   32  nRep:   97
# temp:  10.65  fRep:  60.69  fDist:   7.58  rmsd:   0.09  nViol:   30  nRep:  104
# temp:  10.32  fRep:  60.93  fDist:   7.35  rmsd:   0.09  nViol:   32  nRep:   95
# temp:   9.57  fRep:  61.43  fDist:   6.91  rmsd:   0.08  nViol:   30  nRep:   96
# temp:  10.29  fRep:  61.52  fDist:   6.78  rmsd:   0.08  nViol:   30  nRep:   96
#   0 [ 0.20520087 -1.65851092 -1.22661509]
#   1 [ 1.08607162 -0.96028478 -1.62993222]
#   2 [ 0.99018005  0.19357692 -1.37266362]
#   3 [ 0.0865592   0.43519146 -0.70549499]
#   4 [-0.91086565 -0.1410118  -0.42689665]
#   5 [-0.9199227  -1.27410923 -0.76779942]
#   6 [-0.32983592  1.53871077  1.1076514 ]
#   7 [-0.43189376  0.92811345  2.02139268]
#   8 [ 1.46846871 -3.44389056 -0.31445573]
#   9 [ 1.36574939 -1.16318291 -2.87608569]
#  10 [ 2.11908898  0.82966272 -1.27282171]
#  11 [-1.84955145  0.72380148 -0.35760617]
#  12 [-1.4915832  -2.15938059  0.03216639]
#  13 [ 0.67297598  2.76343217 -0.15718491]
#  14 [-0.11963909 -0.33882459  1.79354894]
#  15 [-1.00698927  0.79491226  3.19170343]
#  16 [-0.96427606  1.57123212  3.0141096 ]
#  17 [ 0.26284971  1.54653957 -0.03299423]
#  18 [ 0.72833657 -2.87942599 -1.24151084]
#  19 [-0.96092397  2.69344846  1.22148884]

# %% [markdown]
# ### Multi-scale repulsion scheme for whole genome structures

# %%
def load_ncc_file(file_path):
  """Load chromosome and contact data from NCC format file, as output from NucProcess"""
  
  if file_path.endswith('.gz'):
    import gzip
    file_obj = gzip.open(file_path)
  
  else:
    file_obj = open(file_path) 
  
  # Observations are treated individually in single-cell Hi-C,
  # i.e. no binning, so num_obs always 1 for each contact
  num_obs = 1  
    
  contact_dict = {}
  chromosomes = set()
    
  for line in file_obj:
    chr_a, f_start_a, f_end_a, start_a, end_a, strand_a, chr_b, f_start_b, f_end_b, start_b, end_b, strand_b, ambig_group, pair_id, swap_pair = line.split()
    
    if strand_a == '+':
      pos_a = int(f_start_a)
    else:
      pos_a = int(f_end_a)
    
    if strand_b == '+':
      pos_b = int(f_start_b)       
    else:
      pos_b = int(f_end_b)
 
    if chr_a > chr_b:
      chr_a, chr_b = chr_b, chr_a
      pos_a, pos_b = pos_b, pos_a
    
    if chr_a not in contact_dict:
      contact_dict[chr_a] = {}
      chromosomes.add(chr_a)
      
    if chr_b not in contact_dict[chr_a]:
      contact_dict[chr_a][chr_b] = [] 
      chromosomes.add(chr_b)
        
    contact_dict[chr_a][chr_b].append((pos_a, pos_b, num_obs, int(ambig_group)))
   
  file_obj.close()
  
  chromo_limits = {}
    
  for chr_a in contact_dict:
    for chr_b in contact_dict[chr_a]:
      contacts = numpy.array(contact_dict[chr_a][chr_b]).T
      contact_dict[chr_a][chr_b] = contacts
      
      seq_pos_a = contacts[1]
      seq_pos_b = contacts[2]
      
      min_a = min(seq_pos_a)
      max_a = max(seq_pos_a)
      min_b = min(seq_pos_b)
      max_b = max(seq_pos_b)
        
      if chr_a in chromo_limits:
        prev_min, prev_max = chromo_limits[chr_a]
        chromo_limits[chr_a] = [min(prev_min, min_a), max(prev_max, max_a)]
      else:
        chromo_limits[chr_a] = [min_a, max_a]
      
      if chr_b in chromo_limits:
        prev_min, prev_max = chromo_limits[chr_b]
        chromo_limits[chr_b] = [min(prev_min, min_b), max(prev_max, max_b)]
      else:
        chromo_limits[chr_b] = [min_b, max_b]
         
  chromosomes = sorted(chromosomes)      
        
  return chromosomes, chromo_limits, contact_dict

# %%
def export_pdb_coords(file_path, coords_dict, seq_pos_dict, particle_size, scale=1.0, extended=True):
  
  from numpy import array, uint32, float32

  alc = ' '
  ins = ' '
  prefix = 'HETATM'
  line_format = '%-80.80s\n'
  
  if extended:
    pdb_format = '%-6.6s%5.1d %4.4s%s%3.3s %s%4.1d%s   %8.3f%8.3f%8.3f%6.2f%6.2f          %2.2s  %10d\n'
    ter_format = '%-6.6s%5.1d      %s %s%4.1d%s                                                     %10d\n'
  else:
    pdb_format = '%-6.6s%5.1d %4.4s%s%3.3s %s%4.1d%s   %8.3f%8.3f%8.3f%6.2f%6.2f          %2.2s  \n'
    ter_format = '%-6.6s%5.1d      %s %s%4.1d%s                                                     \n'

  file_obj = open(file_path, 'w')
  write = file_obj.write
  
  chromosomes = list(seq_pos_dict.keys())
  num_models = len(coords_dict[chromosomes[0]])
  title = 'NucDynamics genome structure export'
  
  write(line_format % 'TITLE     %s' % title)
  write(line_format % 'REMARK 210') 
  write(line_format % 'REMARK 210 Atom type C is used for all particles')
  write(line_format % 'REMARK 210 Atom number increases every %s bases' % particle_size)
  write(line_format % 'REMARK 210 Residue code indicates chromosome')
  write(line_format % 'REMARK 210 Residue number represents which sequence Mb the atom is in')
  write(line_format % 'REMARK 210 Chain letter is different every chromosome, where Chr1=a, Chr2=b etc.')
  
  if extended:
    file_obj.write(line_format % 'REMARK 210 Extended PDB format with particle seq. pos. in last column')
  
  file_obj.write(line_format % 'REMARK 210')
  
  pos_chromo = {}
  
  for m in range(num_models):
    line = 'MODEL     %4d' % (m+1)
    write(line_format  % line)
    
    c = 0
    j = 1
    seqPrev = None
    for chromo in seq_pos_dict:
      
      if chromo.isdigit():
        idx = int(chromo) - 1
        chain_code = chr(ord('A')+idx)
      
      elif len(chromo) == 1:
        chain_code = chromo.upper()
        
      else:
        idx = chromosomes.index(chromo)
        chain_code = chr(ord('a')+idx)
      
      tlc = chromo
      while len(tlc) < 2:
        tlc = '_' + tlc
      
      if len(tlc) == 2:
        tlc = 'C' + tlc
      
      if len(tlc) > 3:
        tlc = tlc[:3]
      
      chromo_model_coords = coords_dict[chromo][m]
      
      if not len(coords):
        continue
      
      pos = seq_pos_dict[chromo]
      
      for i, seqPos in enumerate(pos):
        c += 1
 
        seqMb = int(seqPos//1e6) + 1
        
        if seqMb == seqPrev:
          j += 1
        else:
          j = 1
        
        el = 'C'
        a = 'C%d' % j
          
        aName = '%-3s' % a
        x, y, z = chromo_model_coords[i] #XYZ coordinates
         
        seqPrev = seqMb
        pos_chromo[c] = chromo
        
        if extended:
          line  = pdb_format % (prefix,c,aName,alc,tlc,chain_code,seqMb,ins,x,y,z,0.0,0.0,el,seqPos)
        else:
          line  = pdb_format % (prefix,c,aName,alc,tlc,chain_code,seqMb,ins,x,y,z,0.0,0.0,el)
          
        write(line)
 
    write(line_format  % 'ENDMDL')
 
  for i in range(c-2):
     if pos_chromo[i+1] == pos_chromo[i+2]:
       line = 'CONECT%5.1d%5.1d' % (i+1, i+2)
       write(line_format  % line)
 
  write(line_format  % 'END')
  file_obj.close()

# %%
def remove_isolated_contacts(contact_dict, threshold=int(2e6)):
  """
  Select only contacts which are within a given sequence separation of another
  contact, for the same chromosome pair
  """
    
  for chromoA in contact_dict:
    for chromoB in contact_dict[chromoA]:
      contacts = contact_dict[chromoA][chromoB]
      positions = numpy.array(contacts[:2], numpy.int32).T
      
      if len(positions): # Sometimes empty e.g. for MT, Y chromos 
        active_idx = getSupportedPairs(positions, numpy.int32(threshold))
        contact_dict[chromoA][chromoB] = contacts[:,active_idx]
     
  return contact_dict

# %%
def remove_violated_contacts(contact_dict, coords_dict, particle_seq_pos, particle_size, threshold=5.0):  
  """
  Remove contacts whith structure distances that exceed a given threshold
  """
  from numpy import int32
    
  for chr_a in contact_dict:
    for chr_b in contact_dict[chr_a]:
      contacts = contact_dict[chr_a][chr_b]
      
      contact_pos_a = contacts[0].astype(int32)
      contact_pos_b = contacts[1].astype(int32)
      
      coords_a = coords_dict[chr_a]
      coords_b = coords_dict[chr_b]

      struc_dists = []
 
      for m in range(len(coords_a)):
        coord_data_a = getInterpolatedCoords([chr_a], {chr_a:contact_pos_a}, particle_seq_pos, coords_a[m])
        coord_data_b = getInterpolatedCoords([chr_b], {chr_b:contact_pos_b}, particle_seq_pos, coords_b[m])
 
        deltas = coord_data_a - coord_data_b
        dists = numpy.sqrt((deltas*deltas).sum(axis=1))
        struc_dists.append(dists)
      
      # Average over all conformational models
      struc_dists = numpy.array(struc_dists).T.mean(axis=1)
      
      # Select contacts with distances below distance threshold
      indices = (struc_dists < threshold).nonzero()[0]
      contact_dict[chr_a][chr_b] = contacts[:,indices]
        
  return contact_dict

# %%
def get_random_coords(pos_dict, chromosomes, num_models, radius=10.0):
  """
  Get random, uniformly sampled coorinate positions, restricted to
  a sphere of given radius
  """
    
  from random import uniform
  from numpy import empty
    
  num_particles = sum([len(pos_dict[chromo]) for chromo in chromosomes])
  coords = empty((num_models, num_particles, 3))
  r2 = radius*radius
    
  for m in range(num_models):
    
    for i in range(num_particles):
      x = y = z = radius

      while x*x + y*y + z*z >= r2:
        x = radius * (2*uniform(0,1) - 1)
        y = radius * (2*uniform(0,1) - 1)
        z = radius * (2*uniform(0,1) - 1)
      
      coords[m,i] = [x,y,z]

  return coords

# %%
def pack_chromo_coords(coords_dict, chromosomes):
  """
  Place chromosome 3D coordinates stored in a dictionary keyed by
  chromosome name into a single, ordered array. The chromosomes argument
  is required to set the correct array storage order.
  """
  
  from numpy import empty

  chromo_num_particles = [len(coords_dict[chromo][0]) for chromo in chromosomes]
  n_particles = sum(chromo_num_particles)
  n_models = len(coords_dict[chromosomes[0]])  
  coords = empty((n_models, n_particles, 3), float)
  
  j = 0
  for i, chromo in enumerate(chromosomes):
    span = chromo_num_particles[i]
    coords[:,j:j+span] = coords_dict[chromo]
    j += span
      
  return coords

# %%
def unpack_chromo_coords(coords, chromosomes, seq_pos_dict):
  """
  Exctract coords for multiple chromosomes stored in a single array into
  a dictionary, keyed by chromosome name. The chromosomes argument is required
  to get the correct array storage order.
  """

  chromo_num_particles = [len(seq_pos_dict[chromo]) for chromo in chromosomes]
  n_seq_pos = sum(chromo_num_particles)
  n_models, n_particles, dims = coords.shape

  if n_seq_pos != n_particles:
    msg = 'Model coordinates must be an array of num models x %d' % (n_seq_pos,)
    raise(Exception(msg))  
  
  coords_dict = {}
        
  j = 0
  for i, chromo in enumerate(chromosomes):
    span = chromo_num_particles[i]
    coords_dict[chromo] = coords[:,j:j+span] # all models, slice
    j += span
 
  return coords_dict

# %%
def anneal_genome(chromosomes, contact_dict, num_models, particle_size,
                  general_calc_params, anneal_params,
                  prev_seq_pos_dict=None, start_coords=None):
    """
    Use chromosome contact data to generate distance restraints and then
    apply a simulated annealing protocul to generate/refine coordinates.
    Starting coordinates may be random of from a previous (e.g. lower
    resolution) stage.
    """
    
    from numpy import int32, ones, empty
    from math import log, exp, atan, pi
    import gc
    
    random.seed(general_calc_params['random_seed'])
    particle_size = int32(particle_size)
    
    # Calculate distance restrains from contact data   
    restraint_dict, seq_pos_dict = calc_restraints(chromosomes, contact_dict, particle_size,
                                                   scale=1.0, exponent=general_calc_params['dist_power_law'],
                                                   lower=general_calc_params['contact_dist_lower'],
                                                   upper=general_calc_params['contact_dist_upper'])
    
    # Concatenate chromosomal data into a single array of particle restraints
    # for structure calculation. Add backbone restraints between seq. adjasent particles.
    restraint_indices, restraint_dists = concatenate_restraints(restraint_dict, seq_pos_dict, particle_size,
                                                                general_calc_params['backbone_dist_lower'],
                                                                general_calc_params['backbone_dist_upper'])
 
    # Setup starting structure
    if (start_coords is None) or (prev_seq_pos_dict is None):
      coords = get_random_coords(seq_pos_dict, chromosomes, num_models,
                                 general_calc_params['random_radius'])
      
      num_coords = coords.shape[1]
            
    else:
      # Convert starting coord dict into single array
      coords = pack_chromo_coords(start_coords, chromosomes)
      num_coords = sum([len(seq_pos_dict[c]) for c in chromosomes])
        
      if coords.shape[1] != num_coords: # Change of particle_size
        interp_coords = empty((num_models, num_coords, 3))
        
        for m in range(num_models): # Starting coords interpolated from previous particle positions
          interp_coords[m] = getInterpolatedCoords(chromosomes, seq_pos_dict, prev_seq_pos_dict, coords[m])
        
        coords = interp_coords
        
    # Equal unit masses and radii for all particles
    masses = ones(num_coords,  float)
    radii = ones(num_coords,  float)
    
    # Ambiguiity strides not used here, so set to 1
    num_restraints = len(restraint_indices)
    ambiguity = ones(num_restraints,  int32)
        
    # Below will be set to restrict memory allocation in the repusion list
    # (otherwise all vs all can be huge)
    n_rep_max = int32(0)
    
    # Annealing parameters
    temp_start = anneal_params['temp_start']
    temp_end = anneal_params['temp_end']
    temp_steps = anneal_params['temp_steps']
    
    # Setup annealig schedule: setup temps and repulsive terms
    adj = 1.0 / atan(10.0)
    decay = log(temp_start/temp_end)    
    anneal_schedule = []
    
    for step in range(temp_steps):
      frac = step/float(temp_steps)
    
      # exponential temp decay
      temp = temp_start * exp(-decay*frac)
    
      # sigmoidal repusion scheme
      repulse = 0.5 + adj * atan(frac*20.0-10) / pi 
      
      anneal_schedule.append((temp, repulse))  
        
    # Paricle dynamics parameters
    # (these need not be fixed for all stages, but are for simplicity)    
    dyn_steps = anneal_params['dynamics_steps']
    time_step = anneal_params['time_step']
       
    # Update coordinates in the annealing schedule
    time_taken = 0.0
    
    for m in range(num_models): # For each repeat calculation
      model_coords = coords[m]
        
      for temp, repulse in anneal_schedule:
        gc.collect() # Try to free some memory
        
        # Update coordinates for this temp
        dt, n_rep_max = runDynamics(model_coords, masses, radii, restraint_indices, restraint_dists,
                                    ambiguity, temp, time_step, dyn_steps, repulse, nRepMax=n_rep_max)
      
        n_rep_max = int32(1.05 * n_rep_max) # Base on num in prev cycle, plus an overhead
        time_taken += dt
  
      # Center
      model_coords -= model_coords.mean(axis=0)
      
      # Update
      coords[m] = model_coords
    
    # Convert from single coord array to dict keyed by chromosome
    coords_dict = unpack_chromo_coords(coords, chromosomes, seq_pos_dict)
    
    return coords_dict, seq_pos_dict

# %%
from time import time

# Number of alternative conformations to generate from repeat calculations
# with different random starting coordinates
num_models = 2  

# Parameters to setup restraints and starting coords
general_calc_params = {'dist_power_law':-0.33, 
                       'contact_dist_lower':0.8, 'contact_dist_upper':1.2,
                       'backbone_dist_lower':0.1, 'backbone_dist_upper':1.1,
                       'random_seed':int(time()), 'random_radius':10.0}

# Annealing & dyamics parameters: the same for all stages
# (this is cautious, but not an absolute requirement)
anneal_params = {'temp_start':5000.0, 'temp_end':10.0, 'temp_steps':500,
                 'dynamics_steps':100, 'time_step':0.001}

# Hierarchical scale protocol
particle_sizes = [8e6, 4e6, 2e6, 4e5, 2e5, 1e5]

# Load single-cell Hi-C data from NCC contact file, as output from NucProcess
chromosomes, chromo_limits, contact_dict = load_ncc_file('example_chromo_data/Cell_1_contacts.ncc')

# Only use contacts which are supported by others nearby in sequence, in the initial instance
remove_isolated_contacts(contact_dict, threshold=2e6)

# Initial coords will be random
start_coords = None

# Record partile positions from previous stages
# so that coordinates can be interpolated to higher resolution
prev_seq_pos = None

for stage, particle_size in enumerate(particle_sizes):
    
    print "Running structure caculation stage %d (%d kb)" % (stage+1, (particle_size/1e3))
    
    # Can remove large violations (noise contacts inconsistent with structure)
    # once we have a resonable resolution structure
    if stage == 4:
        remove_violated_contacts(contact_dict, coords_dict, particle_seq_pos,
                                 particle_size, threshold=6.0)
    elif stage == 5:
        remove_violated_contacts(contact_dict, coords_dict, particle_seq_pos,
                                 particle_size, threshold=5.0)
    
    coords_dict, particle_seq_pos = anneal_genome(chromosomes, contact_dict, num_models, particle_size,
                                                  general_calc_params, anneal_params,
                                                  prev_seq_pos, start_coords)
    
    # Next stage based on previous stage's 3D coords
    # and thier respective seq. positions
    start_coords = coords_dict
    prev_seq_pos = particle_seq_pos

# Save final coords as PDB format file
save_path = 'example_chromo_data/Cell_1_structure.pdb'
export_pdb_coords(save_path, coords_dict, particle_seq_pos, particle_size)
print('Saved structure file to: %s' % save_path)
# Out:
# Running structure caculation stage 1 (8000 kb)
# temp:11432.08  fRep: 308.01  fDist:667614.51  rmsd:   9.55  nViol: 2934  nRep: 2167
# temp:9810.20  fRep:5440.10  fDist:188312.72  rmsd:   3.09  nViol: 2899  nRep:26154
# temp:7422.35  fRep:7591.11  fDist:46466.55  rmsd:   1.03  nViol: 2677  nRep:28771
# temp:5636.29  fRep:7494.73  fDist:14377.20  rmsd:   0.48  nViol: 2237  nRep:30209
# temp:4808.19  fRep:7381.46  fDist:10225.34  rmsd:   0.40  nViol: 2094  nRep:31719
# temp:4912.86  fRep:7566.28  fDist:10006.03  rmsd:   0.40  nViol: 2078  nRep:33304
# temp:4702.90  fRep:7339.44  fDist:10013.58  rmsd:   0.40  nViol: 2137  nRep:34969
# temp:4551.19  fRep:8201.45  fDist:10095.23  rmsd:   0.40  nViol: 2127  nRep:36717
# temp:4655.35  fRep:8880.60  fDist:9934.71  rmsd:   0.40  nViol: 2103  nRep:38552
# temp:4519.83  fRep:9460.66  fDist:10621.25  rmsd:   0.42  nViol: 2138  nRep:40479
# temp:4339.68  fRep:10240.21  fDist:11463.22  rmsd:   0.45  nViol: 2204  nRep:42502
# temp:4169.88  fRep:11200.68  fDist:11571.05  rmsd:   0.46  nViol: 2214  nRep:44627
# temp:4172.98  fRep:11109.45  fDist:12399.07  rmsd:   0.48  nViol: 2221  nRep:43351
# temp:4254.65  fRep:11775.16  fDist:11418.44  rmsd:   0.46  nViol: 2220  nRep:45670
# temp:4154.15  fRep:11231.32  fDist:12030.33  rmsd:   0.47  nViol: 2171  nRep:43840
# temp:4181.66  fRep:11628.48  fDist:11468.92  rmsd:   0.46  nViol: 2175  nRep:44440
# temp:4180.25  fRep:11068.87  fDist:12053.47  rmsd:   0.47  nViol: 2207  nRep:43911
# temp:4026.75  fRep:11153.70  fDist:11643.31  rmsd:   0.46  nViol: 2203  nRep:44140
# temp:4034.42  fRep:11246.46  fDist:11731.87  rmsd:   0.46  nViol: 2164  nRep:44417
# temp:3936.87  fRep:11145.66  fDist:11777.37  rmsd:   0.47  nViol: 2212  nRep:43920
# temp:3952.11  fRep:11180.81  fDist:11618.29  rmsd:   0.47  nViol: 2197  nRep:43880
# temp:3865.23  fRep:11351.94  fDist:11288.69  rmsd:   0.46  nViol: 2176  nRep:44234
# temp:3843.66  fRep:11882.48  fDist:10916.55  rmsd:   0.45  nViol: 2138  nRep:44955
# temp:3768.20  fRep:10994.42  fDist:11557.37  rmsd:   0.46  nViol: 2173  nRep:43311
# temp:3810.38  fRep:11028.37  fDist:11456.09  rmsd:   0.46  nViol: 2186  nRep:43874
# temp:3612.76  fRep:11032.08  fDist:11670.25  rmsd:   0.47  nViol: 2198  nRep:43501
# temp:3639.52  fRep:11094.37  fDist:11414.16  rmsd:   0.46  nViol: 2201  nRep:44157
# temp:3505.35  fRep:11505.58  fDist:11221.70  rmsd:   0.45  nViol: 2176  nRep:43972
# temp:3401.31  fRep:11502.22  fDist:11089.05  rmsd:   0.45  nViol: 2198  nRep:44717
# temp:3442.98  fRep:11438.70  fDist:11031.53  rmsd:   0.45  nViol: 2176  nRep:44184
# temp:3366.51  fRep:11574.68  fDist:10899.60  rmsd:   0.45  nViol: 2190  nRep:44534
# temp:3431.42  fRep:11688.60  fDist:10482.13  rmsd:   0.44  nViol: 2140  nRep:45242
# temp:3478.55  fRep:11467.08  fDist:10716.01  rmsd:   0.44  nViol: 2153  nRep:44796
# temp:3309.35  fRep:11315.46  fDist:11014.19  rmsd:   0.45  nViol: 2161  nRep:44358
# temp:3254.23  fRep:11015.50  fDist:11195.58  rmsd:   0.46  nViol: 2189  nRep:43575
# temp:3191.58  fRep:11486.54  fDist:10754.84  rmsd:   0.44  nViol: 2195  nRep:44948
# temp:3231.72  fRep:11351.41  fDist:10981.44  rmsd:   0.46  nViol: 2171  nRep:43823
# temp:3205.27  fRep:11422.24  fDist:10787.32  rmsd:   0.45  nViol: 2156  nRep:44947
# temp:3095.28  fRep:11176.06  fDist:10904.55  rmsd:   0.45  nViol: 2189  nRep:43815
# temp:2999.53  fRep:11448.09  fDist:10561.34  rmsd:   0.44  nViol: 2177  nRep:44586
# temp:3020.14  fRep:11108.07  fDist:10743.46  rmsd:   0.45  nViol: 2198  nRep:43751
# temp:3038.24  fRep:11254.27  fDist:10601.66  rmsd:   0.44  nViol: 2157  nRep:43813
# temp:3020.51  fRep:10991.83  fDist:10863.66  rmsd:   0.45  nViol: 2192  nRep:43205
# temp:2881.18  fRep:11659.41  fDist:10239.57  rmsd:   0.44  nViol: 2111  nRep:44947
# temp:2776.83  fRep:11099.33  fDist:10946.04  rmsd:   0.45  nViol: 2167  nRep:43530
# temp:2783.29  fRep:11406.28  fDist:10622.70  rmsd:   0.44  nViol: 2153  nRep:44532
# temp:2757.30  fRep:11126.08  fDist:10632.43  rmsd:   0.45  nViol: 2162  nRep:43519
# temp:2875.13  fRep:11450.77  fDist:10272.30  rmsd:   0.44  nViol: 2153  nRep:44517
# temp:2793.02  fRep:11227.14  fDist:10440.66  rmsd:   0.44  nViol: 2174  nRep:43907
# temp:2604.16  fRep:11232.23  fDist:10499.45  rmsd:   0.45  nViol: 2159  nRep:44108
# temp:2628.35  fRep:11254.32  fDist:10405.20  rmsd:   0.44  nViol: 2163  nRep:44089
# temp:2672.40  fRep:11505.58  fDist:10040.07  rmsd:   0.44  nViol: 2146  nRep:44205
# temp:2652.94  fRep:11402.77  fDist:10163.37  rmsd:   0.44  nViol: 2161  nRep:44218
# temp:2645.46  fRep:10972.27  fDist:10486.91  rmsd:   0.45  nViol: 2146  nRep:43390
# temp:2540.29  fRep:11365.63  fDist:10114.87  rmsd:   0.44  nViol: 2138  nRep:44266
# temp:2487.13  fRep:11408.94  fDist:10197.88  rmsd:   0.44  nViol: 2188  nRep:43890
# temp:2493.06  fRep:11213.92  fDist:10377.22  rmsd:   0.44  nViol: 2167  nRep:43594
# temp:2404.44  fRep:11358.07  fDist:10272.98  rmsd:   0.44  nViol: 2155  nRep:44014
# temp:2411.36  fRep:11338.47  fDist:9982.47  rmsd:   0.43  nViol: 2163  nRep:44067
# temp:2322.68  fRep:11213.30  fDist:10199.97  rmsd:   0.44  nViol: 2133  nRep:43888
# temp:2326.09  fRep:11154.80  fDist:10321.16  rmsd:   0.44  nViol: 2177  nRep:43538
# temp:2354.72  fRep:11361.18  fDist:10074.82  rmsd:   0.44  nViol: 2146  nRep:43856
# temp:2238.03  fRep:11279.89  fDist:10205.48  rmsd:   0.44  nViol: 2158  nRep:43800
# temp:2324.77  fRep:11031.92  fDist:10173.88  rmsd:   0.44  nViol: 2171  nRep:43263
# temp:2236.65  fRep:11297.32  fDist:9997.37  rmsd:   0.44  nViol: 2147  nRep:44069
# temp:2222.70  fRep:11009.87  fDist:10292.84  rmsd:   0.45  nViol: 2126  nRep:43429
# temp:2203.86  fRep:11090.19  fDist:10233.44  rmsd:   0.45  nViol: 2156  nRep:43605
# temp:2130.48  fRep:10997.04  fDist:10358.30  rmsd:   0.44  nViol: 2176  nRep:43456
# temp:2175.96  fRep:11149.91  fDist:10057.05  rmsd:   0.43  nViol: 2156  nRep:43558
# temp:2057.26  fRep:11288.32  fDist:9924.81  rmsd:   0.43  nViol: 2211  nRep:43777
# temp:2037.21  fRep:11111.46  fDist:10118.61  rmsd:   0.44  nViol: 2175  nRep:43405
# temp:2110.49  fRep:11439.85  fDist:9803.92  rmsd:   0.43  nViol: 2160  nRep:43846
# temp:2046.62  fRep:11301.95  fDist:9785.37  rmsd:   0.43  nViol: 2195  nRep:43821
# temp:1975.21  fRep:11479.15  fDist:9676.21  rmsd:   0.43  nViol: 2166  nRep:44290
# temp:2002.22  fRep:11131.60  fDist:10035.94  rmsd:   0.44  nViol: 2183  nRep:43014
# temp:1985.36  fRep:11262.27  fDist:9835.56  rmsd:   0.43  nViol: 2151  nRep:43493
# temp:1994.61  fRep:11181.01  fDist:9858.87  rmsd:   0.43  nViol: 2145  nRep:43393
# temp:1951.44  fRep:11339.03  fDist:9600.39  rmsd:   0.43  nViol: 2152  nRep:44313
# temp:1878.04  fRep:11460.43  fDist:9505.76  rmsd:   0.43  nViol: 2151  nRep:44010
# temp:1856.70  fRep:11239.39  fDist:9849.83  rmsd:   0.44  nViol: 2149  nRep:43587
# temp:1809.88  fRep:11170.33  fDist:9945.54  rmsd:   0.44  nViol: 2163  nRep:43420
# temp:1828.07  fRep:11444.86  fDist:9491.75  rmsd:   0.43  nViol: 2146  nRep:43685
# temp:1776.53  fRep:11268.81  fDist:9727.46  rmsd:   0.43  nViol: 2124  nRep:43336
# temp:1792.44  fRep:11439.75  fDist:9497.36  rmsd:   0.43  nViol: 2124  nRep:43729
# temp:1781.28  fRep:11368.02  fDist:9617.36  rmsd:   0.43  nViol: 2138  nRep:43498
# temp:1681.17  fRep:11229.90  fDist:9874.06  rmsd:   0.44  nViol: 2153  nRep:43364
# temp:1695.63  fRep:11408.84  fDist:9649.53  rmsd:   0.43  nViol: 2144  nRep:43836
# temp:1718.30  fRep:11305.87  fDist:9601.54  rmsd:   0.43  nViol: 2140  nRep:43221
# temp:1652.90  fRep:11340.50  fDist:9647.16  rmsd:   0.43  nViol: 2154  nRep:43107
# temp:1605.81  fRep:11224.39  fDist:9704.32  rmsd:   0.43  nViol: 2138  nRep:43182
# temp:1620.85  fRep:11263.65  fDist:9540.62  rmsd:   0.43  nViol: 2151  nRep:43181
# temp:1646.78  fRep:11223.57  fDist:9662.21  rmsd:   0.43  nViol: 2164  nRep:43374
# temp:1600.92  fRep:11395.11  fDist:9431.56  rmsd:   0.43  nViol: 2136  nRep:43337
# temp:1594.91  fRep:11388.89  fDist:9383.99  rmsd:   0.43  nViol: 2171  nRep:43481
# temp:1520.06  fRep:11145.84  fDist:9792.20  rmsd:   0.44  nViol: 2145  nRep:42748
# temp:1557.04  fRep:11128.67  fDist:9637.63  rmsd:   0.44  nViol: 2152  nRep:42653
# temp:1529.48  fRep:11147.97  fDist:9586.97  rmsd:   0.43  nViol: 2160  nRep:43138
# temp:1512.81  fRep:11043.18  fDist:9726.29  rmsd:   0.44  nViol: 2144  nRep:42737
# temp:1438.45  fRep:11384.01  fDist:9477.09  rmsd:   0.43  nViol: 2160  nRep:43309
# temp:1445.11  fRep:11336.46  fDist:9534.46  rmsd:   0.43  nViol: 2128  nRep:43250
# temp:1433.78  fRep:11458.53  fDist:9375.60  rmsd:   0.42  nViol: 2141  nRep:43592
# temp:1436.00  fRep:11200.18  fDist:9685.54  rmsd:   0.43  nViol: 2149  nRep:42951
# temp:1354.17  fRep:11423.27  fDist:9425.03  rmsd:   0.43  nViol: 2161  nRep:43264
# temp:1383.48  fRep:11456.59  fDist:9368.73  rmsd:   0.43  nViol: 2122  nRep:43181
# temp:1393.62  fRep:11410.74  fDist:9326.92  rmsd:   0.42  nViol: 2147  nRep:43400
# temp:1309.76  fRep:11180.97  fDist:9565.02  rmsd:   0.43  nViol: 2159  nRep:42895
# temp:1335.39  fRep:11519.54  fDist:9265.71  rmsd:   0.42  nViol: 2164  nRep:43466
# temp:1308.86  fRep:11010.25  fDist:9869.01  rmsd:   0.44  nViol: 2165  nRep:42715
# temp:1313.41  fRep:11415.23  fDist:9378.03  rmsd:   0.43  nViol: 2139  nRep:43342
# temp:1250.49  fRep:11158.60  fDist:9724.60  rmsd:   0.43  nViol: 2159  nRep:42562
# temp:1260.37  fRep:11406.65  fDist:9443.59  rmsd:   0.43  nViol: 2153  nRep:43047
# temp:1266.95  fRep:11154.79  fDist:9681.85  rmsd:   0.43  nViol: 2164  nRep:42421
# temp:1254.33  fRep:11541.82  fDist:9211.83  rmsd:   0.43  nViol: 2151  nRep:43305
# temp:1199.73  fRep:11206.58  fDist:9538.89  rmsd:   0.43  nViol: 2152  nRep:42580
# temp:1193.45  fRep:11280.18  fDist:9467.20  rmsd:   0.43  nViol: 2148  nRep:42976
# temp:1165.81  fRep:11286.90  fDist:9494.28  rmsd:   0.43  nViol: 2137  nRep:42417
# temp:1169.92  fRep:11314.23  fDist:9443.19  rmsd:   0.43  nViol: 2125  nRep:42943
# temp:1114.55  fRep:11306.13  fDist:9526.17  rmsd:   0.43  nViol: 2164  nRep:42590
# temp:1150.74  fRep:11513.00  fDist:9258.77  rmsd:   0.43  nViol: 2153  nRep:43192
# temp:1128.67  fRep:11267.77  fDist:9495.75  rmsd:   0.43  nViol: 2158  nRep:42670
# temp:1088.06  fRep:11495.68  fDist:9319.64  rmsd:   0.43  nViol: 2165  nRep:43203
# temp:1098.98  fRep:11455.37  fDist:9325.09  rmsd:   0.43  nViol: 2162  nRep:42975
# temp:1084.78  fRep:11208.83  fDist:9565.06  rmsd:   0.43  nViol: 2156  nRep:42457
# temp:1064.38  fRep:11370.82  fDist:9405.81  rmsd:   0.43  nViol: 2172  nRep:42642
# temp:1056.63  fRep:11370.63  fDist:9456.13  rmsd:   0.43  nViol: 2151  nRep:42530
# temp:1099.51  fRep:11216.72  fDist:9582.51  rmsd:   0.44  nViol: 2162  nRep:42452
# temp:1040.80  fRep:11395.70  fDist:9390.05  rmsd:   0.43  nViol: 2146  nRep:42554
# temp:1000.28  fRep:11505.09  fDist:9281.01  rmsd:   0.43  nViol: 2163  nRep:42695
# temp:1025.36  fRep:11584.16  fDist:9233.69  rmsd:   0.43  nViol: 2141  nRep:43075
# temp: 984.53  fRep:11609.68  fDist:9235.93  rmsd:   0.43  nViol: 2154  nRep:42665
# temp:1003.88  fRep:11465.32  fDist:9415.18  rmsd:   0.43  nViol: 2171  nRep:42391
# temp: 982.62  fRep:11434.98  fDist:9425.75  rmsd:   0.43  nViol: 2162  nRep:42392
# temp: 963.15  fRep:11552.00  fDist:9288.85  rmsd:   0.43  nViol: 2164  nRep:42662
# temp: 934.54  fRep:11407.19  fDist:9433.08  rmsd:   0.43  nViol: 2178  nRep:42597
# temp: 926.16  fRep:11312.71  fDist:9541.36  rmsd:   0.44  nViol: 2176  nRep:42118
# temp: 928.94  fRep:11552.55  fDist:9271.97  rmsd:   0.43  nViol: 2156  nRep:42556
# temp: 882.67  fRep:11512.34  fDist:9415.30  rmsd:   0.43  nViol: 2155  nRep:42485
# temp: 904.66  fRep:11515.38  fDist:9347.44  rmsd:   0.43  nViol: 2148  nRep:42548
# temp: 933.36  fRep:11703.82  fDist:9201.57  rmsd:   0.43  nViol: 2173  nRep:42771
# temp: 882.86  fRep:11666.10  fDist:9235.69  rmsd:   0.43  nViol: 2144  nRep:42624
# temp: 858.60  fRep:11666.25  fDist:9287.82  rmsd:   0.43  nViol: 2161  nRep:42555
# temp: 867.66  fRep:11730.44  fDist:9198.86  rmsd:   0.43  nViol: 2169  nRep:42809
# temp: 851.90  fRep:11528.46  fDist:9396.56  rmsd:   0.43  nViol: 2159  nRep:42130
# temp: 874.73  fRep:11654.96  fDist:9265.45  rmsd:   0.43  nViol: 2164  nRep:42498
# temp: 819.31  fRep:11641.43  fDist:9340.13  rmsd:   0.43  nViol: 2157  nRep:42415
# temp: 837.75  fRep:11690.24  fDist:9277.94  rmsd:   0.43  nViol: 2157  nRep:42206
# temp: 791.47  fRep:11817.37  fDist:9224.82  rmsd:   0.43  nViol: 2178  nRep:42496
# temp: 803.14  fRep:11664.47  fDist:9311.35  rmsd:   0.43  nViol: 2159  nRep:42495
# temp: 807.21  fRep:11622.65  fDist:9387.97  rmsd:   0.43  nViol: 2169  nRep:41983
# temp: 783.48  fRep:11678.76  fDist:9328.81  rmsd:   0.43  nViol: 2163  nRep:41978
# temp: 738.74  fRep:11637.30  fDist:9415.65  rmsd:   0.43  nViol: 2181  nRep:42138
# temp: 759.44  fRep:11706.03  fDist:9345.71  rmsd:   0.43  nViol: 2155  nRep:42106
# temp: 747.68  fRep:11691.93  fDist:9366.38  rmsd:   0.43  nViol: 2187  nRep:42043
# temp: 752.57  fRep:11778.74  fDist:9334.65  rmsd:   0.43  nViol: 2174  nRep:42128
# temp: 729.10  fRep:11790.28  fDist:9328.84  rmsd:   0.43  nViol: 2184  nRep:42080
# temp: 721.69  fRep:11755.03  fDist:9440.33  rmsd:   0.44  nViol: 2161  nRep:41950
# temp: 716.29  fRep:11780.93  fDist:9406.37  rmsd:   0.43  nViol: 2137  nRep:42089
# temp: 727.76  fRep:11835.73  fDist:9330.87  rmsd:   0.43  nViol: 2171  nRep:41956
# temp: 692.10  fRep:11774.50  fDist:9461.55  rmsd:   0.44  nViol: 2170  nRep:41621
# temp: 706.56  fRep:11929.77  fDist:9278.86  rmsd:   0.43  nViol: 2175  nRep:42093
# temp: 688.46  fRep:11867.76  fDist:9370.88  rmsd:   0.43  nViol: 2157  nRep:41659
# temp: 661.18  fRep:11892.50  fDist:9407.25  rmsd:   0.43  nViol: 2165  nRep:41779
# temp: 673.85  fRep:11953.15  fDist:9352.96  rmsd:   0.44  nViol: 2167  nRep:41808
# temp: 669.49  fRep:11985.81  fDist:9356.83  rmsd:   0.43  nViol: 2190  nRep:41934
# temp: 664.56  fRep:12028.39  fDist:9325.22  rmsd:   0.43  nViol: 2186  nRep:41960
# temp: 647.92  fRep:11905.81  fDist:9474.35  rmsd:   0.44  nViol: 2195  nRep:41703
# temp: 653.76  fRep:11909.67  fDist:9481.03  rmsd:   0.44  nViol: 2186  nRep:41615
# temp: 614.57  fRep:11797.58  fDist:9648.33  rmsd:   0.44  nViol: 2191  nRep:41347
# temp: 618.54  fRep:11831.39  fDist:9652.05  rmsd:   0.44  nViol: 2194  nRep:41485
# temp: 606.63  fRep:11874.02  fDist:9631.63  rmsd:   0.44  nViol: 2196  nRep:41235
# temp: 610.84  fRep:11991.22  fDist:9521.02  rmsd:   0.44  nViol: 2177  nRep:41475
# temp: 589.56  fRep:11918.41  fDist:9680.77  rmsd:   0.44  nViol: 2194  nRep:41191
# temp: 601.41  fRep:12020.59  fDist:9566.40  rmsd:   0.44  nViol: 2173  nRep:41252
# temp: 572.74  fRep:11974.72  fDist:9682.17  rmsd:   0.44  nViol: 2205  nRep:41187
# temp: 577.99  fRep:12027.05  fDist:9660.53  rmsd:   0.44  nViol: 2193  nRep:41102
# temp: 557.22  fRep:12139.79  fDist:9593.42  rmsd:   0.44  nViol: 2160  nRep:41221
# temp: 552.39  fRep:12045.65  fDist:9682.89  rmsd:   0.44  nViol: 2182  nRep:41033
# temp: 545.87  fRep:11989.05  fDist:9778.80  rmsd:   0.45  nViol: 2185  nRep:40850
# temp: 541.15  fRep:12210.58  fDist:9602.71  rmsd:   0.44  nViol: 2207  nRep:41280
# temp: 515.77  fRep:11983.67  fDist:9867.87  rmsd:   0.45  nViol: 2169  nRep:40731
# temp: 522.17  fRep:12002.14  fDist:9920.15  rmsd:   0.45  nViol: 2201  nRep:40538
# temp: 519.53  fRep:12268.60  fDist:9670.42  rmsd:   0.44  nViol: 2207  nRep:41003
# temp: 521.03  fRep:12410.97  fDist:9567.08  rmsd:   0.44  nViol: 2183  nRep:41073
# temp: 513.07  fRep:12239.50  fDist:9786.13  rmsd:   0.44  nViol: 2242  nRep:40698
# temp: 518.65  fRep:12397.85  fDist:9651.42  rmsd:   0.44  nViol: 2205  nRep:40824
# temp: 502.70  fRep:12232.64  fDist:9902.84  rmsd:   0.45  nViol: 2215  nRep:40482
# temp: 477.12  fRep:12350.57  fDist:9864.88  rmsd:   0.45  nViol: 2218  nRep:40535
# temp: 477.86  fRep:12267.17  fDist:9995.66  rmsd:   0.45  nViol: 2224  nRep:40336
# temp: 473.93  fRep:12527.31  fDist:9747.57  rmsd:   0.45  nViol: 2201  nRep:40639
# temp: 469.81  fRep:12300.01  fDist:10040.05  rmsd:   0.46  nViol: 2215  nRep:40057
# temp: 475.08  fRep:12463.31  fDist:9961.01  rmsd:   0.45  nViol: 2205  nRep:40321
# temp: 444.87  fRep:12389.20  fDist:10108.35  rmsd:   0.45  nViol: 2212  nRep:40088
# temp: 476.69  fRep:12582.30  fDist:9914.54  rmsd:   0.45  nViol: 2218  nRep:40486
# temp: 463.69  fRep:12469.23  fDist:10087.70  rmsd:   0.46  nViol: 2232  nRep:40091
# temp: 463.09  fRep:12594.95  fDist:10046.66  rmsd:   0.45  nViol: 2234  nRep:40083
# temp: 437.04  fRep:12527.79  fDist:10213.16  rmsd:   0.46  nViol: 2213  nRep:39790
# temp: 442.22  fRep:12566.57  fDist:10222.54  rmsd:   0.46  nViol: 2227  nRep:39762
# temp: 431.34  fRep:12612.44  fDist:10235.82  rmsd:   0.46  nViol: 2222  nRep:39734
# temp: 428.38  fRep:12724.76  fDist:10185.90  rmsd:   0.46  nViol: 2232  nRep:39990
# temp: 415.70  fRep:12635.20  fDist:10383.51  rmsd:   0.46  nViol: 2220  nRep:39367
# temp: 415.91  fRep:12880.78  fDist:10193.03  rmsd:   0.45  nViol: 2229  nRep:39965
# temp: 412.22  fRep:12733.89  fDist:10425.80  rmsd:   0.46  nViol: 2215  nRep:39275
# temp: 404.79  fRep:12908.30  fDist:10316.59  rmsd:   0.46  nViol: 2226  nRep:39609
# temp: 394.81  fRep:12955.03  fDist:10381.74  rmsd:   0.46  nViol: 2229  nRep:39472
# temp: 385.73  fRep:12965.02  fDist:10451.31  rmsd:   0.46  nViol: 2231  nRep:39347
# temp: 396.06  fRep:13022.07  fDist:10474.10  rmsd:   0.47  nViol: 2254  nRep:39218
# temp: 372.90  fRep:13096.49  fDist:10518.22  rmsd:   0.46  nViol: 2243  nRep:39210
# temp: 383.83  fRep:13187.68  fDist:10508.73  rmsd:   0.47  nViol: 2218  nRep:39203
# temp: 367.80  fRep:13181.37  fDist:10608.60  rmsd:   0.47  nViol: 2242  nRep:38938
# temp: 369.90  fRep:13242.40  fDist:10645.27  rmsd:   0.47  nViol: 2250  nRep:39010
# temp: 362.76  fRep:13182.00  fDist:10810.35  rmsd:   0.47  nViol: 2247  nRep:38496
# temp: 349.23  fRep:13334.95  fDist:10770.33  rmsd:   0.47  nViol: 2242  nRep:38646
# temp: 355.73  fRep:13365.59  fDist:10855.95  rmsd:   0.47  nViol: 2278  nRep:38618
# temp: 352.41  fRep:13344.28  fDist:10998.62  rmsd:   0.48  nViol: 2267  nRep:38390
# temp: 346.73  fRep:13523.88  fDist:10963.06  rmsd:   0.48  nViol: 2243  nRep:38494
# temp: 350.01  fRep:13436.65  fDist:11161.68  rmsd:   0.48  nViol: 2266  nRep:38145
# temp: 334.96  fRep:13592.89  fDist:11139.88  rmsd:   0.48  nViol: 2262  nRep:38144
# temp: 340.19  fRep:13602.76  fDist:11263.34  rmsd:   0.48  nViol: 2278  nRep:37884
# temp: 336.37  fRep:13833.69  fDist:11150.32  rmsd:   0.48  nViol: 2271  nRep:38016
# temp: 332.89  fRep:13891.92  fDist:11234.00  rmsd:   0.48  nViol: 2255  nRep:37797
# temp: 315.86  fRep:13996.66  fDist:11319.29  rmsd:   0.49  nViol: 2277  nRep:37839
# temp: 324.63  fRep:14041.06  fDist:11414.35  rmsd:   0.49  nViol: 2257  nRep:37466
# temp: 308.70  fRep:14040.83  fDist:11566.20  rmsd:   0.49  nViol: 2264  nRep:37287
# temp: 308.53  fRep:14143.87  fDist:11620.76  rmsd:   0.49  nViol: 2304  nRep:37111
# temp: 308.14  fRep:14237.76  fDist:11712.53  rmsd:   0.50  nViol: 2276  nRep:37107
# temp: 296.90  fRep:14312.09  fDist:11813.77  rmsd:   0.50  nViol: 2301  nRep:36902
# temp: 298.06  fRep:14392.92  fDist:11915.03  rmsd:   0.50  nViol: 2302  nRep:36912
# temp: 295.35  fRep:14469.80  fDist:12024.07  rmsd:   0.50  nViol: 2278  nRep:36573
# temp: 291.45  fRep:14551.75  fDist:12134.94  rmsd:   0.51  nViol: 2328  nRep:36396
# temp: 287.74  fRep:14724.13  fDist:12178.42  rmsd:   0.51  nViol: 2309  nRep:36295
# temp: 288.53  fRep:14822.28  fDist:12268.22  rmsd:   0.51  nViol: 2323  nRep:36199
# temp: 281.38  fRep:14850.34  fDist:12473.04  rmsd:   0.51  nViol: 2323  nRep:35766
# temp: 271.40  fRep:15059.18  fDist:12504.53  rmsd:   0.51  nViol: 2320  nRep:35744
# temp: 267.01  fRep:15149.25  fDist:12624.02  rmsd:   0.52  nViol: 2336  nRep:35499
# temp: 268.46  fRep:15201.58  fDist:12816.41  rmsd:   0.52  nViol: 2321  nRep:35321
# temp: 272.11  fRep:15421.36  fDist:12820.27  rmsd:   0.52  nViol: 2324  nRep:35338
# temp: 264.27  fRep:15419.36  fDist:13086.56  rmsd:   0.53  nViol: 2333  nRep:34834
# temp: 263.90  fRep:15683.69  fDist:13082.71  rmsd:   0.53  nViol: 2332  nRep:34855
# temp: 260.40  fRep:15705.29  fDist:13322.01  rmsd:   0.53  nViol: 2330  nRep:34587
# temp: 251.87  fRep:15912.63  fDist:13394.81  rmsd:   0.54  nViol: 2340  nRep:34485
# temp: 250.84  fRep:15903.93  fDist:13667.13  rmsd:   0.54  nViol: 2338  nRep:34184
# temp: 242.18  fRep:16141.03  fDist:13716.92  rmsd:   0.54  nViol: 2349  nRep:33983
# temp: 241.41  fRep:16192.10  fDist:13919.58  rmsd:   0.55  nViol: 2359  nRep:33686
# temp: 238.19  fRep:16491.66  fDist:13936.64  rmsd:   0.55  nViol: 2370  nRep:33642
# temp: 239.15  fRep:16477.99  fDist:14222.41  rmsd:   0.55  nViol: 2360  nRep:33297
# temp: 242.09  fRep:16569.51  fDist:14421.19  rmsd:   0.56  nViol: 2366  nRep:33063
# temp: 236.16  fRep:16763.66  fDist:14527.40  rmsd:   0.56  nViol: 2358  nRep:32847
# temp: 241.12  fRep:16766.58  fDist:14801.05  rmsd:   0.57  nViol: 2386  nRep:32535
# temp: 220.60  fRep:16993.80  fDist:14893.01  rmsd:   0.57  nViol: 2383  nRep:32420
# temp: 221.47  fRep:17151.68  fDist:15014.01  rmsd:   0.57  nViol: 2385  nRep:32184
# temp: 226.45  fRep:17204.28  fDist:15254.28  rmsd:   0.58  nViol: 2385  nRep:31831
# temp: 221.28  fRep:17380.62  fDist:15369.37  rmsd:   0.58  nViol: 2387  nRep:31835
# temp: 216.81  fRep:17460.70  fDist:15573.42  rmsd:   0.58  nViol: 2394  nRep:31567
# temp: 214.80  fRep:17541.13  fDist:15759.98  rmsd:   0.59  nViol: 2408  nRep:31359
# temp: 208.78  fRep:17622.34  fDist:15957.19  rmsd:   0.59  nViol: 2400  nRep:31061
# temp: 208.30  fRep:17778.78  fDist:16070.94  rmsd:   0.59  nViol: 2413  nRep:31058
# temp: 202.91  fRep:17949.56  fDist:16146.24  rmsd:   0.59  nViol: 2407  nRep:30823
# temp: 207.67  fRep:17867.46  fDist:16488.15  rmsd:   0.60  nViol: 2416  nRep:30529
# temp: 200.31  fRep:18056.92  fDist:16551.17  rmsd:   0.60  nViol: 2422  nRep:30388
# temp: 203.26  fRep:18097.34  fDist:16740.71  rmsd:   0.61  nViol: 2440  nRep:30301
# temp: 199.15  fRep:18238.26  fDist:16834.12  rmsd:   0.61  nViol: 2408  nRep:30127
# temp: 184.83  fRep:18346.47  fDist:16952.05  rmsd:   0.61  nViol: 2425  nRep:30053
# temp: 190.53  fRep:18369.39  fDist:17142.49  rmsd:   0.61  nViol: 2430  nRep:29754
# temp: 193.09  fRep:18454.51  fDist:17264.41  rmsd:   0.62  nViol: 2421  nRep:29673
# temp: 188.28  fRep:18513.67  fDist:17393.93  rmsd:   0.62  nViol: 2428  nRep:29626
# temp: 176.11  fRep:18574.57  fDist:17544.97  rmsd:   0.62  nViol: 2431  nRep:29418
# temp: 186.99  fRep:18634.54  fDist:17649.74  rmsd:   0.63  nViol: 2453  nRep:29370
# temp: 176.98  fRep:18740.36  fDist:17726.46  rmsd:   0.63  nViol: 2441  nRep:29176
# temp: 175.65  fRep:18721.64  fDist:17914.81  rmsd:   0.63  nViol: 2457  nRep:29102
# temp: 177.48  fRep:18772.25  fDist:18021.64  rmsd:   0.63  nViol: 2438  nRep:28891
# temp: 174.77  fRep:18883.23  fDist:18060.78  rmsd:   0.63  nViol: 2444  nRep:28936
# temp: 177.08  fRep:18829.32  fDist:18248.56  rmsd:   0.64  nViol: 2438  nRep:28729
# temp: 170.72  fRep:19023.78  fDist:18203.49  rmsd:   0.64  nViol: 2443  nRep:28774
# temp: 170.82  fRep:18946.48  fDist:18416.03  rmsd:   0.64  nViol: 2444  nRep:28492
# temp: 165.27  fRep:19014.02  fDist:18476.78  rmsd:   0.64  nViol: 2452  nRep:28550
# temp: 163.35  fRep:18956.97  fDist:18645.97  rmsd:   0.65  nViol: 2445  nRep:28293
# temp: 156.97  fRep:19063.65  fDist:18659.99  rmsd:   0.65  nViol: 2443  nRep:28352
# temp: 161.31  fRep:19047.48  fDist:18787.69  rmsd:   0.65  nViol: 2450  nRep:28195
# temp: 160.86  fRep:19157.84  fDist:18782.01  rmsd:   0.65  nViol: 2452  nRep:28219
# temp: 155.75  fRep:19189.59  fDist:18845.76  rmsd:   0.65  nViol: 2455  nRep:28205
# temp: 153.89  fRep:19192.04  fDist:18947.93  rmsd:   0.65  nViol: 2460  nRep:28109
# temp: 150.11  fRep:19301.82  fDist:18934.14  rmsd:   0.65  nViol: 2459  nRep:28047
# temp: 153.14  fRep:19242.40  fDist:19074.43  rmsd:   0.65  nViol: 2476  nRep:27970
# temp: 152.28  fRep:19381.31  fDist:19023.23  rmsd:   0.65  nViol: 2471  nRep:28013
# temp: 146.97  fRep:19201.88  fDist:19295.19  rmsd:   0.66  nViol: 2461  nRep:27697
# temp: 143.87  fRep:19340.61  fDist:19226.54  rmsd:   0.66  nViol: 2473  nRep:27731
# temp: 142.24  fRep:19323.71  fDist:19316.52  rmsd:   0.66  nViol: 2454  nRep:27671
# temp: 139.65  fRep:19351.76  fDist:19367.04  rmsd:   0.66  nViol: 2476  nRep:27706
# temp: 140.54  fRep:19361.12  fDist:19432.11  rmsd:   0.66  nViol: 2470  nRep:27577
# temp: 141.78  fRep:19392.18  fDist:19458.50  rmsd:   0.66  nViol: 2473  nRep:27609
# temp: 137.24  fRep:19465.66  fDist:19451.83  rmsd:   0.66  nViol: 2471  nRep:27607
# temp: 133.79  fRep:19461.33  fDist:19525.11  rmsd:   0.66  nViol: 2463  nRep:27551
# temp: 131.55  fRep:19402.34  fDist:19641.30  rmsd:   0.67  nViol: 2472  nRep:27391
# temp: 127.98  fRep:19615.69  fDist:19483.40  rmsd:   0.66  nViol: 2464  nRep:27597
# temp: 126.16  fRep:19484.01  fDist:19671.43  rmsd:   0.67  nViol: 2475  nRep:27412
# temp: 129.30  fRep:19589.53  fDist:19618.63  rmsd:   0.67  nViol: 2463  nRep:27440
# temp: 123.54  fRep:19592.69  fDist:19668.54  rmsd:   0.67  nViol: 2468  nRep:27500
# temp: 123.45  fRep:19589.41  fDist:19719.75  rmsd:   0.67  nViol: 2473  nRep:27309
# temp: 119.54  fRep:19587.01  fDist:19772.86  rmsd:   0.67  nViol: 2476  nRep:27317
# temp: 119.62  fRep:19583.52  fDist:19827.36  rmsd:   0.67  nViol: 2483  nRep:27229
# temp: 119.32  fRep:19625.75  fDist:19822.99  rmsd:   0.67  nViol: 2480  nRep:27279
# temp: 119.91  fRep:19726.51  fDist:19761.67  rmsd:   0.67  nViol: 2474  nRep:27340
# temp: 118.53  fRep:19674.61  fDist:19859.55  rmsd:   0.67  nViol: 2475  nRep:27244
# temp: 115.99  fRep:19721.49  fDist:19852.12  rmsd:   0.67  nViol: 2479  nRep:27201
# temp: 111.81  fRep:19689.47  fDist:19926.22  rmsd:   0.67  nViol: 2472  nRep:27167
# temp: 113.49  fRep:19696.58  fDist:19953.96  rmsd:   0.67  nViol: 2472  nRep:27130
# temp: 113.06  fRep:19722.75  fDist:19963.58  rmsd:   0.67  nViol: 2480  nRep:27176
# temp: 110.08  fRep:19594.33  fDist:20128.04  rmsd:   0.68  nViol: 2480  nRep:26987
# temp: 106.99  fRep:19716.26  fDist:20037.91  rmsd:   0.67  nViol: 2474  nRep:27000
# temp: 106.73  fRep:19685.26  fDist:20108.39  rmsd:   0.67  nViol: 2480  nRep:26997
# temp: 106.92  fRep:19676.08  fDist:20146.14  rmsd:   0.68  nViol: 2478  nRep:26969
# temp: 103.68  fRep:19754.10  fDist:20107.34  rmsd:   0.67  nViol: 2470  nRep:27003
# temp:  99.05  fRep:19757.54  fDist:20136.31  rmsd:   0.67  nViol: 2476  nRep:26936
# temp: 102.39  fRep:19712.99  fDist:20204.47  rmsd:   0.68  nViol: 2475  nRep:26950
# temp:  96.16  fRep:19743.92  fDist:20204.42  rmsd:   0.67  nViol: 2479  nRep:26949
# temp:  96.69  fRep:19786.82  fDist:20195.98  rmsd:   0.68  nViol: 2488  nRep:26909
# temp:  99.00  fRep:19762.05  fDist:20238.69  rmsd:   0.68  nViol: 2469  nRep:26903
# temp:  97.43  fRep:19820.68  fDist:20210.99  rmsd:   0.68  nViol: 2476  nRep:26908
# temp:  94.39  fRep:19804.07  fDist:20251.47  rmsd:   0.68  nViol: 2486  nRep:26868
# temp:  94.37  fRep:19881.75  fDist:20201.17  rmsd:   0.68  nViol: 2478  nRep:26890
# temp:  93.35  fRep:19812.50  fDist:20286.80  rmsd:   0.68  nViol: 2476  nRep:26856
# temp:  90.35  fRep:19857.55  fDist:20267.54  rmsd:   0.68  nViol: 2483  nRep:26881
# temp:  90.59  fRep:19868.33  fDist:20284.14  rmsd:   0.68  nViol: 2488  nRep:26843
# temp:  87.95  fRep:19924.97  fDist:20244.97  rmsd:   0.68  nViol: 2486  nRep:26891
# temp:  92.36  fRep:19848.08  fDist:20346.28  rmsd:   0.68  nViol: 2487  nRep:26770
# temp:  87.01  fRep:19915.78  fDist:20301.45  rmsd:   0.68  nViol: 2485  nRep:26849
# temp:  85.08  fRep:19735.30  fDist:20499.66  rmsd:   0.68  nViol: 2492  nRep:26672
# temp:  86.06  fRep:19861.13  fDist:20394.11  rmsd:   0.68  nViol: 2490  nRep:26808
# temp:  85.05  fRep:19918.17  fDist:20355.16  rmsd:   0.68  nViol: 2486  nRep:26766
# temp:  82.68  fRep:19828.39  fDist:20469.48  rmsd:   0.68  nViol: 2493  nRep:26708
# temp:  80.78  fRep:19758.95  fDist:20555.62  rmsd:   0.68  nViol: 2491  nRep:26591
# temp:  80.99  fRep:19948.97  fDist:20385.53  rmsd:   0.68  nViol: 2485  nRep:26754
# temp:  80.09  fRep:19782.49  fDist:20565.27  rmsd:   0.68  nViol: 2490  nRep:26566
# temp:  77.18  fRep:19949.72  fDist:20413.92  rmsd:   0.68  nViol: 2479  nRep:26713
# temp:  78.14  fRep:19879.22  fDist:20507.60  rmsd:   0.68  nViol: 2481  nRep:26641
# temp:  77.07  fRep:19973.97  fDist:20430.75  rmsd:   0.68  nViol: 2489  nRep:26755
# temp:  79.35  fRep:19925.80  fDist:20488.84  rmsd:   0.68  nViol: 2487  nRep:26622
# temp:  74.18  fRep:20006.97  fDist:20431.00  rmsd:   0.68  nViol: 2483  nRep:26672
# temp:  74.05  fRep:19926.85  fDist:20525.01  rmsd:   0.68  nViol: 2476  nRep:26644
# temp:  74.22  fRep:19961.78  fDist:20502.79  rmsd:   0.68  nViol: 2473  nRep:26657
# temp:  71.36  fRep:19961.90  fDist:20518.69  rmsd:   0.68  nViol: 2474  nRep:26659
# temp:  71.75  fRep:19949.81  fDist:20540.95  rmsd:   0.68  nViol: 2483  nRep:26585
# temp:  70.56  fRep:19947.23  fDist:20564.18  rmsd:   0.68  nViol: 2472  nRep:26613
# temp:  68.56  fRep:19983.20  fDist:20542.25  rmsd:   0.68  nViol: 2475  nRep:26588
# temp:  71.85  fRep:19997.70  fDist:20539.55  rmsd:   0.68  nViol: 2485  nRep:26615
# temp:  65.47  fRep:19952.28  fDist:20603.64  rmsd:   0.68  nViol: 2489  nRep:26509
# temp:  69.35  fRep:20070.29  fDist:20492.62  rmsd:   0.68  nViol: 2501  nRep:26669
# temp:  65.76  fRep:19995.43  fDist:20582.90  rmsd:   0.68  nViol: 2489  nRep:26552
# temp:  66.84  fRep:20004.65  fDist:20584.80  rmsd:   0.68  nViol: 2491  nRep:26586
# temp:  66.11  fRep:19974.34  fDist:20632.12  rmsd:   0.68  nViol: 2488  nRep:26526
# temp:  64.64  fRep:19968.91  fDist:20646.69  rmsd:   0.68  nViol: 2489  nRep:26580
# temp:  65.04  fRep:19945.29  fDist:20680.30  rmsd:   0.69  nViol: 2488  nRep:26485
# temp:  62.76  fRep:20040.36  fDist:20596.17  rmsd:   0.68  nViol: 2476  nRep:26620
# temp:  60.55  fRep:19907.80  fDist:20745.31  rmsd:   0.69  nViol: 2490  nRep:26512
# temp:  61.15  fRep:20005.75  fDist:20656.74  rmsd:   0.68  nViol: 2489  nRep:26533
# temp:  60.76  fRep:20006.34  fDist:20663.61  rmsd:   0.68  nViol: 2497  nRep:26546
# temp:  59.43  fRep:20025.37  fDist:20657.32  rmsd:   0.68  nViol: 2489  nRep:26527
# temp:  57.66  fRep:20034.18  fDist:20660.85  rmsd:   0.68  nViol: 2501  nRep:26525
# temp:  60.19  fRep:20039.85  fDist:20662.47  rmsd:   0.68  nViol: 2479  nRep:26517
# temp:  59.71  fRep:20102.49  fDist:20612.50  rmsd:   0.68  nViol: 2481  nRep:26539
# temp:  56.07  fRep:20059.16  fDist:20667.47  rmsd:   0.69  nViol: 2489  nRep:26516
# temp:  56.53  fRep:20084.70  fDist:20650.25  rmsd:   0.68  nViol: 2486  nRep:26461
# temp:  55.69  fRep:20025.25  fDist:20718.12  rmsd:   0.69  nViol: 2492  nRep:26458
# temp:  53.07  fRep:20026.82  fDist:20729.29  rmsd:   0.69  nViol: 2494  nRep:26435
# temp:  53.05  fRep:20045.39  fDist:20720.45  rmsd:   0.69  nViol: 2490  nRep:26405
# temp:  52.80  fRep:20019.81  fDist:20754.13  rmsd:   0.69  nViol: 2492  nRep:26404
# temp:  54.04  fRep:20095.28  fDist:20685.24  rmsd:   0.69  nViol: 2488  nRep:26497
# temp:  51.19  fRep:20006.55  fDist:20785.67  rmsd:   0.69  nViol: 2487  nRep:26419
# temp:  52.45  fRep:20000.62  fDist:20795.84  rmsd:   0.69  nViol: 2486  nRep:26393
# temp:  50.96  fRep:19965.30  fDist:20840.87  rmsd:   0.69  nViol: 2498  nRep:26362
# temp:  49.93  fRep:20052.39  fDist:20762.17  rmsd:   0.69  nViol: 2485  nRep:26435
# temp:  49.81  fRep:19978.81  fDist:20843.03  rmsd:   0.69  nViol: 2486  nRep:26347
# temp:  49.18  fRep:20010.19  fDist:20821.73  rmsd:   0.69  nViol: 2491  nRep:26350
# temp:  47.76  fRep:19984.13  fDist:20856.15  rmsd:   0.69  nViol: 2491  nRep:26313
# temp:  47.35  fRep:20063.01  fDist:20784.35  rmsd:   0.69  nViol: 2487  nRep:26402
# temp:  46.58  fRep:20028.30  fDist:20825.93  rmsd:   0.69  nViol: 2491  nRep:26345
# temp:  46.73  fRep:20103.59  fDist:20761.81  rmsd:   0.69  nViol: 2491  nRep:26405
# temp:  45.55  fRep:20049.91  fDist:20824.25  rmsd:   0.69  nViol: 2487  nRep:26361
# temp:  44.75  fRep:20072.21  fDist:20806.49  rmsd:   0.69  nViol: 2486  nRep:26360
# temp:  44.49  fRep:20056.98  fDist:20828.88  rmsd:   0.69  nViol: 2497  nRep:26361
# temp:  44.54  fRep:20088.21  fDist:20807.21  rmsd:   0.69  nViol: 2478  nRep:26364
# temp:  44.02  fRep:20068.81  fDist:20834.03  rmsd:   0.69  nViol: 2486  nRep:26331
# temp:  43.01  fRep:20106.97  fDist:20799.09  rmsd:   0.69  nViol: 2489  nRep:26364
# temp:  43.49  fRep:20031.27  fDist:20880.47  rmsd:   0.69  nViol: 2492  nRep:26337
# temp:  41.60  fRep:20078.12  fDist:20842.85  rmsd:   0.69  nViol: 2492  nRep:26362
# temp:  41.95  fRep:20043.07  fDist:20886.77  rmsd:   0.69  nViol: 2488  nRep:26296
# temp:  41.65  fRep:20158.32  fDist:20775.10  rmsd:   0.69  nViol: 2486  nRep:26419
# temp:  39.55  fRep:20083.21  fDist:20857.18  rmsd:   0.69  nViol: 2489  nRep:26355
# temp:  37.66  fRep:20104.34  fDist:20844.68  rmsd:   0.69  nViol: 2493  nRep:26364
# temp:  40.23  fRep:20075.58  fDist:20878.15  rmsd:   0.69  nViol: 2488  nRep:26332
# temp:  38.58  fRep:20129.00  fDist:20832.05  rmsd:   0.69  nViol: 2487  nRep:26374
# temp:  38.21  fRep:20084.97  fDist:20881.18  rmsd:   0.69  nViol: 2494  nRep:26368
# temp:  37.09  fRep:20180.05  fDist:20796.43  rmsd:   0.69  nViol: 2488  nRep:26363
# temp:  36.71  fRep:20064.62  fDist:20914.39  rmsd:   0.69  nViol: 2497  nRep:26263
# temp:  37.89  fRep:20143.14  fDist:20840.90  rmsd:   0.69  nViol: 2492  nRep:26351
# temp:  37.14  fRep:20073.75  fDist:20915.74  rmsd:   0.69  nViol: 2493  nRep:26299
# temp:  36.78  fRep:20111.22  fDist:20883.44  rmsd:   0.69  nViol: 2493  nRep:26309
# temp:  34.58  fRep:20049.84  fDist:20952.18  rmsd:   0.69  nViol: 2495  nRep:26276
# temp:  35.78  fRep:20131.18  fDist:20875.67  rmsd:   0.69  nViol: 2491  nRep:26288
# temp:  35.45  fRep:20078.88  fDist:20932.84  rmsd:   0.69  nViol: 2495  nRep:26264
# temp:  34.37  fRep:20134.68  fDist:20882.32  rmsd:   0.69  nViol: 2487  nRep:26278
# temp:  33.86  fRep:20129.23  fDist:20895.02  rmsd:   0.69  nViol: 2488  nRep:26282
# temp:  33.35  fRep:20175.93  fDist:20852.66  rmsd:   0.69  nViol: 2493  nRep:26321
# temp:  33.38  fRep:20161.59  fDist:20870.76  rmsd:   0.69  nViol: 2493  nRep:26280
# temp:  32.84  fRep:20131.00  fDist:20906.60  rmsd:   0.69  nViol: 2495  nRep:26269
# temp:  32.27  fRep:20155.90  fDist:20888.83  rmsd:   0.69  nViol: 2493  nRep:26288
# temp:  32.01  fRep:20158.21  fDist:20891.48  rmsd:   0.69  nViol: 2500  nRep:26270
# temp:  30.82  fRep:20192.25  fDist:20864.93  rmsd:   0.69  nViol: 2503  nRep:26288
# temp:  31.28  fRep:20140.33  fDist:20916.58  rmsd:   0.69  nViol: 2488  nRep:26254
# temp:  29.89  fRep:20153.17  fDist:20908.92  rmsd:   0.69  nViol: 2497  nRep:26252
# temp:  29.86  fRep:20075.27  fDist:20992.80  rmsd:   0.69  nViol: 2494  nRep:26237
# temp:  30.10  fRep:20166.33  fDist:20905.59  rmsd:   0.69  nViol: 2492  nRep:26262
# temp:  29.81  fRep:20120.42  fDist:20956.31  rmsd:   0.69  nViol: 2490  nRep:26220
# temp:  28.81  fRep:20143.49  fDist:20936.93  rmsd:   0.69  nViol: 2489  nRep:26264
# temp:  28.42  fRep:20137.25  fDist:20948.85  rmsd:   0.69  nViol: 2489  nRep:26242
# temp:  29.36  fRep:20146.42  fDist:20943.35  rmsd:   0.69  nViol: 2489  nRep:26251
# temp:  28.38  fRep:20142.14  fDist:20953.84  rmsd:   0.69  nViol: 2490  nRep:26252
# temp:  28.75  fRep:20156.33  fDist:20943.84  rmsd:   0.69  nViol: 2488  nRep:26252
# temp:  28.50  fRep:20101.41  fDist:21001.35  rmsd:   0.69  nViol: 2497  nRep:26189
# temp:  27.74  fRep:20121.85  fDist:20985.93  rmsd:   0.69  nViol: 2494  nRep:26205
# temp:  26.62  fRep:20152.16  fDist:20959.80  rmsd:   0.69  nViol: 2495  nRep:26259
# temp:  26.28  fRep:20111.73  fDist:21004.50  rmsd:   0.69  nViol: 2493  nRep:26188
# temp:  26.38  fRep:20151.67  fDist:20970.01  rmsd:   0.69  nViol: 2493  nRep:26223
# temp:  26.04  fRep:20090.37  fDist:21034.50  rmsd:   0.69  nViol: 2502  nRep:26159
# temp:  26.10  fRep:20155.75  fDist:20971.84  rmsd:   0.69  nViol: 2498  nRep:26253
# temp:  25.77  fRep:20107.95  fDist:21024.58  rmsd:   0.69  nViol: 2492  nRep:26158
# temp:  25.07  fRep:20153.82  fDist:20983.37  rmsd:   0.69  nViol: 2497  nRep:26220
# temp:  23.62  fRep:20145.82  fDist:20996.01  rmsd:   0.69  nViol: 2491  nRep:26210
# temp:  24.54  fRep:20156.07  fDist:20989.53  rmsd:   0.69  nViol: 2493  nRep:26271
# temp:  23.80  fRep:20169.77  fDist:20980.12  rmsd:   0.69  nViol: 2491  nRep:26182
# temp:  23.72  fRep:20138.43  fDist:21014.77  rmsd:   0.69  nViol: 2499  nRep:26177
# temp:  23.77  fRep:20167.50  fDist:20988.73  rmsd:   0.69  nViol: 2488  nRep:26233
# temp:  23.50  fRep:20157.33  fDist:21002.04  rmsd:   0.69  nViol: 2503  nRep:26201
# temp:  21.89  fRep:20135.59  fDist:21029.63  rmsd:   0.69  nViol: 2504  nRep:26173
# temp:  22.93  fRep:20132.09  fDist:21034.31  rmsd:   0.69  nViol: 2500  nRep:26200
# temp:  21.31  fRep:20180.31  fDist:20990.44  rmsd:   0.69  nViol: 2493  nRep:26184
# temp:  21.39  fRep:20128.07  fDist:21045.85  rmsd:   0.69  nViol: 2497  nRep:26189
# temp:  21.93  fRep:20131.98  fDist:21045.21  rmsd:   0.69  nViol: 2496  nRep:26159
# temp:  22.17  fRep:20167.33  fDist:21013.46  rmsd:   0.69  nViol: 2488  nRep:26212
# temp:  21.63  fRep:20155.36  fDist:21030.10  rmsd:   0.69  nViol: 2498  nRep:26180
# temp:  20.87  fRep:20148.50  fDist:21039.91  rmsd:   0.69  nViol: 2491  nRep:26198
# temp:  20.60  fRep:20149.52  fDist:21042.28  rmsd:   0.69  nViol: 2503  nRep:26182
# temp:  20.17  fRep:20152.86  fDist:21042.10  rmsd:   0.69  nViol: 2491  nRep:26196
# temp:  20.74  fRep:20139.62  fDist:21057.55  rmsd:   0.69  nViol: 2497  nRep:26160
# temp:  19.61  fRep:20159.41  fDist:21042.23  rmsd:   0.69  nViol: 2491  nRep:26176
# temp:  20.01  fRep:20166.03  fDist:21037.79  rmsd:   0.69  nViol: 2496  nRep:26163
# temp:  19.36  fRep:20141.14  fDist:21067.02  rmsd:   0.69  nViol: 2495  nRep:26153
# temp:  19.43  fRep:20186.66  fDist:21023.86  rmsd:   0.69  nViol: 2496  nRep:26189
# temp:  19.53  fRep:20155.36  fDist:21057.63  rmsd:   0.69  nViol: 2498  nRep:26167
# temp:  18.40  fRep:20180.44  fDist:21037.17  rmsd:   0.69  nViol: 2499  nRep:26188
# temp:  18.41  fRep:20184.26  fDist:21035.57  rmsd:   0.69  nViol: 2498  nRep:26176
# temp:  17.97  fRep:20183.62  fDist:21039.26  rmsd:   0.69  nViol: 2498  nRep:26182
# temp:  18.49  fRep:20178.74  fDist:21047.15  rmsd:   0.69  nViol: 2496  nRep:26167
# temp:  17.86  fRep:20176.85  fDist:21052.25  rmsd:   0.69  nViol: 2499  nRep:26152
# temp:  17.82  fRep:20176.48  fDist:21055.25  rmsd:   0.69  nViol: 2493  nRep:26171
# temp:  18.03  fRep:20193.30  fDist:21039.85  rmsd:   0.69  nViol: 2496  nRep:26183
# temp:  17.33  fRep:20199.32  fDist:21037.79  rmsd:   0.69  nViol: 2492  nRep:26184
# temp:  17.12  fRep:20191.43  fDist:21048.90  rmsd:   0.69  nViol: 2505  nRep:26187
# temp:  16.71  fRep:20174.10  fDist:21069.59  rmsd:   0.69  nViol: 2495  nRep:26154
# temp:  16.73  fRep:20195.84  fDist:21050.11  rmsd:   0.69  nViol: 2501  nRep:26158
# temp:  16.64  fRep:20189.05  fDist:21060.26  rmsd:   0.69  nViol: 2494  nRep:26152
# temp:  15.96  fRep:20195.74  fDist:21055.72  rmsd:   0.69  nViol: 2500  nRep:26128
# temp:  15.51  fRep:20189.81  fDist:21065.08  rmsd:   0.69  nViol: 2501  nRep:26129
# temp:  16.23  fRep:20181.34  fDist:21075.39  rmsd:   0.69  nViol: 2499  nRep:26152
# temp:  15.66  fRep:20186.45  fDist:21073.61  rmsd:   0.69  nViol: 2489  nRep:26134
# temp:  15.30  fRep:20202.38  fDist:21060.77  rmsd:   0.69  nViol: 2496  nRep:26159
# temp:  15.20  fRep:20204.17  fDist:21061.08  rmsd:   0.69  nViol: 2495  nRep:26133
# temp:  15.10  fRep:20204.49  fDist:21062.99  rmsd:   0.69  nViol: 2497  nRep:26161
# temp:  15.19  fRep:20237.36  fDist:21033.70  rmsd:   0.69  nViol: 2490  nRep:26144
# temp:  14.75  fRep:20170.24  fDist:21103.10  rmsd:   0.69  nViol: 2494  nRep:26124
# temp:  14.37  fRep:20215.02  fDist:21061.90  rmsd:   0.69  nViol: 2497  nRep:26145
# temp:  14.36  fRep:20186.22  fDist:21092.14  rmsd:   0.69  nViol: 2496  nRep:26136
# temp:  14.06  fRep:20229.04  fDist:21051.78  rmsd:   0.69  nViol: 2498  nRep:26146
# temp:  13.96  fRep:20180.20  fDist:21103.64  rmsd:   0.69  nViol: 2492  nRep:26125
# temp:  13.97  fRep:20194.86  fDist:21090.58  rmsd:   0.69  nViol: 2495  nRep:26159
# temp:  13.86  fRep:20213.28  fDist:21074.70  rmsd:   0.69  nViol: 2499  nRep:26157
# temp:  13.28  fRep:20201.07  fDist:21090.08  rmsd:   0.69  nViol: 2500  nRep:26130
# temp:  13.33  fRep:20212.57  fDist:21080.66  rmsd:   0.69  nViol: 2503  nRep:26137
# temp:  13.09  fRep:20218.63  fDist:21076.47  rmsd:   0.69  nViol: 2502  nRep:26134
# temp:  12.81  fRep:20216.31  fDist:21081.46  rmsd:   0.69  nViol: 2496  nRep:26124
# temp:  12.72  fRep:20223.11  fDist:21077.44  rmsd:   0.69  nViol: 2497  nRep:26119
# temp:  12.88  fRep:20184.25  fDist:21118.25  rmsd:   0.69  nViol: 2503  nRep:26127
# temp:  12.32  fRep:20241.61  fDist:21063.97  rmsd:   0.69  nViol: 2492  nRep:26137
# temp:  12.24  fRep:20218.52  fDist:21088.48  rmsd:   0.69  nViol: 2494  nRep:26109
# temp:  12.27  fRep:20217.66  fDist:21091.63  rmsd:   0.69  nViol: 2498  nRep:26119
# temp:  12.06  fRep:20257.12  fDist:21054.12  rmsd:   0.69  nViol: 2497  nRep:26155
# temp:  11.79  fRep:20226.26  fDist:21087.68  rmsd:   0.69  nViol: 2495  nRep:26136
# temp:  11.40  fRep:20252.60  fDist:21064.64  rmsd:   0.69  nViol: 2496  nRep:26140
# temp:  11.73  fRep:20199.06  fDist:21119.20  rmsd:   0.69  nViol: 2498  nRep:26137
# temp:  11.38  fRep:20253.00  fDist:21067.40  rmsd:   0.69  nViol: 2494  nRep:26124
# temp:  11.32  fRep:20237.77  fDist:21084.85  rmsd:   0.69  nViol: 2492  nRep:26158
# temp:  11.20  fRep:20227.65  fDist:21097.49  rmsd:   0.69  nViol: 2493  nRep:26123
# temp:  10.90  fRep:20231.92  fDist:21095.15  rmsd:   0.69  nViol: 2497  nRep:26118
# temp:  10.93  fRep:20246.22  fDist:21082.38  rmsd:   0.69  nViol: 2498  nRep:26138
# temp:  10.60  fRep:20234.44  fDist:21096.82  rmsd:   0.69  nViol: 2494  nRep:26125
# temp:  10.49  fRep:20224.52  fDist:21108.88  rmsd:   0.69  nViol: 2495  nRep:26106
# temp:  10.36  fRep:20231.64  fDist:21104.00  rmsd:   0.69  nViol: 2497  nRep:26090
# temp:  10.13  fRep:20211.68  fDist:21125.91  rmsd:   0.69  nViol: 2501  nRep:26092
# temp:  10.04  fRep:20249.67  fDist:21090.23  rmsd:   0.69  nViol: 2491  nRep:26123
# temp:  10.21  fRep:20243.00  fDist:21098.47  rmsd:   0.69  nViol: 2497  nRep:26139
# temp:11280.16  fRep: 327.44  fDist:685981.00  rmsd:   9.76  nViol: 2934  nRep: 2285
# temp:9395.90  fRep:5768.21  fDist:194813.30  rmsd:   3.22  nViol: 2891  nRep:26024
# temp:7138.95  fRep:8849.88  fDist:45877.23  rmsd:   1.05  nViol: 2624  nRep:28838
# temp:5480.18  fRep:7432.98  fDist:15118.47  rmsd:   0.50  nViol: 2290  nRep:30279
# temp:4949.66  fRep:7787.37  fDist:10615.72  rmsd:   0.41  nViol: 2099  nRep:31792
# temp:4876.67  fRep:7351.05  fDist:10536.80  rmsd:   0.41  nViol: 2103  nRep:33381
# temp:4592.75  fRep:7605.98  fDist:9942.36  rmsd:   0.40  nViol: 2129  nRep:35050
# temp:4690.46  fRep:8293.94  fDist:9801.94  rmsd:   0.39  nViol: 2156  nRep:36802
# temp:4582.82  fRep:9189.35  fDist:10008.61  rmsd:   0.40  nViol: 2136  nRep:38642
# temp:4498.65  fRep:9453.70  fDist:10181.84  rmsd:   0.41  nViol: 2167  nRep:40574
# temp:4535.98  fRep:10118.09  fDist:10818.01  rmsd:   0.44  nViol: 2136  nRep:42602
# temp:4335.15  fRep:11432.87  fDist:11573.22  rmsd:   0.47  nViol: 2158  nRep:44732
# temp:4352.27  fRep:11671.39  fDist:12102.26  rmsd:   0.47  nViol: 2186  nRep:44995
# temp:4274.29  fRep:11539.40  fDist:11934.27  rmsd:   0.47  nViol: 2192  nRep:45149
# temp:4262.80  fRep:11829.41  fDist:11280.10  rmsd:   0.46  nViol: 2199  nRep:45412
# temp:4151.22  fRep:11565.54  fDist:11566.32  rmsd:   0.46  nViol: 2187  nRep:44939
# temp:4025.02  fRep:11418.25  fDist:11733.64  rmsd:   0.46  nViol: 2195  nRep:44760
# temp:3988.00  fRep:11080.01  fDist:11896.02  rmsd:   0.47  nViol: 2190  nRep:43543
# temp:3957.46  fRep:11421.45  fDist:11546.77  rmsd:   0.45  nViol: 2196  nRep:44777
# temp:3919.41  fRep:11163.95  fDist:11808.98  rmsd:   0.47  nViol: 2209  nRep:43863
# temp:3897.51  fRep:11460.02  fDist:11397.23  rmsd:   0.46  nViol: 2199  nRep:44469
# temp:3720.91  fRep:11388.00  fDist:11537.10  rmsd:   0.47  nViol: 2175  nRep:44711
# temp:3922.11  fRep:11487.54  fDist:11154.89  rmsd:   0.45  nViol: 2167  nRep:44862
# temp:3819.88  fRep:10980.21  fDist:11767.75  rmsd:   0.47  nViol: 2192  nRep:43771
# temp:3704.20  fRep:11591.52  fDist:11024.18  rmsd:   0.45  nViol: 2197  nRep:45017
# temp:3699.95  fRep:11382.94  fDist:10996.48  rmsd:   0.45  nViol: 2160  nRep:44492
# temp:3547.33  fRep:11317.25  fDist:11370.40  rmsd:   0.46  nViol: 2162  nRep:44136
# temp:3605.44  fRep:11516.83  fDist:11039.68  rmsd:   0.45  nViol: 2188  nRep:44923
# temp:3564.51  fRep:11332.81  fDist:11113.58  rmsd:   0.45  nViol: 2157  nRep:44130
# temp:3478.88  fRep:11478.13  fDist:10877.55  rmsd:   0.45  nViol: 2178  nRep:44351
# temp:3490.07  fRep:11224.32  fDist:11090.13  rmsd:   0.45  nViol: 2191  nRep:44012
# temp:3356.47  fRep:11216.52  fDist:11252.77  rmsd:   0.46  nViol: 2187  nRep:43347
# temp:3332.45  fRep:11318.80  fDist:10941.53  rmsd:   0.45  nViol: 2194  nRep:44503
# temp:3246.16  fRep:11427.23  fDist:10818.17  rmsd:   0.45  nViol: 2182  nRep:43949
# temp:3220.81  fRep:11380.76  fDist:11052.52  rmsd:   0.45  nViol: 2168  nRep:44328
# temp:3232.74  fRep:11083.38  fDist:11208.55  rmsd:   0.46  nViol: 2191  nRep:44068
# temp:3213.75  fRep:11606.98  fDist:10524.91  rmsd:   0.44  nViol: 2156  nRep:44560
# temp:3166.98  fRep:11341.92  fDist:10811.15  rmsd:   0.45  nViol: 2170  nRep:44381
# temp:3155.47  fRep:11422.45  fDist:10767.70  rmsd:   0.45  nViol: 2203  nRep:44567
# temp:2985.13  fRep:11340.04  fDist:10749.82  rmsd:   0.45  nViol: 2160  nRep:44922
# temp:3032.83  fRep:11855.08  fDist:10230.69  rmsd:   0.43  nViol: 2146  nRep:45533
# temp:2970.58  fRep:11406.29  fDist:10549.87  rmsd:   0.44  nViol: 2174  nRep:44786
# temp:2973.28  fRep:11253.67  fDist:10570.55  rmsd:   0.44  nViol: 2170  nRep:44088
# temp:2959.41  fRep:11388.62  fDist:10505.55  rmsd:   0.44  nViol: 2157  nRep:44087
# temp:2908.88  fRep:11210.56  fDist:10529.98  rmsd:   0.44  nViol: 2161  nRep:43804
# temp:2718.40  fRep:11433.77  fDist:10419.67  rmsd:   0.44  nViol: 2145  nRep:44650
# temp:2827.03  fRep:10810.41  fDist:10750.28  rmsd:   0.45  nViol: 2175  nRep:43181
# temp:2720.09  fRep:11297.29  fDist:10600.75  rmsd:   0.45  nViol: 2207  nRep:43997
# temp:2729.65  fRep:11378.33  fDist:10535.89  rmsd:   0.44  nViol: 2173  nRep:44213
# temp:2805.49  fRep:11253.51  fDist:10379.05  rmsd:   0.44  nViol: 2160  nRep:43908
# temp:2613.88  fRep:11144.93  fDist:10515.99  rmsd:   0.44  nViol: 2210  nRep:43666
# temp:2615.60  fRep:11065.58  fDist:10798.58  rmsd:   0.45  nViol: 2170  nRep:43622
# temp:2578.12  fRep:11471.31  fDist:10197.56  rmsd:   0.44  nViol: 2172  nRep:44641
# temp:2621.43  fRep:11399.97  fDist:10244.58  rmsd:   0.43  nViol: 2179  nRep:44032
# temp:2575.05  fRep:11182.70  fDist:10298.86  rmsd:   0.44  nViol: 2191  nRep:43979
# temp:2545.44  fRep:11547.46  fDist:9904.00  rmsd:   0.43  nViol: 2139  nRep:44543
# temp:2494.48  fRep:11069.67  fDist:10331.57  rmsd:   0.44  nViol: 2150  nRep:43605
# temp:2439.26  fRep:11372.47  fDist:10013.92  rmsd:   0.43  nViol: 2129  nRep:44594
# temp:2355.12  fRep:11308.38  fDist:10306.20  rmsd:   0.44  nViol: 2183  nRep:44155
# temp:2324.52  fRep:11472.14  fDist:9988.52  rmsd:   0.43  nViol: 2177  nRep:44608
# temp:2360.35  fRep:11334.30  fDist:10107.43  rmsd:   0.44  nViol: 2116  nRep:43987
# temp:2311.15  fRep:11537.25  fDist:9901.10  rmsd:   0.43  nViol: 2131  nRep:44106
# temp:2257.18  fRep:11684.88  fDist:9687.00  rmsd:   0.43  nViol: 2172  nRep:44770
# temp:2201.85  fRep:11202.18  fDist:10136.43  rmsd:   0.43  nViol: 2133  nRep:43794
# temp:2217.89  fRep:11645.98  fDist:9777.77  rmsd:   0.43  nViol: 2124  nRep:44611
# temp:2213.05  fRep:11227.11  fDist:10177.93  rmsd:   0.43  nViol: 2167  nRep:43904
# temp:2206.37  fRep:11514.40  fDist:9821.44  rmsd:   0.43  nViol: 2141  nRep:44249
# temp:2163.10  fRep:11049.93  fDist:10113.49  rmsd:   0.44  nViol: 2155  nRep:43100
# temp:2139.47  fRep:11452.78  fDist:9783.08  rmsd:   0.43  nViol: 2150  nRep:43950
# temp:2070.28  fRep:11299.39  fDist:10015.00  rmsd:   0.43  nViol: 2147  nRep:44238
# temp:2079.86  fRep:11547.43  fDist:9582.93  rmsd:   0.43  nViol: 2165  nRep:44407
# temp:2071.54  fRep:11418.67  fDist:9730.81  rmsd:   0.43  nViol: 2110  nRep:44015
# temp:2045.04  fRep:11395.12  fDist:9868.24  rmsd:   0.43  nViol: 2169  nRep:43923
# temp:1962.36  fRep:11443.64  fDist:9840.86  rmsd:   0.43  nViol: 2159  nRep:44136
# temp:1882.78  fRep:11167.02  fDist:10183.76  rmsd:   0.44  nViol: 2163  nRep:43590
# temp:1981.26  fRep:11182.15  fDist:9980.26  rmsd:   0.44  nViol: 2171  nRep:43498
# temp:1909.78  fRep:11403.51  fDist:9812.90  rmsd:   0.43  nViol: 2128  nRep:43764
# temp:1922.65  fRep:11267.28  fDist:9678.92  rmsd:   0.43  nViol: 2141  nRep:43573
# temp:1885.08  fRep:11224.96  fDist:9795.46  rmsd:   0.43  nViol: 2160  nRep:43545
# ...
# temp:  97.09  fRep:375571.99  fDist:414796.54  rmsd:   0.58  nViol:66081  nRep:1065762
# temp:  96.01  fRep:375951.25  fDist:414790.94  rmsd:   0.58  nViol:66164  nRep:1065547
# temp:  94.63  fRep:375795.25  fDist:415364.04  rmsd:   0.58  nViol:66107  nRep:1064736
# temp:  93.50  fRep:375702.46  fDist:415834.92  rmsd:   0.58  nViol:66093  nRep:1063749
# temp:  92.33  fRep:375710.27  fDist:416235.20  rmsd:   0.58  nViol:66110  nRep:1063441
# temp:  91.36  fRep:375703.95  fDist:416568.40  rmsd:   0.58  nViol:66158  nRep:1062429
# temp:  90.26  fRep:376003.11  fDist:416596.46  rmsd:   0.58  nViol:66143  nRep:1062317
# temp:  88.82  fRep:376051.44  fDist:416957.65  rmsd:   0.58  nViol:66186  nRep:1062105
# temp:  87.93  fRep:376016.97  fDist:417276.72  rmsd:   0.58  nViol:66229  nRep:1061585
# temp:  86.80  fRep:376208.88  fDist:417419.27  rmsd:   0.58  nViol:66249  nRep:1061437
# temp:  85.76  fRep:376036.38  fDist:417849.25  rmsd:   0.59  nViol:66186  nRep:1060799
# temp:  84.66  fRep:375987.48  fDist:418223.74  rmsd:   0.59  nViol:66239  nRep:1059115
# temp:  83.62  fRep:376022.15  fDist:418553.93  rmsd:   0.59  nViol:66314  nRep:1058504
# temp:  82.59  fRep:376070.95  fDist:418783.62  rmsd:   0.59  nViol:66306  nRep:1057375
# temp:  81.45  fRep:376431.80  fDist:418695.32  rmsd:   0.59  nViol:66221  nRep:1058700
# temp:  80.58  fRep:376131.23  fDist:419252.79  rmsd:   0.59  nViol:66357  nRep:1057011
# temp:  79.63  fRep:376568.26  fDist:419062.17  rmsd:   0.59  nViol:66320  nRep:1058142
# temp:  78.66  fRep:376345.01  fDist:419523.79  rmsd:   0.59  nViol:66373  nRep:1057027
# temp:  77.52  fRep:376813.80  fDist:419348.43  rmsd:   0.59  nViol:66387  nRep:1057625
# temp:  76.71  fRep:376698.95  fDist:419756.41  rmsd:   0.59  nViol:66434  nRep:1056748
# temp:  75.90  fRep:376349.11  fDist:420335.71  rmsd:   0.59  nViol:66374  nRep:1055962
# temp:  74.74  fRep:376590.37  fDist:420321.44  rmsd:   0.59  nViol:66391  nRep:1055740
# temp:  73.83  fRep:376410.94  fDist:420733.71  rmsd:   0.59  nViol:66447  nRep:1055285
# temp:  72.80  fRep:376568.41  fDist:420802.53  rmsd:   0.59  nViol:66371  nRep:1055178
# temp:  71.90  fRep:376692.58  fDist:420911.33  rmsd:   0.59  nViol:66455  nRep:1055027
# temp:  71.21  fRep:376538.81  fDist:421261.54  rmsd:   0.59  nViol:66350  nRep:1054087
# temp:  70.50  fRep:376903.27  fDist:421150.85  rmsd:   0.59  nViol:66525  nRep:1054532
# temp:  69.40  fRep:376650.08  fDist:421587.72  rmsd:   0.59  nViol:66459  nRep:1053412
# temp:  68.77  fRep:376439.42  fDist:421965.75  rmsd:   0.59  nViol:66496  nRep:1052888
# temp:  67.72  fRep:376653.91  fDist:421968.21  rmsd:   0.59  nViol:66510  nRep:1052688
# temp:  67.04  fRep:376544.35  fDist:422248.43  rmsd:   0.59  nViol:66533  nRep:1052307
# temp:  66.20  fRep:376411.62  fDist:422513.57  rmsd:   0.59  nViol:66599  nRep:1051985
# temp:  65.25  fRep:376500.31  fDist:422667.94  rmsd:   0.59  nViol:66481  nRep:1051578
# temp:  64.27  fRep:376633.29  fDist:422720.52  rmsd:   0.59  nViol:66645  nRep:1051354
# temp:  63.54  fRep:376403.76  fDist:423102.36  rmsd:   0.59  nViol:66699  nRep:1050694
# temp:  62.97  fRep:376653.23  fDist:423053.71  rmsd:   0.59  nViol:66634  nRep:1050529
# temp:  62.17  fRep:376736.84  fDist:423135.50  rmsd:   0.59  nViol:66604  nRep:1050327
# temp:  61.26  fRep:376725.31  fDist:423307.56  rmsd:   0.59  nViol:66651  nRep:1050564
# temp:  60.79  fRep:376728.21  fDist:423453.11  rmsd:   0.59  nViol:66615  nRep:1050193
# temp:  59.69  fRep:376980.66  fDist:423383.02  rmsd:   0.59  nViol:66693  nRep:1050234
# temp:  59.13  fRep:376828.82  fDist:423695.16  rmsd:   0.59  nViol:66733  nRep:1049751
# temp:  58.40  fRep:376789.96  fDist:423874.84  rmsd:   0.59  nViol:66785  nRep:1049458
# temp:  57.69  fRep:377002.43  fDist:423790.40  rmsd:   0.59  nViol:66632  nRep:1049712
# temp:  56.88  fRep:376935.89  fDist:424041.88  rmsd:   0.59  nViol:66685  nRep:1048886
# temp:  56.15  fRep:376991.04  fDist:424124.46  rmsd:   0.59  nViol:66754  nRep:1049210
# temp:  55.52  fRep:376801.43  fDist:424428.45  rmsd:   0.59  nViol:66779  nRep:1048866
# temp:  54.90  fRep:376902.39  fDist:424470.90  rmsd:   0.59  nViol:66736  nRep:1047596
# temp:  54.24  fRep:376417.85  fDist:425102.38  rmsd:   0.59  nViol:66701  nRep:1047788
# temp:  53.45  fRep:376896.65  fDist:424749.62  rmsd:   0.59  nViol:66820  nRep:1047396
# temp:  52.85  fRep:376805.35  fDist:424979.99  rmsd:   0.59  nViol:66806  nRep:1047738
# temp:  52.22  fRep:376748.52  fDist:425148.85  rmsd:   0.59  nViol:66789  nRep:1047050
# temp:  51.56  fRep:377024.21  fDist:425039.71  rmsd:   0.59  nViol:66768  nRep:1047458
# temp:  50.87  fRep:377201.48  fDist:424987.74  rmsd:   0.59  nViol:66752  nRep:1047377
# temp:  50.15  fRep:376996.68  fDist:425283.99  rmsd:   0.59  nViol:66818  nRep:1046815
# temp:  49.53  fRep:377005.16  fDist:425396.36  rmsd:   0.59  nViol:66814  nRep:1046401
# temp:  49.13  fRep:377123.16  fDist:425372.09  rmsd:   0.59  nViol:66917  nRep:1047045
# temp:  48.49  fRep:377234.93  fDist:425400.76  rmsd:   0.59  nViol:66952  nRep:1046175
# temp:  47.81  fRep:377140.87  fDist:425619.92  rmsd:   0.59  nViol:66826  nRep:1046229
# temp:  47.25  fRep:377096.47  fDist:425750.26  rmsd:   0.59  nViol:66913  nRep:1046179
# temp:  46.75  fRep:377258.49  fDist:425690.24  rmsd:   0.59  nViol:66909  nRep:1045418
# temp:  46.06  fRep:377040.92  fDist:426024.88  rmsd:   0.59  nViol:66918  nRep:1045428
# temp:  45.51  fRep:376771.41  fDist:426411.62  rmsd:   0.59  nViol:66942  nRep:1044865
# temp:  44.99  fRep:377043.34  fDist:426252.14  rmsd:   0.59  nViol:66919  nRep:1045488
# temp:  44.25  fRep:377161.38  fDist:426226.63  rmsd:   0.59  nViol:66919  nRep:1045442
# temp:  43.85  fRep:377028.46  fDist:426464.96  rmsd:   0.59  nViol:66965  nRep:1044676
# temp:  43.30  fRep:377195.95  fDist:426395.88  rmsd:   0.59  nViol:67033  nRep:1045064
# temp:  42.85  fRep:377280.63  fDist:426397.72  rmsd:   0.59  nViol:67002  nRep:1044600
# temp:  42.28  fRep:377083.45  fDist:426691.57  rmsd:   0.59  nViol:67097  nRep:1044621
# temp:  41.66  fRep:377205.59  fDist:426683.28  rmsd:   0.59  nViol:67031  nRep:1044701
# temp:  41.28  fRep:377003.24  fDist:426955.37  rmsd:   0.59  nViol:67010  nRep:1044058
# temp:  40.63  fRep:377481.83  fDist:426575.56  rmsd:   0.59  nViol:67009  nRep:1044713
# temp:  40.20  fRep:377152.32  fDist:426988.33  rmsd:   0.59  nViol:66978  nRep:1043248
# temp:  39.68  fRep:377316.58  fDist:426908.34  rmsd:   0.59  nViol:67009  nRep:1043954
# temp:  39.18  fRep:377160.18  fDist:427166.07  rmsd:   0.59  nViol:67053  nRep:1043353
# temp:  38.71  fRep:377102.59  fDist:427290.46  rmsd:   0.59  nViol:67080  nRep:1043581
# temp:  38.29  fRep:377371.38  fDist:427109.07  rmsd:   0.59  nViol:67124  nRep:1043058
# temp:  37.71  fRep:377443.37  fDist:427153.05  rmsd:   0.59  nViol:67040  nRep:1043496
# temp:  37.42  fRep:377145.26  fDist:427473.62  rmsd:   0.59  nViol:67115  nRep:1042394
# temp:  36.81  fRep:377368.14  fDist:427354.21  rmsd:   0.59  nViol:67109  nRep:1043427
# temp:  36.36  fRep:377221.61  fDist:427597.24  rmsd:   0.59  nViol:67138  nRep:1042705
# temp:  35.89  fRep:377421.55  fDist:427469.60  rmsd:   0.59  nViol:67186  nRep:1042814
# temp:  35.53  fRep:377181.98  fDist:427781.27  rmsd:   0.59  nViol:67161  nRep:1042267
# temp:  35.15  fRep:377193.61  fDist:427857.00  rmsd:   0.59  nViol:67123  nRep:1042087
# temp:  34.57  fRep:377169.51  fDist:427950.98  rmsd:   0.59  nViol:67101  nRep:1042138
# temp:  34.26  fRep:377183.93  fDist:428000.55  rmsd:   0.59  nViol:67195  nRep:1042147
# temp:  33.79  fRep:377223.41  fDist:428028.71  rmsd:   0.59  nViol:67116  nRep:1041758
# temp:  33.32  fRep:377406.59  fDist:427933.37  rmsd:   0.59  nViol:67149  nRep:1042449
# temp:  32.92  fRep:377380.09  fDist:428048.79  rmsd:   0.59  nViol:67265  nRep:1041801
# temp:  32.54  fRep:377359.16  fDist:428126.57  rmsd:   0.59  nViol:67123  nRep:1042097
# temp:  32.16  fRep:377465.16  fDist:428091.15  rmsd:   0.59  nViol:67260  nRep:1042028
# temp:  31.74  fRep:377359.04  fDist:428272.97  rmsd:   0.59  nViol:67181  nRep:1041608
# temp:  31.33  fRep:377277.68  fDist:428420.38  rmsd:   0.59  nViol:67209  nRep:1041076
# temp:  31.03  fRep:377677.81  fDist:428079.53  rmsd:   0.59  nViol:67119  nRep:1042068
# temp:  30.58  fRep:377305.68  fDist:428514.32  rmsd:   0.59  nViol:67228  nRep:1041156
# temp:  30.22  fRep:377499.32  fDist:428389.74  rmsd:   0.59  nViol:67273  nRep:1041201
# temp:  29.78  fRep:377198.75  fDist:428771.84  rmsd:   0.59  nViol:67266  nRep:1040853
# temp:  29.43  fRep:377469.76  fDist:428552.86  rmsd:   0.59  nViol:67282  nRep:1040458
# temp:  29.08  fRep:377490.13  fDist:428594.08  rmsd:   0.59  nViol:67280  nRep:1040866
# temp:  28.74  fRep:377488.71  fDist:428655.49  rmsd:   0.59  nViol:67278  nRep:1040784
# temp:  28.28  fRep:377486.69  fDist:428723.28  rmsd:   0.59  nViol:67308  nRep:1040603
# temp:  27.89  fRep:377491.86  fDist:428786.86  rmsd:   0.59  nViol:67293  nRep:1040201
# temp:  27.63  fRep:377474.25  fDist:428843.43  rmsd:   0.59  nViol:67298  nRep:1040115
# temp:  27.29  fRep:377375.36  fDist:429011.88  rmsd:   0.60  nViol:67320  nRep:1040091
# temp:  26.98  fRep:377411.50  fDist:429041.86  rmsd:   0.59  nViol:67326  nRep:1040044
# temp:  26.70  fRep:377689.21  fDist:428838.74  rmsd:   0.59  nViol:67313  nRep:1040007
# temp:  26.35  fRep:377586.57  fDist:428984.44  rmsd:   0.59  nViol:67246  nRep:1039916
# temp:  25.99  fRep:377454.97  fDist:429168.49  rmsd:   0.60  nViol:67375  nRep:1039134
# temp:  25.73  fRep:377359.38  fDist:429315.28  rmsd:   0.60  nViol:67395  nRep:1039545
# temp:  25.42  fRep:377524.51  fDist:429225.36  rmsd:   0.60  nViol:67369  nRep:1039398
# temp:  25.05  fRep:377417.38  fDist:429373.91  rmsd:   0.60  nViol:67286  nRep:1039755
# temp:  24.72  fRep:377598.23  fDist:429265.35  rmsd:   0.60  nViol:67396  nRep:1039357
# temp:  24.49  fRep:377773.03  fDist:429135.25  rmsd:   0.60  nViol:67334  nRep:1039940
# temp:  24.16  fRep:377512.41  fDist:429457.32  rmsd:   0.60  nViol:67380  nRep:1039610
# temp:  23.86  fRep:377636.14  fDist:429376.78  rmsd:   0.60  nViol:67401  nRep:1039381
# temp:  23.52  fRep:377603.30  fDist:429456.71  rmsd:   0.60  nViol:67389  nRep:1039269
# temp:  23.29  fRep:377641.20  fDist:429475.75  rmsd:   0.60  nViol:67477  nRep:1039219
# temp:  23.06  fRep:377655.28  fDist:429496.84  rmsd:   0.60  nViol:67395  nRep:1039379
# temp:  22.78  fRep:377538.21  fDist:429666.72  rmsd:   0.60  nViol:67449  nRep:1038844
# temp:  22.43  fRep:377448.63  fDist:429817.28  rmsd:   0.60  nViol:67453  nRep:1038691
# temp:  22.13  fRep:377550.65  fDist:429769.90  rmsd:   0.60  nViol:67506  nRep:1038560
# temp:  21.80  fRep:377552.45  fDist:429827.80  rmsd:   0.60  nViol:67521  nRep:1038719
# temp:  21.60  fRep:377564.27  fDist:429857.61  rmsd:   0.60  nViol:67451  nRep:1038370
# temp:  21.33  fRep:377530.33  fDist:429939.41  rmsd:   0.60  nViol:67455  nRep:1038461
# temp:  21.03  fRep:377605.49  fDist:429908.22  rmsd:   0.60  nViol:67452  nRep:1038432
# temp:  20.82  fRep:377582.82  fDist:429985.47  rmsd:   0.60  nViol:67471  nRep:1038057
# temp:  20.51  fRep:377798.88  fDist:429811.83  rmsd:   0.60  nViol:67471  nRep:1038395
# temp:  20.25  fRep:377529.04  fDist:430134.27  rmsd:   0.60  nViol:67500  nRep:1038150
# temp:  20.06  fRep:377668.53  fDist:430027.12  rmsd:   0.60  nViol:67485  nRep:1037812
# temp:  19.75  fRep:377578.71  fDist:430168.73  rmsd:   0.60  nViol:67563  nRep:1038156
# temp:  19.58  fRep:377707.26  fDist:430082.83  rmsd:   0.60  nViol:67520  nRep:1037877
# temp:  19.30  fRep:377601.87  fDist:430236.35  rmsd:   0.60  nViol:67503  nRep:1038100
# temp:  19.10  fRep:377731.11  fDist:430154.66  rmsd:   0.60  nViol:67566  nRep:1037812
# temp:  18.83  fRep:377550.41  fDist:430384.15  rmsd:   0.60  nViol:67526  nRep:1037929
# temp:  18.59  fRep:377669.53  fDist:430311.78  rmsd:   0.60  nViol:67514  nRep:1037793
# temp:  18.42  fRep:377769.12  fDist:430249.29  rmsd:   0.60  nViol:67462  nRep:1037587
# temp:  18.11  fRep:377685.68  fDist:430376.16  rmsd:   0.60  nViol:67526  nRep:1037656
# temp:  17.91  fRep:377910.14  fDist:430199.99  rmsd:   0.60  nViol:67567  nRep:1037959
# temp:  17.70  fRep:377775.59  fDist:430366.39  rmsd:   0.60  nViol:67512  nRep:1037682
# temp:  17.47  fRep:377931.90  fDist:430253.91  rmsd:   0.60  nViol:67563  nRep:1037594
# temp:  17.28  fRep:377584.27  fDist:430638.66  rmsd:   0.60  nViol:67573  nRep:1037433
# temp:  17.07  fRep:377853.19  fDist:430413.40  rmsd:   0.60  nViol:67625  nRep:1037401
# temp:  16.83  fRep:377709.55  fDist:430604.36  rmsd:   0.60  nViol:67598  nRep:1037295
# temp:  16.57  fRep:377826.25  fDist:430534.27  rmsd:   0.60  nViol:67597  nRep:1037300
# temp:  16.42  fRep:377728.42  fDist:430669.24  rmsd:   0.60  nViol:67583  nRep:1036959
# temp:  16.25  fRep:377811.29  fDist:430619.58  rmsd:   0.60  nViol:67667  nRep:1036808
# temp:  16.04  fRep:377780.62  fDist:430689.34  rmsd:   0.60  nViol:67600  nRep:1036842
# temp:  15.76  fRep:377728.00  fDist:430782.52  rmsd:   0.60  nViol:67563  nRep:1037119
# temp:  15.66  fRep:377829.69  fDist:430716.48  rmsd:   0.60  nViol:67629  nRep:1036842
# temp:  15.41  fRep:377537.59  fDist:431055.33  rmsd:   0.60  nViol:67598  nRep:1036480
# temp:  15.24  fRep:377725.44  fDist:430904.39  rmsd:   0.60  nViol:67613  nRep:1036286
# temp:  15.05  fRep:377813.60  fDist:430845.11  rmsd:   0.60  nViol:67623  nRep:1036784
# temp:  14.80  fRep:377703.55  fDist:430999.31  rmsd:   0.60  nViol:67651  nRep:1036351
# temp:  14.65  fRep:377842.19  fDist:430893.95  rmsd:   0.60  nViol:67642  nRep:1036967
# temp:  14.51  fRep:377708.34  fDist:431068.36  rmsd:   0.60  nViol:67665  nRep:1036549
# temp:  14.31  fRep:377822.93  fDist:430993.58  rmsd:   0.60  nViol:67617  nRep:1036416
# temp:  14.12  fRep:377795.79  fDist:431051.33  rmsd:   0.60  nViol:67678  nRep:1036243
# temp:  13.99  fRep:377953.51  fDist:430922.92  rmsd:   0.60  nViol:67657  nRep:1036539
# temp:  13.78  fRep:377772.90  fDist:431148.79  rmsd:   0.60  nViol:67668  nRep:1036450
# temp:  13.63  fRep:377732.34  fDist:431220.69  rmsd:   0.60  nViol:67668  nRep:1036414
# temp:  13.46  fRep:377800.79  fDist:431186.41  rmsd:   0.60  nViol:67604  nRep:1036346
# temp:  13.27  fRep:377908.06  fDist:431112.97  rmsd:   0.60  nViol:67643  nRep:1036571
# temp:  13.12  fRep:377826.33  fDist:431234.94  rmsd:   0.60  nViol:67689  nRep:1036175
# temp:  13.02  fRep:377618.45  fDist:431468.19  rmsd:   0.60  nViol:67703  nRep:1035713
# temp:  12.77  fRep:377966.62  fDist:431164.20  rmsd:   0.60  nViol:67675  nRep:1036224
# temp:  12.63  fRep:377735.61  fDist:431424.32  rmsd:   0.60  nViol:67627  nRep:1036167
# temp:  12.49  fRep:377939.06  fDist:431257.38  rmsd:   0.60  nViol:67702  nRep:1035911
# temp:  12.33  fRep:377858.21  fDist:431367.08  rmsd:   0.60  nViol:67659  nRep:1036089
# temp:  12.19  fRep:378008.55  fDist:431251.74  rmsd:   0.60  nViol:67666  nRep:1035949
# temp:  12.04  fRep:377792.69  fDist:431503.49  rmsd:   0.60  nViol:67763  nRep:1035723
# temp:  11.86  fRep:377837.83  fDist:431492.35  rmsd:   0.60  nViol:67731  nRep:1035797
# temp:  11.73  fRep:377793.04  fDist:431568.82  rmsd:   0.60  nViol:67772  nRep:1035592
# temp:  11.62  fRep:377854.30  fDist:431541.93  rmsd:   0.60  nViol:67732  nRep:1035690
# temp:  11.44  fRep:377929.75  fDist:431499.75  rmsd:   0.60  nViol:67754  nRep:1035606
# temp:  11.31  fRep:377837.32  fDist:431621.13  rmsd:   0.60  nViol:67790  nRep:1035630
# temp:  11.16  fRep:377780.81  fDist:431708.95  rmsd:   0.60  nViol:67736  nRep:1035369
# temp:  11.05  fRep:377910.90  fDist:431614.58  rmsd:   0.60  nViol:67750  nRep:1035388
# temp:  10.90  fRep:377713.09  fDist:431844.53  rmsd:   0.60  nViol:67746  nRep:1035202
# temp:  10.75  fRep:377856.80  fDist:431727.24  rmsd:   0.60  nViol:67753  nRep:1035260
# temp:  10.63  fRep:377821.59  fDist:431793.79  rmsd:   0.60  nViol:67742  nRep:1035091
# temp:  10.49  fRep:377901.98  fDist:431748.23  rmsd:   0.60  nViol:67778  nRep:1035315
# temp:  10.36  fRep:377739.86  fDist:431938.25  rmsd:   0.60  nViol:67812  nRep:1035181
# temp:  10.24  fRep:377918.68  fDist:431790.03  rmsd:   0.60  nViol:67737  nRep:1035156
# temp:  10.12  fRep:377786.54  fDist:431952.72  rmsd:   0.60  nViol:67776  nRep:1034954
# Saved structure file to: example_chromo_data/Cell_1_structure.pdb
