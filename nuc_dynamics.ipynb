# %%
# %load_ext cythonmagic

# %%
# %%cython
# from libc.math cimport exp, abs, sqrt
# from numpy cimport ndarray, double_t, int_t
# import numpy, cython, time, gc
#
# BOLTZMANN_K = 0.0019872041
#
# #ctypedef int_t   int
# #ctypedef double_t double
#
# class NucCythonError(Exception):
#
#   def __init__(self, err):
#
#     Exception.__init__(self, err)
#
#
# cdef int getRepulsionList(ndarray[int,   ndim=2] repList,
#                           ndarray[double, ndim=2] coords,
#                           int nCoords, int nRepMax,
#                           double repDist,
#                           ndarray[double, ndim=1] radii):
#
#   cdef int i, j
#   cdef int n = 0
#   cdef double dx, dy, dz, d2
#   cdef double distLim
#   cdef double distLim2
#
#   for i in range(nCoords-2):
#     for j in range(i+2, nCoords):
#       distLim = repDist + radii[i] + radii[j]
#       distLim2 = distLim * distLim
#
#       dx = coords[i,0] - coords[j,0]
#       if abs(dx) > distLim:
#         continue
#
#       dy = coords[i,1] - coords[j,1]
#       if abs(dy) > distLim:
#         continue
#
#       dz = coords[i,2] - coords[j,2]
#       if abs(dz) > distLim:
#         continue
#
#       d2 = dx*dx + dy*dy + dz*dz
#
#       if d2 > distLim2:
#         continue
#
#       repList[n,0] = i
#       repList[n,1] = j
#
#       n += 1
#
#       #return if we reached max, something is seriously wrong anyway
#       if n == nRepMax:
#         return n
#
#   return n
#
#
# cdef double getTemp(ndarray[double] masses,
#                     ndarray[double, ndim=2] veloc,
#                     int nCoords):
#   cdef int i
#   cdef double kin = 0.0
#
#   for i in range(nCoords):
#     kin += masses[i] * (veloc[i,0]*veloc[i,0] + veloc[i,1]*veloc[i,1] + veloc[i,2]*veloc[i,2])
#
#   return kin / (3 * nCoords * BOLTZMANN_K)
#
#
# def getStats(ndarray[int,   ndim=2] restIndices,
#              ndarray[double, ndim=2] restLimits,
#              ndarray[double, ndim=2] coords,
#              int nRest):
#
#   cdef int i, nViol = 0
#   cdef int j, k
#   cdef double viol, dmin, dmax, dx, dy, dz, r, s = 0
#
#   for i in range(nRest):
#     j = restIndices[i,0]
#     k = restIndices[i,1]
#
#     if j == k:
#       continue
#
#     dmin = restLimits[i,0]
#     dmax = restLimits[i,1]
#
#     dx = coords[j,0] - coords[k,0]
#     dy = coords[j,1] - coords[k,1]
#     dz = coords[j,2] - coords[k,2]
#     r = sqrt(dx*dx + dy*dy + dz*dz)
#
#     if r < dmin:
#       viol = dmin - r
#       nViol += 1
#
#     elif r > dmax:
#       viol = r - dmax
#       nViol += 1
#
#     else:
#       viol = 0
#
#     s += viol * viol
#
#   return nViol, sqrt(s/nRest)
#
#
# cdef void updateMotion(ndarray[double] masses,
#                        ndarray[double, ndim=2] forces,
#                        ndarray[double, ndim=2] accel,
#                        ndarray[double, ndim=2] veloc,
#                        ndarray[double, ndim=2] coords,
#                        int nCoords, double tRef,
#                        double tStep, double beta):
#
#   cdef int i
#   cdef double r, rtStep, temp
#
#   rtStep = 0.5 * tStep * tStep
#   temp = getTemp(masses, veloc, nCoords)
#   temp = max(temp, 0.001)
#   r = beta * (tRef/temp-1.0)
#
#   for i in range(nCoords):
#
#     accel[i,0] = forces[i,0] / masses[i] + r * veloc[i,0]
#     accel[i,1] = forces[i,1] / masses[i] + r * veloc[i,1]
#     accel[i,2] = forces[i,2] / masses[i] + r * veloc[i,2]
#
#     coords[i,0] += tStep * veloc[i,0] + rtStep * accel[i,0]
#     coords[i,1] += tStep * veloc[i,1] + rtStep * accel[i,1]
#     coords[i,2] += tStep * veloc[i,2] + rtStep * accel[i,2]
#
#     veloc[i,0] += tStep * accel[i,0]
#     veloc[i,1] += tStep * accel[i,1]
#     veloc[i,2] += tStep * accel[i,2]
#
#
# cdef void updateVelocity(ndarray[double] masses,
#                          ndarray[double, ndim=2] forces,
#                          ndarray[double, ndim=2] accel,
#                          ndarray[double, ndim=2] veloc,
#                          int nCoords, double tRef,
#                          double tStep, double beta):
#
#   cdef int i
#   cdef double r, temp
#
#   temp = getTemp(masses, veloc, nCoords)
#   #avoid division by 0 temperature
#   temp = max(temp, 0.001)
#   r = beta * (tRef/temp-1.0)
#
#   for i in range(nCoords):
#     veloc[i,0] += 0.5 * tStep * (forces[i,0] / masses[i] + r * veloc[i,0] - accel[i,0])
#     veloc[i,1] += 0.5 * tStep * (forces[i,1] / masses[i] + r * veloc[i,1] - accel[i,1])
#     veloc[i,2] += 0.5 * tStep * (forces[i,2] / masses[i] + r * veloc[i,2] - accel[i,2])
#
#
# cdef double getRepulsiveForce(ndarray[int,   ndim=2] repList,
#                               ndarray[double, ndim=2] forces,
#                               ndarray[double, ndim=2] coords,
#                               int nRep, double fConst,
#                               ndarray[double, ndim=1] radii):
#
#   cdef int i, j, k
#   cdef double dx, dy, dz, d2, dr, rjk
#   cdef double force = 0
#   cdef double repDist2
#
#   if fConst == 0:
#     return force
#
#   for i from 0 <= i < nRep:
#     j = repList[i,0]
#     k = repList[i,1]
#     repDist = radii[j] + radii[k]
#     repDist2 = repDist * repDist
#
#
#     dx = coords[k,0] - coords[j,0]
#     if abs(dx) > repDist:
#       continue
#
#     dy = coords[k,1] - coords[j,1]
#     if abs(dy) > repDist:
#       continue
#
#     dz = coords[k,2] - coords[j,2]
#     if abs(dz) > repDist:
#       continue
#
#     d2 = dx*dx + dy*dy + dz*dz
#     if d2 > repDist2:
#       continue
#
#     dr = repDist2 - d2
#     #energy contribution
#     force += fConst * dr * dr
#     rjk = 4 * fConst * dr
#
#     dx *= rjk
#     dy *= rjk
#     dz *= rjk
#
#     #force contributions
#     forces[j,0] -= dx
#     forces[k,0] += dx
#
#     forces[j,1] -= dy
#     forces[k,1] += dy
#
#     forces[j,2] -= dz
#     forces[k,2] += dz
#
#   return force
#
#
# cdef double getRestraintForce(ndarray[double, ndim=2] forces,
#                               ndarray[double, ndim=2] coords,
#                               ndarray[int,   ndim=2] restIndices,
#                               ndarray[double, ndim=2] restLimits,
#                               ndarray[int, ndim=1] restAmbig,
#                               int nRest, double fConst, double exponent=2.0,
#                               double distSwitch=0.5, double asymptote=1.0):
#
#   cdef int i, j, k, n, nAmbig
#   cdef double a, b, da, d, dmin, dmax, dx, dy, dz
#   cdef double r, r2, s2, rjk, ujk, force = 0, t
#
#   b = asymptote*distSwitch*distSwitch - exponent*distSwitch*distSwitch*distSwitch
#   a = distSwitch*distSwitch - asymptote*distSwitch - b/ distSwitch
#
#   i = 0
#
#   while i < nRest:
#
#
#     nAmbig = restAmbig[i]
#     r2 = 0.0
#
#     if nAmbig == 1:
#       j = restIndices[i,0]
#       k = restIndices[i,1]
#
#       if j != k:
#         dx = coords[j,0] - coords[k,0]
#         dy = coords[j,1] - coords[k,1]
#         dz = coords[j,2] - coords[k,2]
#         r2 = dx*dx + dy*dy + dz*dz
#
#     else:
#       for n in range(nAmbig):
#         j = restIndices[i+n,0]
#         k = restIndices[i+n,1]
#
#         if j != k:
#           dx = coords[j,0] - coords[k,0]
#           dy = coords[j,1] - coords[k,1]
#           dz = coords[j,2] - coords[k,2]
#           r = dx*dx + dy*dy + dz*dz
#           r2 += 1.0 / (r * r)
#
#       if r2 > 0:
#         r2 = 1.0 / sqrt(r2)
#
#     if r2 <= 0:
#       i += nAmbig
#       continue
#
#     dmin = restLimits[i,0]
#     dmax = restLimits[i,1]
#
#     da = dmax + distSwitch
#
#     if r2 < dmin*dmin:
#       r2 = max(r2, 1e-8)
#       r = sqrt(r2)
#       d = dmin - r
#       ujk = fConst * d * d
#       rjk = fConst * 2 * d
#
#     elif r2 > dmax*dmax:
#       r = sqrt(r2)
#       d = r - dmax
#
#       if r <= da:
#         ujk = fConst * d * d
#         rjk = - fConst * 2 * d
#
#       else:
#         ujk = fConst * (a + asymptote*d + b/d)
#         rjk = - fConst * (asymptote - b/(d*d))
#
#     else:
#       ujk = rjk = 0
#       r = 1.0
#
#     force += ujk
#
#     if nAmbig == 1:
#       j = restIndices[i,0]
#       k = restIndices[i,1]
#
#       if j == k:
#         i += nAmbig
#         continue
#
#       t = rjk / r
#       dx = coords[j,0] - coords[k,0]
#       dy = coords[j,1] - coords[k,1]
#       dz = coords[j,2] - coords[k,2]
#
#       dx *= t
#       dy *= t
#       dz *= t
#
#       forces[j,0] += dx
#       forces[j,1] += dy
#       forces[j,2] += dz
#
#       forces[k,0] -= dx
#       forces[k,1] -= dy
#       forces[k,2] -= dz
#
#     else:
#
#       for n in range(nAmbig):
#         j = restIndices[i+n,0]
#         k = restIndices[i+n,1]
#
#         if j == k:
#           continue
#
#         dx = coords[j,0] - coords[k,0]
#         dy = coords[j,1] - coords[k,1]
#         dz = coords[j,2] - coords[k,2]
#
#         s2 = dx*dx + dy*dy + dz*dz
#         t = rjk * r2 * r2 * r / (s2 * s2 * s2)
#
#         dx *= t
#         dy *= t
#         dz *= t
#
#         forces[j,0] += dx
#         forces[k,0] -= dx
#         forces[j,1] += dy
#         forces[k,1] -= dy
#         forces[j,2] += dz
#         forces[k,2] -= dz
#
#     i += nAmbig
#
#   return force
#
#
# def runDynamics(ndarray[double, ndim=2] coords,
#                 ndarray[double, ndim=1] masses,
#                 ndarray[double, ndim=1] radii,
#                 ndarray[int, ndim=2] restIndices,
#                 ndarray[double, ndim=2] restLimits,
#                 ndarray[int, ndim=1] restAmbig,
#                 double tRef=1000.0, double tStep=0.001, int nSteps=1000,
#                 double fConstR=1.0, double fConstD=25.0, double beta=10.0,
#                 double minDist=2.25, double repDist=2.0,
#                 double tTaken=0.0, int printInterval=10000,
#                 double tot0=20.458, int use_Langevin=1,
#                 double LangevinTau_per_tStep=100.0,
#                 int nRepMax=0):
#
#   cdef int nRest = len(restIndices)
#   cdef int nCoords = len(coords)
#
#   if nCoords < 2:
#     raise NucCythonError('Too few coodinates')
#
#   indices = set(restIndices.ravel())
#   if min(indices) < 0:
#     raise NucCythonError('Restraint index negative')
#
#   if max(indices) >= nCoords:
#     data = (max(indices), nCoords)
#     raise NucCythonError('Restraint index "%d" out of bounds (> %d)' % data)
#
#   if nCoords != len(masses):
#     raise NucCythonError('Masses list size does not match coordinates')
#
#   if nRest != len(restLimits):
#     raise NucCythonError('Number of restraint index pairs does not match number of restraint limits')
#
#   if len(restAmbig) != nRest:
#     raise NucCythonError('Size of ambiguity list does not match number of restraints')
#
#   if use_Langevin != 1 and use_Langevin != 0:
#     raise NucCythonError('Unknown value for use_Langevin, has to be 1 (Langevin) or 0 (Berendsen)')
#
#   cdef int i, j, n, step, nViol, nRep = 0
#
#   if not nRepMax:
#     nRepMax = nCoords*800
#
#   cdef double d2, maxDelta, dx, dy, dz, ek, rmsd, tStep0, temp, fDist, fRep
#   cdef double deltaLim = 0.25 * repDist * repDist
#   cdef double Langevin_gamma
#
#   tStep0 = tStep * tot0
#   beta /= tot0
#
#   veloc = numpy.random.normal(0.0, 1.0, (nCoords, 3))
#   veloc *= sqrt(tRef / getTemp(masses, veloc, nCoords))
#
#   zeroArray = numpy.zeros((nCoords, 3))
#   repList = numpy.zeros((nRepMax, 2), numpy.int32)
#
#   cdef ndarray[double, ndim=2] coordsPrev = numpy.array(coords)
#   cdef ndarray[double, ndim=2] accel = numpy.array(zeroArray)
#   cdef ndarray[double, ndim=2] forces
#
#   t0 = time.time()
#
#   for step in range(nSteps):
#
#     if step == 0:
#       nRep = getRepulsionList(repList, coords, nCoords, nRepMax, repDist, radii) # Handle errors
#
#       for i in range(nCoords):
#         coordsPrev[i,0] = coords[i,0]
#         coordsPrev[i,1] = coords[i,1]
#         coordsPrev[i,2] = coords[i,2]
#
#       forces = numpy.array(zeroArray)
#       fRep = getRepulsiveForce(repList, forces, coords, nRep,  fConstR, radii)
#       fDist = getRestraintForce(forces, coords, restIndices, restLimits, restAmbig, nRest, fConstD)
#
#       for i in range(nCoords):
#         accel[i,0] = forces[i,0] / masses[i]
#         accel[i,1] = forces[i,1] / masses[i]
#         accel[i,2] = forces[i,2] / masses[i]
#
#     else:
#       maxDelta = 0.0
#       for i in range(nCoords):
#         dx = coords[i,0] - coordsPrev[i,0]
#         dy = coords[i,1] - coordsPrev[i,1]
#         dz = coords[i,2] - coordsPrev[i,2]
#         d2 = dx*dx + dy*dy + dz*dz
#
#         if d2 > maxDelta:
#           maxDelta = d2
#
#           if maxDelta > deltaLim:
#             break
#
#       if maxDelta > deltaLim:
#         nRep = getRepulsionList(repList, coords, nCoords, nRepMax, repDist, radii) # Handle errors
#
#         for i in range(nCoords):
#           coordsPrev[i,0] = coords[i,0]
#           coordsPrev[i,1] = coords[i,1]
#           coordsPrev[i,2] = coords[i,2]
#
#     updateMotion(masses, forces, accel, veloc, coords, nCoords, tRef, tStep0, beta)
#
#     for i in range(nCoords):
#       forces[i,0] = 0.0
#       forces[i,1] = 0.0
#       forces[i,2] = 0.0
#
#     fRep  = getRepulsiveForce(repList, forces, coords, nRep, fConstR, radii)
#     fDist = getRestraintForce(forces, coords, restIndices, restLimits, restAmbig, nRest, fConstD)
#
#     updateVelocity(masses, forces, accel, veloc, nCoords, tRef, tStep0,  beta)
#
#     if (printInterval > 0) and step % printInterval == 0:
#       temp = getTemp(masses, veloc, nCoords)
#       nViol, rmsd = getStats(restIndices, restLimits, coords, nRest)
#
#       data = (temp, fRep, fDist, rmsd, nViol, nRep)
#       print('temp:%7.2lf  fRep:%7.2lf  fDist:%7.2lf  rmsd:%7.2lf  nViol:%5d  nRep:%5d' % data)
#
#     tTaken += tStep
#
#   return tTaken, nRep

# %%
def annealStructure(coords, restraintIndices, restraintLimits,
                    tempMax=5000.0, tempMin=10.0, tempSteps=500,
                    dynSteps=100, timeStep=0.001, randSeed=None):

  from random import seed
  from math import atan, log, exp, pi
  from numpy import array, random, ones, int32
    
  # Consider masses and fixed particles
      
  if randSeed is None:
    seed()
  else:
    seed(randSeed)
  
  # Ensure inputs are numpy.ndarray  
  coords = array(coords)
  restraintIndices = array(restraintIndices, dtype=int32)
  restraintLimits = array(restraintLimits)
    
  nPoints = len(coords)
  
  # Masses and radii not used, just set to 1.0
  masses = radii = ones(nPoints, float)
    
  # Ambiguiuty not used, but represents the stride of sequential, grouped restraints
  ambiguity = ones(len(restraintIndices), int32)

  adj = 1.0 / atan(10.0)
  decay = log(tempMax/tempMin)    

  for step in range(tempSteps):
    frac = step/float(tempSteps)
    
    # exponential temp decay
    temp = tempMax * exp(-decay*frac)
    
    # sigmoidal repusion scheme
    repulse = 0.5 + adj * atan(frac*20.0-10) / pi 
    
    # update coordinates
    runDynamics(coords, masses, radii, restraintIndices, restraintLimits,
                ambiguity, temp, timeStep, dynSteps, repulse,
                minDist=1.50, repDist=1.5, printInterval=int32(100))
  
    # Center
    coords -= coords.mean(axis=0)
  
  return coords

# %% [markdown]
# ### Test annealing

# %%
from numpy import random

# Random particle coordinates - 20 test points of (x,y,z) 
nCoords = 20
coords = random.uniform(-1.0, 1.0, (nCoords,3)) 
  
# Each pair represents a connection between a pair of particles
# Restraint indices refer to indices in coordinate array
rIndices = [(0, 1), (0, 5), (0, 18), (1, 0), (1, 2),
            (1, 9), (2, 1), (2, 3), (2, 10), (3, 2),
            (3, 4), (3, 17), (4, 3), (4, 5), (4, 11),
            (5, 0), (5, 4), (5, 12), (6, 7), (6, 17),
            (6, 19), (7, 6), (7, 14), (7, 15), (7, 16),
            (8, 18), (9, 1), (10, 2), (11, 4), (12, 5),
            (13, 17), (14, 7), (15, 7), (16, 7), (17, 3),
            (17, 6), (17, 13), (18, 0), (18, 8), (19, 6)]
  
# Distances - upper and lower bounds for each particle
# Unform upper and lower bounds for test restraints
lower = 0.8
upper = 1.2
rDists = [(0.8, 1.2)] * len(rIndices)

# Run calculation
coords = annealStructure(coords, rIndices, rDists)
  
# Show results
for i, c in enumerate(coords):
  print '%3d' % i, c
# Out:
# temp:4960.64  fRep: 156.33  fDist: 276.90  rmsd:   0.58  nViol:   34  nRep:  171
# temp:4997.37  fRep:  31.91  fDist: 204.52  rmsd:   0.51  nViol:   32  nRep:  112
# temp:4904.86  fRep:  37.40  fDist: 112.94  rmsd:   0.42  nViol:   26  nRep:  110
# temp:4470.07  fRep:  36.65  fDist: 140.02  rmsd:   0.41  nViol:   28  nRep:  109
# temp:4740.35  fRep:  46.56  fDist: 109.33  rmsd:   0.35  nViol:   30  nRep:  119
# temp:4486.75  fRep:  28.90  fDist: 156.42  rmsd:   0.43  nViol:   28  nRep:  132
# temp:4481.09  fRep:  49.36  fDist: 115.87  rmsd:   0.36  nViol:   28  nRep:  141
# temp:4801.76  fRep:  45.67  fDist: 135.95  rmsd:   0.39  nViol:   24  nRep:  120
# temp:4006.16  fRep:  34.19  fDist: 158.03  rmsd:   0.42  nViol:   30  nRep:  126
# temp:4513.70  fRep:  53.39  fDist: 151.66  rmsd:   0.43  nViol:   32  nRep:  150
# temp:4573.51  fRep:  32.88  fDist: 150.21  rmsd:   0.42  nViol:   26  nRep:  125
# temp:4258.02  fRep:  36.74  fDist: 126.32  rmsd:   0.37  nViol:   32  nRep:  130
# temp:4186.28  fRep:  64.53  fDist:  77.01  rmsd:   0.29  nViol:   24  nRep:  150
# temp:4412.58  fRep:  32.61  fDist: 152.71  rmsd:   0.47  nViol:   32  nRep:   95
# temp:4114.90  fRep:  31.28  fDist: 126.99  rmsd:   0.37  nViol:   30  nRep:  122
# temp:4275.83  fRep:  48.36  fDist:  87.82  rmsd:   0.30  nViol:   36  nRep:  131
# temp:4148.59  fRep:  35.84  fDist:  97.86  rmsd:   0.32  nViol:   22  nRep:  104
# temp:4024.26  fRep:  75.21  fDist:  69.39  rmsd:   0.27  nViol:   26  nRep:  157
# temp:4151.00  fRep:  27.71  fDist: 105.41  rmsd:   0.33  nViol:   36  nRep:  112
# temp:4134.94  fRep:  57.70  fDist:  72.89  rmsd:   0.27  nViol:   26  nRep:  152
# temp:4133.91  fRep:  32.76  fDist:  97.46  rmsd:   0.33  nViol:   28  nRep:  104
# temp:3675.27  fRep:  50.29  fDist: 105.98  rmsd:   0.36  nViol:   26  nRep:  143
# temp:3713.87  fRep:  34.05  fDist:  60.19  rmsd:   0.25  nViol:   26  nRep:   96
# temp:3692.87  fRep:  41.10  fDist:  54.02  rmsd:   0.23  nViol:   28  nRep:  118
# temp:3881.44  fRep:  32.52  fDist: 105.86  rmsd:   0.36  nViol:   24  nRep:  120
# temp:3509.06  fRep:  49.43  fDist: 107.52  rmsd:   0.33  nViol:   30  nRep:  147
# temp:3783.22  fRep:  42.52  fDist:  72.87  rmsd:   0.27  nViol:   34  nRep:  123
# temp:3543.68  fRep:  53.29  fDist:  65.99  rmsd:   0.26  nViol:   34  nRep:  145
# temp:3621.79  fRep:  50.03  fDist:  73.02  rmsd:   0.27  nViol:   34  nRep:  139
# temp:3325.05  fRep:  37.39  fDist:  74.51  rmsd:   0.28  nViol:   32  nRep:  114
# temp:3330.15  fRep:  53.26  fDist:  72.27  rmsd:   0.27  nViol:   32  nRep:  152
# temp:3331.22  fRep:  44.92  fDist:  70.34  rmsd:   0.27  nViol:   28  nRep:  130
# temp:3377.27  fRep:  39.35  fDist:  61.84  rmsd:   0.25  nViol:   30  nRep:   99
# temp:3546.23  fRep:  39.06  fDist:  49.53  rmsd:   0.23  nViol:   26  nRep:  126
# temp:3114.58  fRep:  41.33  fDist:  44.59  rmsd:   0.21  nViol:   26  nRep:  128
# temp:3130.13  fRep:  36.19  fDist:  66.22  rmsd:   0.26  nViol:   32  nRep:  128
# temp:3137.18  fRep:  40.12  fDist: 101.68  rmsd:   0.33  nViol:   28  nRep:  118
# temp:3314.62  fRep:  25.57  fDist: 106.33  rmsd:   0.34  nViol:   30  nRep:  112
# temp:2959.61  fRep:  40.31  fDist:  68.07  rmsd:   0.26  nViol:   24  nRep:  106
# temp:3129.55  fRep:  49.42  fDist:  44.00  rmsd:   0.21  nViol:   28  nRep:  131
# temp:2966.52  fRep:  32.58  fDist:  72.16  rmsd:   0.27  nViol:   24  nRep:  122
# temp:3066.43  fRep:  30.59  fDist:  58.38  rmsd:   0.24  nViol:   28  nRep:  102
# temp:2958.36  fRep:  31.47  fDist:  72.89  rmsd:   0.27  nViol:   26  nRep:  113
# temp:2891.48  fRep:  38.04  fDist:  58.58  rmsd:   0.25  nViol:   20  nRep:  107
# temp:2741.74  fRep:  41.77  fDist:  69.41  rmsd:   0.27  nViol:   30  nRep:  134
# temp:2941.13  fRep:  54.70  fDist:  45.74  rmsd:   0.21  nViol:   30  nRep:  127
# temp:2766.68  fRep:  47.70  fDist:  60.54  rmsd:   0.25  nViol:   32  nRep:  142
# temp:2754.07  fRep:  37.86  fDist:  51.23  rmsd:   0.23  nViol:   30  nRep:  119
# temp:2831.25  fRep:  50.07  fDist:  68.04  rmsd:   0.28  nViol:   28  nRep:  137
# temp:2803.75  fRep:  60.59  fDist:  32.76  rmsd:   0.18  nViol:   24  nRep:  121
# temp:2664.02  fRep:  50.01  fDist:  22.45  rmsd:   0.15  nViol:   22  nRep:  129
# temp:2528.75  fRep:  33.56  fDist:  45.62  rmsd:   0.21  nViol:   24  nRep:  105
# temp:2675.00  fRep:  34.86  fDist:  83.24  rmsd:   0.29  nViol:   26  nRep:  131
# temp:2816.60  fRep:  41.25  fDist:  56.95  rmsd:   0.24  nViol:   24  nRep:  105
# temp:2575.11  fRep:  37.39  fDist:  57.23  rmsd:   0.24  nViol:   24  nRep:  120
# temp:2580.91  fRep:  44.65  fDist:  37.94  rmsd:   0.19  nViol:   24  nRep:  136
# temp:2352.60  fRep:  30.18  fDist:  53.56  rmsd:   0.23  nViol:   28  nRep:  119
# temp:2420.74  fRep:  23.19  fDist:  42.56  rmsd:   0.21  nViol:   26  nRep:  129
# temp:2511.69  fRep:  29.13  fDist:  27.09  rmsd:   0.16  nViol:   24  nRep:  119
# temp:2357.68  fRep:  38.72  fDist:  54.84  rmsd:   0.23  nViol:   26  nRep:  103
# temp:2259.68  fRep:  43.75  fDist:  44.67  rmsd:   0.21  nViol:   30  nRep:  147
# temp:2444.28  fRep:  34.72  fDist:  34.28  rmsd:   0.19  nViol:   30  nRep:   95
# temp:2188.59  fRep:  35.13  fDist:  43.87  rmsd:   0.21  nViol:   32  nRep:  114
# temp:2104.11  fRep:  35.57  fDist:  42.96  rmsd:   0.21  nViol:   26  nRep:  133
# temp:2204.20  fRep:  35.00  fDist:  29.70  rmsd:   0.17  nViol:   32  nRep:   93
# temp:2153.67  fRep:  40.95  fDist:  30.81  rmsd:   0.18  nViol:   28  nRep:  148
# temp:2122.35  fRep:  25.34  fDist:  45.33  rmsd:   0.21  nViol:   28  nRep:   95
# temp:2160.06  fRep:  42.37  fDist:  15.99  rmsd:   0.13  nViol:   20  nRep:  112
# temp:2050.24  fRep:  45.13  fDist:  38.82  rmsd:   0.20  nViol:   30  nRep:  132
# temp:2171.91  fRep:  45.54  fDist:  19.10  rmsd:   0.14  nViol:   24  nRep:  137
# temp:2079.76  fRep:  33.05  fDist:  40.03  rmsd:   0.20  nViol:   20  nRep:   97
# temp:2051.31  fRep:  63.82  fDist:  27.42  rmsd:   0.17  nViol:   24  nRep:  130
# temp:2088.26  fRep:  37.86  fDist:  46.07  rmsd:   0.22  nViol:   28  nRep:  119
# temp:1901.15  fRep:  41.56  fDist:  67.49  rmsd:   0.27  nViol:   30  nRep:  131
# temp:2079.12  fRep:  40.37  fDist:  22.16  rmsd:   0.15  nViol:   24  nRep:  123
# temp:2045.72  fRep:  44.81  fDist:  28.09  rmsd:   0.17  nViol:   28  nRep:  147
# temp:1864.70  fRep:  36.58  fDist:  34.28  rmsd:   0.19  nViol:   28  nRep:  121
# temp:1929.08  fRep:  52.48  fDist:  16.31  rmsd:   0.13  nViol:   26  nRep:  132
# temp:1936.38  fRep:  48.82  fDist:  28.82  rmsd:   0.17  nViol:   28  nRep:  121
# temp:1811.58  fRep:  36.39  fDist:  27.38  rmsd:   0.17  nViol:   24  nRep:  108
# temp:1826.28  fRep:  32.08  fDist:  42.75  rmsd:   0.21  nViol:   32  nRep:  115
# temp:1779.06  fRep:  36.65  fDist:  34.34  rmsd:   0.19  nViol:   28  nRep:  127
# temp:1862.69  fRep:  23.48  fDist:  36.80  rmsd:   0.19  nViol:   28  nRep:   90
# temp:1759.75  fRep:  40.96  fDist:  24.91  rmsd:   0.16  nViol:   22  nRep:  131
# temp:1721.08  fRep:  46.76  fDist:  10.54  rmsd:   0.10  nViol:   16  nRep:  124
# temp:1768.81  fRep:  36.52  fDist:  31.40  rmsd:   0.18  nViol:   28  nRep:  134
# temp:1706.36  fRep:  35.76  fDist:  50.85  rmsd:   0.23  nViol:   32  nRep:  125
# temp:1694.16  fRep:  54.29  fDist:  21.45  rmsd:   0.15  nViol:   18  nRep:  150
# temp:1550.77  fRep:  27.73  fDist:  38.67  rmsd:   0.20  nViol:   22  nRep:  104
# temp:1755.60  fRep:  43.72  fDist:  13.21  rmsd:   0.11  nViol:   24  nRep:  142
# temp:1522.08  fRep:  31.15  fDist:  42.21  rmsd:   0.21  nViol:   26  nRep:  102
# temp:1693.08  fRep:  25.53  fDist:  37.75  rmsd:   0.19  nViol:   20  nRep:  106
# temp:1637.15  fRep:  26.58  fDist:  22.35  rmsd:   0.15  nViol:   22  nRep:  110
# temp:1553.15  fRep:  31.52  fDist:  36.39  rmsd:   0.19  nViol:   26  nRep:  106
# temp:1569.18  fRep:  39.34  fDist:  34.41  rmsd:   0.19  nViol:   28  nRep:  124
# temp:1664.72  fRep:  42.93  fDist:  30.64  rmsd:   0.18  nViol:   22  nRep:  106
# temp:1583.49  fRep:  44.99  fDist:  10.82  rmsd:   0.10  nViol:   20  nRep:  137
# temp:1491.15  fRep:  39.84  fDist:  13.79  rmsd:   0.12  nViol:   16  nRep:  115
# temp:1369.60  fRep:  36.82  fDist:  28.84  rmsd:   0.17  nViol:   24  nRep:  117
# temp:1496.18  fRep:  50.91  fDist:  17.39  rmsd:   0.13  nViol:   22  nRep:  122
# temp:1417.60  fRep:  49.94  fDist:  17.81  rmsd:   0.13  nViol:   20  nRep:  121
# temp:1436.64  fRep:  35.38  fDist:   4.45  rmsd:   0.07  nViol:   24  nRep:  138
# temp:1463.20  fRep:  28.42  fDist:  42.21  rmsd:   0.21  nViol:   26  nRep:   89
# temp:1404.29  fRep:  34.09  fDist:  11.54  rmsd:   0.11  nViol:   26  nRep:  124
# temp:1346.13  fRep:  42.99  fDist:  18.36  rmsd:   0.14  nViol:   22  nRep:  145
# temp:1342.71  fRep:  40.00  fDist:  25.44  rmsd:   0.16  nViol:   26  nRep:  127
# temp:1330.24  fRep:  30.61  fDist:  26.95  rmsd:   0.16  nViol:   24  nRep:  124
# temp:1278.30  fRep:  39.20  fDist:  28.95  rmsd:   0.17  nViol:   26  nRep:  134
# temp:1388.52  fRep:  36.79  fDist:  19.72  rmsd:   0.14  nViol:   20  nRep:  129
# temp:1237.13  fRep:  32.98  fDist:  10.77  rmsd:   0.10  nViol:   24  nRep:  108
# temp:1336.74  fRep:  40.06  fDist:  18.81  rmsd:   0.14  nViol:   24  nRep:   98
# temp:1279.62  fRep:  37.06  fDist:  23.13  rmsd:   0.15  nViol:   22  nRep:  119
# temp:1305.14  fRep:  37.58  fDist:  17.86  rmsd:   0.13  nViol:   24  nRep:  117
# temp:1246.36  fRep:  40.15  fDist:  27.42  rmsd:   0.17  nViol:   30  nRep:  111
# temp:1222.96  fRep:  38.91  fDist:  28.20  rmsd:   0.17  nViol:   28  nRep:  115
# temp:1269.95  fRep:  42.89  fDist:  23.91  rmsd:   0.15  nViol:   24  nRep:  117
# temp:1234.23  fRep:  43.20  fDist:  19.56  rmsd:   0.14  nViol:   26  nRep:  151
# temp:1158.11  fRep:  30.62  fDist:  25.33  rmsd:   0.16  nViol:   28  nRep:   98
# temp:1130.26  fRep:  35.82  fDist:  12.97  rmsd:   0.11  nViol:   22  nRep:  143
# temp:1029.68  fRep:  27.21  fDist:  25.97  rmsd:   0.16  nViol:   32  nRep:   85
# temp:1132.86  fRep:  54.91  fDist:   8.31  rmsd:   0.09  nViol:   18  nRep:  143
# temp:1170.31  fRep:  25.36  fDist:  22.78  rmsd:   0.15  nViol:   26  nRep:  101
# temp:1049.75  fRep:  31.25  fDist:  18.08  rmsd:   0.13  nViol:   16  nRep:  132
# temp:1116.76  fRep:  32.00  fDist:  10.60  rmsd:   0.10  nViol:   26  nRep:  120
# temp:1085.07  fRep:  36.74  fDist:  13.06  rmsd:   0.11  nViol:   24  nRep:  137
# temp:1082.91  fRep:  24.62  fDist:  20.73  rmsd:   0.14  nViol:   24  nRep:   93
# temp:1026.43  fRep:  37.29  fDist:  13.43  rmsd:   0.12  nViol:   26  nRep:  121
# temp:1021.09  fRep:  44.00  fDist:   5.07  rmsd:   0.07  nViol:   16  nRep:  102
# temp:1038.95  fRep:  33.11  fDist:   6.57  rmsd:   0.08  nViol:   18  nRep:  143
# temp: 989.50  fRep:  33.99  fDist:   9.19  rmsd:   0.10  nViol:   16  nRep:  103
# temp: 945.12  fRep:  25.72  fDist:  32.47  rmsd:   0.18  nViol:   24  nRep:   99
# temp: 989.60  fRep:  30.20  fDist:  13.05  rmsd:   0.11  nViol:   22  nRep:   92
# temp: 991.73  fRep:  22.40  fDist:  25.82  rmsd:   0.16  nViol:   28  nRep:  105
# temp: 961.49  fRep:  26.50  fDist:  12.00  rmsd:   0.11  nViol:   14  nRep:  107
# temp: 935.55  fRep:  40.16  fDist:   2.82  rmsd:   0.05  nViol:   18  nRep:  129
# temp: 932.20  fRep:  42.55  fDist:   3.44  rmsd:   0.06  nViol:   24  nRep:  102
# temp: 963.30  fRep:  33.85  fDist:  17.69  rmsd:   0.13  nViol:   30  nRep:  118
# temp: 884.94  fRep:  32.34  fDist:  10.50  rmsd:   0.10  nViol:   20  nRep:  112
# temp: 938.44  fRep:  26.35  fDist:  17.75  rmsd:   0.13  nViol:   26  nRep:   97
# temp: 857.25  fRep:  35.21  fDist:  22.43  rmsd:   0.15  nViol:   22  nRep:  113
# temp: 839.61  fRep:  28.82  fDist:  21.78  rmsd:   0.15  nViol:   32  nRep:  110
# temp: 868.27  fRep:  29.12  fDist:  16.78  rmsd:   0.13  nViol:   24  nRep:  122
# temp: 877.64  fRep:  25.36  fDist:   9.03  rmsd:   0.10  nViol:   24  nRep:  109
# temp: 874.51  fRep:  33.65  fDist:   8.26  rmsd:   0.09  nViol:   28  nRep:  118
# temp: 883.59  fRep:  28.03  fDist:  22.67  rmsd:   0.15  nViol:   26  nRep:   93
# temp: 877.24  fRep:  39.33  fDist:  14.37  rmsd:   0.12  nViol:   26  nRep:  133
# temp: 776.94  fRep:  33.67  fDist:   7.90  rmsd:   0.09  nViol:   20  nRep:  101
# temp: 812.61  fRep:  31.66  fDist:  10.52  rmsd:   0.10  nViol:   26  nRep:  126
# temp: 778.28  fRep:  28.35  fDist:  17.14  rmsd:   0.13  nViol:   26  nRep:  103
# temp: 771.50  fRep:  36.69  fDist:   8.81  rmsd:   0.09  nViol:   20  nRep:  121
# temp: 737.19  fRep:  35.59  fDist:  12.27  rmsd:   0.11  nViol:   22  nRep:  109
# temp: 709.88  fRep:  23.27  fDist:  26.50  rmsd:   0.16  nViol:   22  nRep:  108
# temp: 766.06  fRep:  26.85  fDist:  28.55  rmsd:   0.17  nViol:   32  nRep:  117
# temp: 732.64  fRep:  38.23  fDist:   7.52  rmsd:   0.09  nViol:   16  nRep:  112
# temp: 737.58  fRep:  29.92  fDist:  12.56  rmsd:   0.11  nViol:   32  nRep:  113
# temp: 734.65  fRep:  36.44  fDist:  12.56  rmsd:   0.11  nViol:   26  nRep:  109
# temp: 696.06  fRep:  34.99  fDist:  10.02  rmsd:   0.10  nViol:   24  nRep:  121
# temp: 703.19  fRep:  36.61  fDist:  19.25  rmsd:   0.14  nViol:   22  nRep:  117
# temp: 674.88  fRep:  33.39  fDist:  16.91  rmsd:   0.13  nViol:   22  nRep:  119
# temp: 726.47  fRep:  32.98  fDist:   6.78  rmsd:   0.08  nViol:   30  nRep:  113
# temp: 688.62  fRep:  25.48  fDist:  16.56  rmsd:   0.13  nViol:   22  nRep:  103
# temp: 639.14  fRep:  31.87  fDist:   7.47  rmsd:   0.09  nViol:   28  nRep:  108
# temp: 697.02  fRep:  37.49  fDist:   6.88  rmsd:   0.08  nViol:   24  nRep:  108
# temp: 654.09  fRep:  32.11  fDist:  13.77  rmsd:   0.12  nViol:   16  nRep:  108
# temp: 684.28  fRep:  27.33  fDist:   9.46  rmsd:   0.10  nViol:   30  nRep:   96
# temp: 636.31  fRep:  33.61  fDist:   4.55  rmsd:   0.07  nViol:   16  nRep:  117
# temp: 612.09  fRep:  31.84  fDist:  18.31  rmsd:   0.14  nViol:   24  nRep:  104
# temp: 625.27  fRep:  36.45  fDist:  10.65  rmsd:   0.10  nViol:   16  nRep:  115
# temp: 651.78  fRep:  27.25  fDist:  20.08  rmsd:   0.14  nViol:   32  nRep:   98
# temp: 576.10  fRep:  35.74  fDist:   9.18  rmsd:   0.10  nViol:   22  nRep:  127
# temp: 607.89  fRep:  35.60  fDist:   2.39  rmsd:   0.05  nViol:   16  nRep:  114
# temp: 571.86  fRep:  35.91  fDist:  15.08  rmsd:   0.12  nViol:   22  nRep:  100
# temp: 592.72  fRep:  38.50  fDist:   9.79  rmsd:   0.10  nViol:   18  nRep:  129
# temp: 567.74  fRep:  29.37  fDist:   2.91  rmsd:   0.05  nViol:   24  nRep:  102
# temp: 576.81  fRep:  35.66  fDist:   3.94  rmsd:   0.06  nViol:   20  nRep:  133
# temp: 564.97  fRep:  31.60  fDist:   7.29  rmsd:   0.09  nViol:   20  nRep:   98
# temp: 545.75  fRep:  29.21  fDist:   7.82  rmsd:   0.09  nViol:   22  nRep:  122
# temp: 528.64  fRep:  35.80  fDist:   5.59  rmsd:   0.07  nViol:   12  nRep:  105
# temp: 547.81  fRep:  33.76  fDist:   5.04  rmsd:   0.07  nViol:   26  nRep:  125
# temp: 528.26  fRep:  26.96  fDist:   8.00  rmsd:   0.09  nViol:   18  nRep:  109
# temp: 523.06  fRep:  26.10  fDist:  17.01  rmsd:   0.13  nViol:   20  nRep:  100
# temp: 551.90  fRep:  25.97  fDist:  13.62  rmsd:   0.12  nViol:   18  nRep:  103
# temp: 514.49  fRep:  29.83  fDist:   7.02  rmsd:   0.08  nViol:   20  nRep:  111
# temp: 515.20  fRep:  30.21  fDist:   6.11  rmsd:   0.08  nViol:   22  nRep:  124
# temp: 522.32  fRep:  29.47  fDist:   5.81  rmsd:   0.08  nViol:   20  nRep:  122
# temp: 511.17  fRep:  28.54  fDist:   7.09  rmsd:   0.08  nViol:   24  nRep:  128
# temp: 474.39  fRep:  25.29  fDist:  15.52  rmsd:   0.12  nViol:   22  nRep:  110
# temp: 501.35  fRep:  27.46  fDist:  16.55  rmsd:   0.13  nViol:   28  nRep:  119
# temp: 481.76  fRep:  34.34  fDist:   8.64  rmsd:   0.09  nViol:   24  nRep:  122
# temp: 481.80  fRep:  31.82  fDist:  10.12  rmsd:   0.10  nViol:   22  nRep:  117
# temp: 482.55  fRep:  28.46  fDist:   8.31  rmsd:   0.09  nViol:   18  nRep:   95
# temp: 478.73  fRep:  30.48  fDist:   7.27  rmsd:   0.09  nViol:   22  nRep:  117
# temp: 484.85  fRep:  32.30  fDist:   5.76  rmsd:   0.08  nViol:   22  nRep:  111
# temp: 448.66  fRep:  32.60  fDist:   4.45  rmsd:   0.07  nViol:   20  nRep:  123
# temp: 437.34  fRep:  26.17  fDist:  10.90  rmsd:   0.10  nViol:   32  nRep:  108
# temp: 440.92  fRep:  33.52  fDist:   7.24  rmsd:   0.09  nViol:   30  nRep:  119
# temp: 442.91  fRep:  32.52  fDist:   8.60  rmsd:   0.09  nViol:   20  nRep:  110
# temp: 449.86  fRep:  27.78  fDist:   7.88  rmsd:   0.09  nViol:   26  nRep:   97
# temp: 429.03  fRep:  32.87  fDist:   1.46  rmsd:   0.04  nViol:   16  nRep:  101
# temp: 413.96  fRep:  32.89  fDist:   6.40  rmsd:   0.08  nViol:   20  nRep:  105
# temp: 399.00  fRep:  36.06  fDist:   4.74  rmsd:   0.07  nViol:   14  nRep:   98
# temp: 401.31  fRep:  34.81  fDist:   7.48  rmsd:   0.09  nViol:   18  nRep:  105
# temp: 417.47  fRep:  31.39  fDist:   6.17  rmsd:   0.08  nViol:   14  nRep:   91
# temp: 416.27  fRep:  32.29  fDist:   6.70  rmsd:   0.08  nViol:   26  nRep:  116
# temp: 396.39  fRep:  30.96  fDist:   5.33  rmsd:   0.07  nViol:   18  nRep:  101
# temp: 399.59  fRep:  31.47  fDist:   3.07  rmsd:   0.06  nViol:   20  nRep:  109
# temp: 360.83  fRep:  29.15  fDist:  11.46  rmsd:   0.11  nViol:   28  nRep:  103
# temp: 378.70  fRep:  28.42  fDist:   7.10  rmsd:   0.08  nViol:   24  nRep:  103
# temp: 389.41  fRep:  33.31  fDist:   8.20  rmsd:   0.09  nViol:   26  nRep:  110
# temp: 380.04  fRep:  30.27  fDist:   6.58  rmsd:   0.08  nViol:   22  nRep:  107
# temp: 342.09  fRep:  29.53  fDist:   6.26  rmsd:   0.08  nViol:   26  nRep:  102
# temp: 375.87  fRep:  29.62  fDist:  11.78  rmsd:   0.11  nViol:   24  nRep:   95
# temp: 353.16  fRep:  30.85  fDist:   3.99  rmsd:   0.06  nViol:   24  nRep:  108
# temp: 354.08  fRep:  32.51  fDist:   7.57  rmsd:   0.09  nViol:   24  nRep:   99
# temp: 341.54  fRep:  29.46  fDist:   9.24  rmsd:   0.10  nViol:   34  nRep:  108
# temp: 338.91  fRep:  31.44  fDist:   6.90  rmsd:   0.08  nViol:   26  nRep:  109
# temp: 349.95  fRep:  26.59  fDist:  10.94  rmsd:   0.10  nViol:   28  nRep:   99
# temp: 343.74  fRep:  30.13  fDist:   5.52  rmsd:   0.07  nViol:   24  nRep:   97
# temp: 340.21  fRep:  34.81  fDist:   4.64  rmsd:   0.07  nViol:   26  nRep:  105
# temp: 338.69  fRep:  38.23  fDist:   2.97  rmsd:   0.05  nViol:   20  nRep:  103
# temp: 339.18  fRep:  31.10  fDist:   8.25  rmsd:   0.09  nViol:   28  nRep:  103
# temp: 312.16  fRep:  29.66  fDist:   5.76  rmsd:   0.08  nViol:   28  nRep:   96
# temp: 309.14  fRep:  33.34  fDist:   9.47  rmsd:   0.10  nViol:   28  nRep:  104
# temp: 339.31  fRep:  33.15  fDist:   7.41  rmsd:   0.09  nViol:   26  nRep:   98
# temp: 305.80  fRep:  32.58  fDist:   5.39  rmsd:   0.07  nViol:   24  nRep:   96
# temp: 308.27  fRep:  30.33  fDist:   8.60  rmsd:   0.09  nViol:   30  nRep:   97
# temp: 296.95  fRep:  35.18  fDist:   5.03  rmsd:   0.07  nViol:   26  nRep:  109
# temp: 295.51  fRep:  35.75  fDist:   3.37  rmsd:   0.06  nViol:   20  nRep:   97
# temp: 304.52  fRep:  35.78  fDist:   4.82  rmsd:   0.07  nViol:   24  nRep:  108
# temp: 276.58  fRep:  33.92  fDist:   7.31  rmsd:   0.09  nViol:   28  nRep:  102
# temp: 290.42  fRep:  36.20  fDist:   3.91  rmsd:   0.06  nViol:   24  nRep:  115
# temp: 296.35  fRep:  32.94  fDist:   6.68  rmsd:   0.08  nViol:   34  nRep:  107
# temp: 262.45  fRep:  35.52  fDist:  10.34  rmsd:   0.10  nViol:   28  nRep:  105
# temp: 270.25  fRep:  31.56  fDist:  12.77  rmsd:   0.11  nViol:   34  nRep:  104
# temp: 268.11  fRep:  32.39  fDist:  11.86  rmsd:   0.11  nViol:   32  nRep:  102
# temp: 267.84  fRep:  36.07  fDist:   6.70  rmsd:   0.08  nViol:   26  nRep:  105
# temp: 279.40  fRep:  34.18  fDist:   8.68  rmsd:   0.09  nViol:   28  nRep:  107
# temp: 259.29  fRep:  39.32  fDist:   6.51  rmsd:   0.08  nViol:   24  nRep:   93
# temp: 259.86  fRep:  35.06  fDist:  11.04  rmsd:   0.11  nViol:   32  nRep:   96
# temp: 256.16  fRep:  38.35  fDist:   5.22  rmsd:   0.07  nViol:   28  nRep:   98
# temp: 271.37  fRep:  39.56  fDist:   5.30  rmsd:   0.07  nViol:   26  nRep:   96
# temp: 241.31  fRep:  44.69  fDist:   4.65  rmsd:   0.07  nViol:   18  nRep:  108
# temp: 233.97  fRep:  38.09  fDist:  10.76  rmsd:   0.10  nViol:   22  nRep:  102
# temp: 243.56  fRep:  40.84  fDist:   6.02  rmsd:   0.08  nViol:   24  nRep:   99
# temp: 245.70  fRep:  42.68  fDist:   5.05  rmsd:   0.07  nViol:   28  nRep:  110
# temp: 236.14  fRep:  42.99  fDist:   5.46  rmsd:   0.07  nViol:   22  nRep:  128
# temp: 219.61  fRep:  41.85  fDist:   5.17  rmsd:   0.07  nViol:   24  nRep:  117
# temp: 232.03  fRep:  38.57  fDist:   8.54  rmsd:   0.09  nViol:   30  nRep:  109
# temp: 218.55  fRep:  40.94  fDist:   8.58  rmsd:   0.09  nViol:   34  nRep:  113
# temp: 217.38  fRep:  40.43  fDist:   8.16  rmsd:   0.09  nViol:   28  nRep:  112
# temp: 220.62  fRep:  40.12  fDist:  12.50  rmsd:   0.11  nViol:   28  nRep:  107
# temp: 220.07  fRep:  43.47  fDist:   7.40  rmsd:   0.09  nViol:   26  nRep:  107
# temp: 222.19  fRep:  45.91  fDist:   5.34  rmsd:   0.07  nViol:   26  nRep:  111
# temp: 210.46  fRep:  40.60  fDist:  11.25  rmsd:   0.11  nViol:   30  nRep:   95
# temp: 205.25  fRep:  43.62  fDist:   7.17  rmsd:   0.08  nViol:   36  nRep:  108
# temp: 207.29  fRep:  43.68  fDist:   8.62  rmsd:   0.09  nViol:   30  nRep:   95
# temp: 206.04  fRep:  46.48  fDist:   6.86  rmsd:   0.08  nViol:   30  nRep:   90
# temp: 203.38  fRep:  47.24  fDist:   7.01  rmsd:   0.08  nViol:   34  nRep:  102
# temp: 209.35  fRep:  46.32  fDist:  10.25  rmsd:   0.10  nViol:   32  nRep:   89
# temp: 188.77  fRep:  47.93  fDist:   7.82  rmsd:   0.09  nViol:   30  nRep:  110
# temp: 192.40  fRep:  48.31  fDist:   8.36  rmsd:   0.09  nViol:   32  nRep:  105
# temp: 206.72  fRep:  46.29  fDist:   9.56  rmsd:   0.10  nViol:   36  nRep:   94
# temp: 189.55  fRep:  45.43  fDist:  11.16  rmsd:   0.11  nViol:   38  nRep:   89
# temp: 185.19  fRep:  48.18  fDist:  10.06  rmsd:   0.10  nViol:   30  nRep:   88
# temp: 180.53  fRep:  52.00  fDist:   6.49  rmsd:   0.08  nViol:   26  nRep:   99
# temp: 179.94  fRep:  46.41  fDist:  13.11  rmsd:   0.11  nViol:   36  nRep:   98
# temp: 198.14  fRep:  48.56  fDist:   9.51  rmsd:   0.10  nViol:   32  nRep:  102
# temp: 184.61  fRep:  51.26  fDist:   8.95  rmsd:   0.09  nViol:   34  nRep:   98
# temp: 174.10  fRep:  49.12  fDist:   8.87  rmsd:   0.09  nViol:   36  nRep:  101
# temp: 172.05  fRep:  52.04  fDist:   6.26  rmsd:   0.08  nViol:   36  nRep:   92
# temp: 184.36  fRep:  52.31  fDist:   8.43  rmsd:   0.09  nViol:   32  nRep:   87
# temp: 163.19  fRep:  52.13  fDist:   9.35  rmsd:   0.10  nViol:   28  nRep:   90
# temp: 161.30  fRep:  53.24  fDist:   8.91  rmsd:   0.09  nViol:   26  nRep:   94
# temp: 171.07  fRep:  50.74  fDist:  10.85  rmsd:   0.10  nViol:   32  nRep:   94
# temp: 163.07  fRep:  52.57  fDist:   9.34  rmsd:   0.10  nViol:   34  nRep:   92
# temp: 163.94  fRep:  52.63  fDist:  10.74  rmsd:   0.10  nViol:   34  nRep:  101
# temp: 163.05  fRep:  51.12  fDist:   8.88  rmsd:   0.09  nViol:   36  nRep:   89
# temp: 159.22  fRep:  56.34  fDist:   6.29  rmsd:   0.08  nViol:   32  nRep:   97
# temp: 154.84  fRep:  55.66  fDist:   4.99  rmsd:   0.07  nViol:   36  nRep:   95
# temp: 142.59  fRep:  55.02  fDist:   8.92  rmsd:   0.09  nViol:   32  nRep:   94
# temp: 160.17  fRep:  53.59  fDist:   8.61  rmsd:   0.09  nViol:   34  nRep:   98
# temp: 144.79  fRep:  52.69  fDist:  10.10  rmsd:   0.10  nViol:   36  nRep:  102
# temp: 155.99  fRep:  54.14  fDist:   8.46  rmsd:   0.09  nViol:   32  nRep:  114
# temp: 153.06  fRep:  57.57  fDist:   5.35  rmsd:   0.07  nViol:   32  nRep:  108
# temp: 151.94  fRep:  56.44  fDist:   6.49  rmsd:   0.08  nViol:   28  nRep:  109
# temp: 153.71  fRep:  50.67  fDist:  13.90  rmsd:   0.12  nViol:   36  nRep:  105
# temp: 143.71  fRep:  53.67  fDist:  10.94  rmsd:   0.10  nViol:   36  nRep:   94
# temp: 148.65  fRep:  53.55  fDist:   9.95  rmsd:   0.10  nViol:   36  nRep:   97
# temp: 134.39  fRep:  53.43  fDist:  11.38  rmsd:   0.11  nViol:   34  nRep:   97
# temp: 142.32  fRep:  58.26  fDist:   6.66  rmsd:   0.08  nViol:   32  nRep:  101
# temp: 132.35  fRep:  52.98  fDist:  11.85  rmsd:   0.11  nViol:   32  nRep:  100
# temp: 134.63  fRep:  58.52  fDist:   9.38  rmsd:   0.10  nViol:   26  nRep:  103
# temp: 141.66  fRep:  54.16  fDist:  11.52  rmsd:   0.11  nViol:   34  nRep:   95
# temp: 134.07  fRep:  55.83  fDist:   8.87  rmsd:   0.09  nViol:   36  nRep:   95
# temp: 130.23  fRep:  56.90  fDist:   7.14  rmsd:   0.08  nViol:   34  nRep:   96
# temp: 134.54  fRep:  57.40  fDist:   7.48  rmsd:   0.09  nViol:   34  nRep:  105
# temp: 122.76  fRep:  57.54  fDist:   7.85  rmsd:   0.09  nViol:   32  nRep:  102
# temp: 119.76  fRep:  58.69  fDist:   5.54  rmsd:   0.07  nViol:   32  nRep:  109
# temp: 121.85  fRep:  57.34  fDist:   8.66  rmsd:   0.09  nViol:   34  nRep:  119
# temp: 126.01  fRep:  52.36  fDist:  12.11  rmsd:   0.11  nViol:   38  nRep:  101
# temp: 119.11  fRep:  58.06  fDist:   8.51  rmsd:   0.09  nViol:   32  nRep:   91
# temp: 122.37  fRep:  57.13  fDist:   8.48  rmsd:   0.09  nViol:   38  nRep:   95
# temp: 108.00  fRep:  59.91  fDist:   5.20  rmsd:   0.07  nViol:   30  nRep:   98
# temp: 114.50  fRep:  58.66  fDist:   7.38  rmsd:   0.09  nViol:   32  nRep:   90
# temp: 110.45  fRep:  56.88  fDist:   8.06  rmsd:   0.09  nViol:   34  nRep:   95
# temp: 113.41  fRep:  54.57  fDist:  11.11  rmsd:   0.11  nViol:   40  nRep:  102
# temp: 120.61  fRep:  54.83  fDist:  11.53  rmsd:   0.11  nViol:   36  nRep:   97
# temp: 108.49  fRep:  53.54  fDist:  12.34  rmsd:   0.11  nViol:   32  nRep:   94
# temp: 111.78  fRep:  54.32  fDist:  11.73  rmsd:   0.11  nViol:   34  nRep:   96
# temp: 108.10  fRep:  57.54  fDist:   7.51  rmsd:   0.09  nViol:   30  nRep:   96
# temp: 105.42  fRep:  57.16  fDist:   8.80  rmsd:   0.09  nViol:   34  nRep:   94
# temp:  93.35  fRep:  58.27  fDist:  10.00  rmsd:   0.10  nViol:   38  nRep:   93
# temp: 103.89  fRep:  54.90  fDist:  11.53  rmsd:   0.11  nViol:   32  nRep:   91
# temp: 109.34  fRep:  55.67  fDist:   9.96  rmsd:   0.10  nViol:   32  nRep:  104
# temp: 100.31  fRep:  58.32  fDist:   9.04  rmsd:   0.10  nViol:   32  nRep:   93
# temp:  96.84  fRep:  58.30  fDist:   7.49  rmsd:   0.09  nViol:   34  nRep:  103
# temp:  98.51  fRep:  58.59  fDist:   6.61  rmsd:   0.08  nViol:   34  nRep:  103
# temp:  94.18  fRep:  60.56  fDist:   6.31  rmsd:   0.08  nViol:   36  nRep:  106
# temp:  96.01  fRep:  55.90  fDist:  10.21  rmsd:   0.10  nViol:   32  nRep:  102
# temp: 105.91  fRep:  58.93  fDist:   7.09  rmsd:   0.08  nViol:   36  nRep:   96
# temp:  92.15  fRep:  56.08  fDist:  10.29  rmsd:   0.10  nViol:   32  nRep:  101
# temp:  95.32  fRep:  59.35  fDist:   6.87  rmsd:   0.08  nViol:   32  nRep:   98
# temp:  96.85  fRep:  60.64  fDist:   6.25  rmsd:   0.08  nViol:   30  nRep:  105
# temp:  88.22  fRep:  55.10  fDist:  11.49  rmsd:   0.11  nViol:   34  nRep:  111
# temp:  92.28  fRep:  58.25  fDist:   9.42  rmsd:   0.10  nViol:   34  nRep:  100
# temp:  86.34  fRep:  53.98  fDist:  13.44  rmsd:   0.12  nViol:   34  nRep:  118
# temp:  89.35  fRep:  57.90  fDist:   8.96  rmsd:   0.09  nViol:   30  nRep:   99
# temp:  80.85  fRep:  59.25  fDist:   8.02  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  81.04  fRep:  57.79  fDist:   8.78  rmsd:   0.09  nViol:   32  nRep:   99
# temp:  83.46  fRep:  60.49  fDist:   5.79  rmsd:   0.08  nViol:   32  nRep:   97
# temp:  81.94  fRep:  59.69  fDist:   7.30  rmsd:   0.09  nViol:   36  nRep:  100
# temp:  80.46  fRep:  58.87  fDist:   7.84  rmsd:   0.09  nViol:   32  nRep:  102
# temp:  74.55  fRep:  59.39  fDist:   8.46  rmsd:   0.09  nViol:   32  nRep:   98
# temp:  85.75  fRep:  58.85  fDist:   8.34  rmsd:   0.09  nViol:   34  nRep:   97
# temp:  78.76  fRep:  55.06  fDist:  12.81  rmsd:   0.11  nViol:   32  nRep:  100
# temp:  78.67  fRep:  58.53  fDist:   8.64  rmsd:   0.09  nViol:   36  nRep:   94
# temp:  78.01  fRep:  56.55  fDist:  10.51  rmsd:   0.10  nViol:   34  nRep:   93
# temp:  79.33  fRep:  56.53  fDist:  10.41  rmsd:   0.10  nViol:   36  nRep:   89
# temp:  72.28  fRep:  59.87  fDist:   7.47  rmsd:   0.09  nViol:   34  nRep:   94
# temp:  77.15  fRep:  59.64  fDist:   7.13  rmsd:   0.08  nViol:   34  nRep:   96
# temp:  72.09  fRep:  59.23  fDist:   7.33  rmsd:   0.09  nViol:   34  nRep:   97
# temp:  71.13  fRep:  59.05  fDist:   7.94  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  64.77  fRep:  59.33  fDist:   8.74  rmsd:   0.09  nViol:   30  nRep:   99
# temp:  69.68  fRep:  59.48  fDist:   7.65  rmsd:   0.09  nViol:   34  nRep:  105
# temp:  67.42  fRep:  56.09  fDist:  11.96  rmsd:   0.11  nViol:   34  nRep:   95
# temp:  68.49  fRep:  59.68  fDist:   8.40  rmsd:   0.09  nViol:   34  nRep:   92
# temp:  64.67  fRep:  57.14  fDist:  10.36  rmsd:   0.10  nViol:   36  nRep:   95
# temp:  68.07  fRep:  59.25  fDist:   8.10  rmsd:   0.09  nViol:   34  nRep:   93
# temp:  65.95  fRep:  56.94  fDist:  10.16  rmsd:   0.10  nViol:   38  nRep:   90
# temp:  59.65  fRep:  61.56  fDist:   6.16  rmsd:   0.08  nViol:   36  nRep:  102
# temp:  64.76  fRep:  58.78  fDist:   9.27  rmsd:   0.10  nViol:   36  nRep:   93
# temp:  63.46  fRep:  58.93  fDist:   9.21  rmsd:   0.10  nViol:   34  nRep:   92
# temp:  60.02  fRep:  59.48  fDist:   8.58  rmsd:   0.09  nViol:   38  nRep:   94
# temp:  63.55  fRep:  61.13  fDist:   7.49  rmsd:   0.09  nViol:   32  nRep:   94
# temp:  61.05  fRep:  60.29  fDist:   7.70  rmsd:   0.09  nViol:   32  nRep:   94
# temp:  61.87  fRep:  60.47  fDist:   7.54  rmsd:   0.09  nViol:   32  nRep:   94
# temp:  58.79  fRep:  58.38  fDist:   9.69  rmsd:   0.10  nViol:   34  nRep:   93
# temp:  62.24  fRep:  59.80  fDist:   7.22  rmsd:   0.08  nViol:   34  nRep:   98
# temp:  58.82  fRep:  62.22  fDist:   4.77  rmsd:   0.07  nViol:   28  nRep:   94
# temp:  52.82  fRep:  58.53  fDist:   8.97  rmsd:   0.09  nViol:   32  nRep:   92
# temp:  55.56  fRep:  58.15  fDist:   8.84  rmsd:   0.09  nViol:   32  nRep:   89
# temp:  56.67  fRep:  58.83  fDist:   8.06  rmsd:   0.09  nViol:   28  nRep:   89
# temp:  53.39  fRep:  58.68  fDist:   8.77  rmsd:   0.09  nViol:   36  nRep:   88
# temp:  55.47  fRep:  60.06  fDist:   6.88  rmsd:   0.08  nViol:   32  nRep:   89
# temp:  55.74  fRep:  59.54  fDist:   7.85  rmsd:   0.09  nViol:   32  nRep:   85
# temp:  51.21  fRep:  60.33  fDist:   7.01  rmsd:   0.08  nViol:   32  nRep:   92
# temp:  55.65  fRep:  60.74  fDist:   7.02  rmsd:   0.08  nViol:   34  nRep:   94
# temp:  50.99  fRep:  59.99  fDist:   8.29  rmsd:   0.09  nViol:   34  nRep:  102
# temp:  53.59  fRep:  61.13  fDist:   6.44  rmsd:   0.08  nViol:   34  nRep:   96
# temp:  49.98  fRep:  58.56  fDist:   9.07  rmsd:   0.10  nViol:   34  nRep:  105
# temp:  48.44  fRep:  57.70  fDist:   9.89  rmsd:   0.10  nViol:   32  nRep:  101
# temp:  51.62  fRep:  61.02  fDist:   6.72  rmsd:   0.08  nViol:   38  nRep:   96
# temp:  51.75  fRep:  59.38  fDist:   8.58  rmsd:   0.09  nViol:   38  nRep:   98
# temp:  50.32  fRep:  60.85  fDist:   6.63  rmsd:   0.08  nViol:   34  nRep:  101
# temp:  48.45  fRep:  59.41  fDist:   8.02  rmsd:   0.09  nViol:   32  nRep:   93
# temp:  50.67  fRep:  59.37  fDist:   8.17  rmsd:   0.09  nViol:   32  nRep:  106
# temp:  46.68  fRep:  60.62  fDist:   7.25  rmsd:   0.09  nViol:   36  nRep:  105
# temp:  45.53  fRep:  60.56  fDist:   7.23  rmsd:   0.09  nViol:   32  nRep:  106
# temp:  46.91  fRep:  57.98  fDist:   9.63  rmsd:   0.10  nViol:   32  nRep:  104
# temp:  44.54  fRep:  59.09  fDist:   8.44  rmsd:   0.09  nViol:   32  nRep:  104
# temp:  45.79  fRep:  60.37  fDist:   7.31  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  43.15  fRep:  60.65  fDist:   6.89  rmsd:   0.08  nViol:   34  nRep:   90
# temp:  41.96  fRep:  59.91  fDist:   8.34  rmsd:   0.09  nViol:   30  nRep:   97
# temp:  41.33  fRep:  58.57  fDist:   9.03  rmsd:   0.10  nViol:   30  nRep:   90
# temp:  43.89  fRep:  59.00  fDist:   8.70  rmsd:   0.09  nViol:   34  nRep:   93
# temp:  40.35  fRep:  60.53  fDist:   7.23  rmsd:   0.09  nViol:   34  nRep:   93
# temp:  39.95  fRep:  60.39  fDist:   7.01  rmsd:   0.08  nViol:   38  nRep:   91
# temp:  41.41  fRep:  59.21  fDist:   8.20  rmsd:   0.09  nViol:   36  nRep:   86
# temp:  40.34  fRep:  59.97  fDist:   8.26  rmsd:   0.09  nViol:   32  nRep:   88
# temp:  38.75  fRep:  61.06  fDist:   6.54  rmsd:   0.08  nViol:   34  nRep:   96
# temp:  35.97  fRep:  59.87  fDist:   8.63  rmsd:   0.09  nViol:   34  nRep:   93
# temp:  40.05  fRep:  60.50  fDist:   7.20  rmsd:   0.08  nViol:   32  nRep:   92
# temp:  37.53  fRep:  59.09  fDist:   8.87  rmsd:   0.09  nViol:   32  nRep:   89
# temp:  36.96  fRep:  60.14  fDist:   7.56  rmsd:   0.09  nViol:   32  nRep:   90
# temp:  36.96  fRep:  58.95  fDist:   9.04  rmsd:   0.10  nViol:   36  nRep:   94
# temp:  37.93  fRep:  58.10  fDist:   9.77  rmsd:   0.10  nViol:   34  nRep:   94
# temp:  35.49  fRep:  60.57  fDist:   7.36  rmsd:   0.09  nViol:   32  nRep:   92
# temp:  35.00  fRep:  59.88  fDist:   7.80  rmsd:   0.09  nViol:   34  nRep:   96
# temp:  37.11  fRep:  58.74  fDist:   9.14  rmsd:   0.10  nViol:   34  nRep:   93
# temp:  36.47  fRep:  60.10  fDist:   7.74  rmsd:   0.09  nViol:   36  nRep:   94
# temp:  38.15  fRep:  59.01  fDist:   8.84  rmsd:   0.09  nViol:   36  nRep:   91
# temp:  33.99  fRep:  61.76  fDist:   6.50  rmsd:   0.08  nViol:   32  nRep:   91
# temp:  33.82  fRep:  59.93  fDist:   8.13  rmsd:   0.09  nViol:   38  nRep:   94
# temp:  32.69  fRep:  61.09  fDist:   6.70  rmsd:   0.08  nViol:   32  nRep:   93
# temp:  30.89  fRep:  59.21  fDist:   8.87  rmsd:   0.09  nViol:   32  nRep:   90
# temp:  31.66  fRep:  60.38  fDist:   7.68  rmsd:   0.09  nViol:   34  nRep:   88
# temp:  31.95  fRep:  60.01  fDist:   8.02  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  29.94  fRep:  59.57  fDist:   8.54  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  31.19  fRep:  61.42  fDist:   6.55  rmsd:   0.08  nViol:   36  nRep:   92
# temp:  31.70  fRep:  60.46  fDist:   7.84  rmsd:   0.09  nViol:   36  nRep:   89
# temp:  30.69  fRep:  59.47  fDist:   8.56  rmsd:   0.09  nViol:   32  nRep:   98
# temp:  29.96  fRep:  60.13  fDist:   7.84  rmsd:   0.09  nViol:   36  nRep:   99
# temp:  30.69  fRep:  60.97  fDist:   6.94  rmsd:   0.08  nViol:   30  nRep:   92
# temp:  30.12  fRep:  58.84  fDist:   9.31  rmsd:   0.10  nViol:   36  nRep:   95
# temp:  30.46  fRep:  60.50  fDist:   7.41  rmsd:   0.09  nViol:   36  nRep:   96
# temp:  29.57  fRep:  60.18  fDist:   7.52  rmsd:   0.09  nViol:   34  nRep:   94
# temp:  27.47  fRep:  62.73  fDist:   5.39  rmsd:   0.07  nViol:   30  nRep:   99
# temp:  27.86  fRep:  61.24  fDist:   6.66  rmsd:   0.08  nViol:   36  nRep:   95
# temp:  27.24  fRep:  61.14  fDist:   7.00  rmsd:   0.08  nViol:   34  nRep:   94
# temp:  26.47  fRep:  60.53  fDist:   7.72  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  27.81  fRep:  61.23  fDist:   6.64  rmsd:   0.08  nViol:   32  nRep:   88
# temp:  25.75  fRep:  59.69  fDist:   8.61  rmsd:   0.09  nViol:   34  nRep:   89
# temp:  25.27  fRep:  61.40  fDist:   6.68  rmsd:   0.08  nViol:   34  nRep:   95
# temp:  23.62  fRep:  60.15  fDist:   8.15  rmsd:   0.09  nViol:   32  nRep:   95
# temp:  25.12  fRep:  60.43  fDist:   7.68  rmsd:   0.09  nViol:   32  nRep:   90
# temp:  25.98  fRep:  60.68  fDist:   7.18  rmsd:   0.08  nViol:   36  nRep:   94
# temp:  25.96  fRep:  60.35  fDist:   7.50  rmsd:   0.09  nViol:   30  nRep:   95
# temp:  25.07  fRep:  60.25  fDist:   7.97  rmsd:   0.09  nViol:   32  nRep:   95
# temp:  25.14  fRep:  59.69  fDist:   8.49  rmsd:   0.09  nViol:   34  nRep:   93
# temp:  26.30  fRep:  59.77  fDist:   8.33  rmsd:   0.09  nViol:   30  nRep:   94
# temp:  24.62  fRep:  59.81  fDist:   8.06  rmsd:   0.09  nViol:   30  nRep:   95
# temp:  24.37  fRep:  60.85  fDist:   6.93  rmsd:   0.08  nViol:   34  nRep:   98
# temp:  23.01  fRep:  61.68  fDist:   6.20  rmsd:   0.08  nViol:   32  nRep:   99
# temp:  20.61  fRep:  60.94  fDist:   7.28  rmsd:   0.09  nViol:   36  nRep:   99
# temp:  22.10  fRep:  60.94  fDist:   7.27  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  21.54  fRep:  61.29  fDist:   6.76  rmsd:   0.08  nViol:   30  nRep:   90
# temp:  21.98  fRep:  60.80  fDist:   7.21  rmsd:   0.08  nViol:   34  nRep:  100
# temp:  21.26  fRep:  60.19  fDist:   7.81  rmsd:   0.09  nViol:   30  nRep:   98
# temp:  20.96  fRep:  60.82  fDist:   7.08  rmsd:   0.08  nViol:   34  nRep:   97
# temp:  21.19  fRep:  60.90  fDist:   7.20  rmsd:   0.08  nViol:   36  nRep:  100
# temp:  20.53  fRep:  60.43  fDist:   7.72  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  19.69  fRep:  61.45  fDist:   6.74  rmsd:   0.08  nViol:   32  nRep:   95
# temp:  20.47  fRep:  61.22  fDist:   6.79  rmsd:   0.08  nViol:   32  nRep:   99
# temp:  20.89  fRep:  61.46  fDist:   6.49  rmsd:   0.08  nViol:   32  nRep:  101
# temp:  19.67  fRep:  61.03  fDist:   7.06  rmsd:   0.08  nViol:   36  nRep:   95
# temp:  19.32  fRep:  61.12  fDist:   7.01  rmsd:   0.08  nViol:   34  nRep:   94
# temp:  19.73  fRep:  60.85  fDist:   7.17  rmsd:   0.08  nViol:   30  nRep:   89
# temp:  18.37  fRep:  59.39  fDist:   8.75  rmsd:   0.09  nViol:   34  nRep:   99
# temp:  19.09  fRep:  61.23  fDist:   6.70  rmsd:   0.08  nViol:   30  nRep:   96
# temp:  18.31  fRep:  60.58  fDist:   7.53  rmsd:   0.09  nViol:   30  nRep:   96
# temp:  19.72  fRep:  60.46  fDist:   7.56  rmsd:   0.09  nViol:   36  nRep:   92
# temp:  18.10  fRep:  60.29  fDist:   7.72  rmsd:   0.09  nViol:   30  nRep:   98
# temp:  18.62  fRep:  62.60  fDist:   5.61  rmsd:   0.07  nViol:   30  nRep:   95
# temp:  18.53  fRep:  60.60  fDist:   7.59  rmsd:   0.09  nViol:   36  nRep:   98
# temp:  17.79  fRep:  61.76  fDist:   6.33  rmsd:   0.08  nViol:   34  nRep:   99
# temp:  17.90  fRep:  60.47  fDist:   7.63  rmsd:   0.09  nViol:   32  nRep:   98
# temp:  16.67  fRep:  59.47  fDist:   8.72  rmsd:   0.09  nViol:   32  nRep:   94
# temp:  17.23  fRep:  60.49  fDist:   7.55  rmsd:   0.09  nViol:   34  nRep:   96
# temp:  16.78  fRep:  60.75  fDist:   7.45  rmsd:   0.09  nViol:   38  nRep:   92
# temp:  17.33  fRep:  62.29  fDist:   6.10  rmsd:   0.08  nViol:   30  nRep:   97
# temp:  16.52  fRep:  61.89  fDist:   6.22  rmsd:   0.08  nViol:   30  nRep:   96
# temp:  15.63  fRep:  60.67  fDist:   7.52  rmsd:   0.09  nViol:   32  nRep:   91
# temp:  15.65  fRep:  60.69  fDist:   7.50  rmsd:   0.09  nViol:   30  nRep:   94
# temp:  14.72  fRep:  61.07  fDist:   7.04  rmsd:   0.08  nViol:   32  nRep:   92
# temp:  16.11  fRep:  61.86  fDist:   6.37  rmsd:   0.08  nViol:   32  nRep:   91
# temp:  16.03  fRep:  60.68  fDist:   7.48  rmsd:   0.09  nViol:   30  nRep:   90
# temp:  14.46  fRep:  60.13  fDist:   8.04  rmsd:   0.09  nViol:   28  nRep:   88
# temp:  14.13  fRep:  60.72  fDist:   7.45  rmsd:   0.09  nViol:   32  nRep:   92
# temp:  15.03  fRep:  60.05  fDist:   8.24  rmsd:   0.09  nViol:   36  nRep:   90
# temp:  14.22  fRep:  61.78  fDist:   6.38  rmsd:   0.08  nViol:   32  nRep:   88
# temp:  14.20  fRep:  61.03  fDist:   6.98  rmsd:   0.08  nViol:   32  nRep:   85
# temp:  14.25  fRep:  61.96  fDist:   6.24  rmsd:   0.08  nViol:   34  nRep:   92
# temp:  12.98  fRep:  60.74  fDist:   7.67  rmsd:   0.09  nViol:   30  nRep:   89
# temp:  14.77  fRep:  61.30  fDist:   6.97  rmsd:   0.08  nViol:   36  nRep:   89
# temp:  13.29  fRep:  60.98  fDist:   7.17  rmsd:   0.08  nViol:   30  nRep:   90
# temp:  13.86  fRep:  60.53  fDist:   7.57  rmsd:   0.09  nViol:   32  nRep:   91
# temp:  13.75  fRep:  60.91  fDist:   7.24  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  13.57  fRep:  61.14  fDist:   7.00  rmsd:   0.08  nViol:   32  nRep:   92
# temp:  12.61  fRep:  62.38  fDist:   5.81  rmsd:   0.08  nViol:   36  nRep:   91
# temp:  13.11  fRep:  60.33  fDist:   8.11  rmsd:   0.09  nViol:   34  nRep:   93
# temp:  13.08  fRep:  60.87  fDist:   7.32  rmsd:   0.09  nViol:   34  nRep:   95
# temp:  12.30  fRep:  61.54  fDist:   6.81  rmsd:   0.08  nViol:   34  nRep:   91
# temp:  12.86  fRep:  60.93  fDist:   7.48  rmsd:   0.09  nViol:   28  nRep:   92
# temp:  12.73  fRep:  60.64  fDist:   7.65  rmsd:   0.09  nViol:   34  nRep:   92
# temp:  12.24  fRep:  61.05  fDist:   7.16  rmsd:   0.08  nViol:   28  nRep:   94
# temp:  12.32  fRep:  60.98  fDist:   7.23  rmsd:   0.09  nViol:   28  nRep:   88
# temp:  11.49  fRep:  60.74  fDist:   7.46  rmsd:   0.09  nViol:   30  nRep:   92
# temp:  10.95  fRep:  61.15  fDist:   7.25  rmsd:   0.09  nViol:   34  nRep:   91
# temp:  11.48  fRep:  60.85  fDist:   7.48  rmsd:   0.09  nViol:   30  nRep:   93
# temp:  10.82  fRep:  60.53  fDist:   7.80  rmsd:   0.09  nViol:   34  nRep:   90
# temp:  11.60  fRep:  61.38  fDist:   6.90  rmsd:   0.08  nViol:   30  nRep:   91
# temp:  10.81  fRep:  60.68  fDist:   7.60  rmsd:   0.09  nViol:   34  nRep:   88
# temp:  11.82  fRep:  62.12  fDist:   6.25  rmsd:   0.08  nViol:   34  nRep:   86
# temp:  10.56  fRep:  60.49  fDist:   7.92  rmsd:   0.09  nViol:   36  nRep:   91
# temp:  10.42  fRep:  61.49  fDist:   6.81  rmsd:   0.08  nViol:   34  nRep:   90
# temp:  10.94  fRep:  61.41  fDist:   6.91  rmsd:   0.08  nViol:   34  nRep:   91
# temp:   9.48  fRep:  60.61  fDist:   7.76  rmsd:   0.09  nViol:   32  nRep:   89
# temp:  10.65  fRep:  62.11  fDist:   6.19  rmsd:   0.08  nViol:   32  nRep:   92
# temp:  10.06  fRep:  61.71  fDist:   6.65  rmsd:   0.08  nViol:   34  nRep:   93
# temp:  10.30  fRep:  61.05  fDist:   7.31  rmsd:   0.09  nViol:   34  nRep:   89
#   0 [-0.04549971  2.27403474  1.08619179]
#   1 [ 0.97545512  1.65795972  1.13456549]
#   2 [ 1.08230651  0.6153128   0.55576848]
#   3 [ 0.20149474  0.17893355 -0.12854519]
#   4 [-0.62529181  0.88471898 -0.52337625]
#   5 [-0.78936029  1.93455925  0.06033701]
#   6 [ 0.55240967 -1.72801222 -0.91117267]
#   7 [ 0.41193722 -2.83682121 -1.1351241 ]
#   8 [-1.93593046  1.95681573  2.45851808]
#   9 [ 2.1165513   2.28425992  0.99795159]
#  10 [ 1.89904465 -0.12765832  1.2141324 ]
#  11 [-0.50505144  1.16319587 -1.79674159]
#  12 [-1.86850792  2.62487067  0.30764086]
#  13 [-1.22849122 -1.14025501  0.68560563]
#  14 [-0.78290113 -3.22543695 -1.46520791]
#  15 [-0.31453455 -3.45208263 -2.03589722]
#  16 [ 1.20753862 -3.5300011  -0.38756008]
#  17 [-0.23382322 -1.05317439 -0.13735597]
#  18 [-0.86619175  2.55182829  2.02785975]
#  19 [ 0.74884566 -1.0330477  -2.0075901 ]
